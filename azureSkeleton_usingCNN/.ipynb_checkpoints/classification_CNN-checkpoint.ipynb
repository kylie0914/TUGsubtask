# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from utils.utils_CNN import utilsCNN
from Visualization.plot_graph import plot_graph

from tensorflow import ConfigProto


utilsCNN = utilsCNN()
plots = plot_graph()

np.random.seed(7)
np.set_printoptions(precision=4)

datasetDir = '/home/sang/dataset/TUG/arrangedData_LabelSave'
# datasetDir = 'D:/바탕화면/Dataset/TUG/arrangedData_LabelSave' ; 
print(" Current workaing path [root]", os.getcwd())  

os.chdir(datasetDir) ; print(" Current workaing path [dataset] ", os.getcwd())  # -- Dataset 있는 곳으로 경로 변경 

# -------- 1. get csv file list for every trial 
utilsCNN.getDatalist_forEveryTrials(ROOT_DIR = datasetDir, displayList= True)
# # # ------ 2. getRawPelvis from All Trial (draw and save figures)
utilsCNN.getData_forEveryTrial(ROOT_DIR = datasetDir, displayResult = False)
# Out:
# utils CNN 객체 생성 -- Initialize
#  Current workaing path [root] /home/sang/conda_WS/tug_pjt/own/azureSkeleton_usingCNN
#  Current workaing path [dataset]  /home/sang/dataset/TUG/arrangedData_LabelSave
# Folder index: 0 ,    Folder name: 2020_11_03_(result)
#      ----------------------------------------------------------------------
#      Subject Idx: 0,      Subject: NHJ_60 ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 1,      Subject: bys_tug ,   # fo csvFiles: 9
#      ----------------------------------------------------------------------
#      Subject Idx: 2,      Subject: cbd_tug ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 3,      Subject: cyj2 ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 4,      Subject: cyj_tug ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 5,      Subject: pss ,   # fo csvFiles: 10
# Folder index: 1 ,    Folder name: 2020_11_20_v1_(result)
#      ----------------------------------------------------------------------
#      Subject Idx: 6,      Subject: NHJ_60 ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 7,      Subject: kw ,   # fo csvFiles: 9
#      ----------------------------------------------------------------------
#      Subject Idx: 8,      Subject: kyh ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 9,      Subject: lhs ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 10,      Subject: nhs ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 11,      Subject: pjh ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 12,      Subject: pss ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 13,      Subject: rjh ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 14,      Subject: yjh ,   # fo csvFiles: 10
# Folder index: 2 ,    Folder name: 2020_11_20_v2_(result)
#      ----------------------------------------------------------------------
#      Subject Idx: 15,      Subject: bys ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 16,      Subject: cbd ,   # fo csvFiles: 9
#      ----------------------------------------------------------------------
#      Subject Idx: 17,      Subject: cyj ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 18,      Subject: cyj2 ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 19,      Subject: jdh ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 20,      Subject: jek ,   # fo csvFiles: 10
#      ----------------------------------------------------------------------
#      Subject Idx: 21,      Subject: kch ,   # fo csvFiles: 10
# -----> [ Total Trials] (# of Trial):  220

# %%
# # -------------------[Subject Idx][trial Idx]
# print(np.array(utilsCNN.timestamp_sec).shape)
# print(np.array(utilsCNN.rawPelvis_x).shape)
# print(np.array(utilsCNN.rawPelvis_y).shape)
# print(np.array(utilsCNN.rawPelvis_z).shape)

numFeature = 4  # timestamp_sec, pelvis_x, pelvis_y, pelvis_z
numActions = 5  # "sitting": 0, "sit-stand":1, "walking":2, "turning":3, "stand-sit":4
action_label_code = {"sitting": 0, "sit-stand":1, "walking":2, "turning":3, "stand-sit":4} 

train_x_data , train_y_data , test_x_data, test_y_data= utilsCNN.createDataset_fromCSV(ROOT_DIR=datasetDir, numFeature=numFeature, numActions = numActions, trainSubNum = 14, displayInfo=True)
print("Train Set(x,y): {0} , {1} , Test Set(x,y): {2} , {3}".format(train_x_data.shape, train_y_data.shape, test_x_data.shape, test_y_data.shape))
# Out:
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/bys_tug  ,   FileName:  Labeled_CSV_bys_tug_001.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/bys_tug  ,   FileName:  Labeled_CSV_bys_tug_002.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/bys_tug  ,   FileName:  Labeled_CSV_bys_tug_003.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/bys_tug  ,   FileName:  Labeled_CSV_bys_tug_004.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/bys_tug  ,   FileName:  Labeled_CSV_bys_tug_005.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/bys_tug  ,   FileName:  Labeled_CSV_bys_tug_006.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/bys_tug  ,   FileName:  Labeled_CSV_bys_tug_007.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/bys_tug  ,   FileName:  Labeled_CSV_bys_tug_008.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/bys_tug  ,   FileName:  Labeled_CSV_bys_tug_009.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cbd_tug  ,   FileName:  Labeled_CSV_cbd_tug_000.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cbd_tug  ,   FileName:  Labeled_CSV_cbd_tug_001.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cbd_tug  ,   FileName:  Labeled_CSV_cbd_tug_002.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cbd_tug  ,   FileName:  Labeled_CSV_cbd_tug_003.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cbd_tug  ,   FileName:  Labeled_CSV_cbd_tug_004.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cbd_tug  ,   FileName:  Labeled_CSV_cbd_tug_005.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cbd_tug  ,   FileName:  Labeled_CSV_cbd_tug_006.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cbd_tug  ,   FileName:  Labeled_CSV_cbd_tug_007.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cbd_tug  ,   FileName:  Labeled_CSV_cbd_tug_008.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cbd_tug  ,   FileName:  Labeled_CSV_cbd_tug_009.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj_tug  ,   FileName:  Labeled_CSV_cyj_tug_000.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj_tug  ,   FileName:  Labeled_CSV_cyj_tug_001.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj_tug  ,   FileName:  Labeled_CSV_cyj_tug_002.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj_tug  ,   FileName:  Labeled_CSV_cyj_tug_003.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj_tug  ,   FileName:  Labeled_CSV_cyj_tug_004.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj_tug  ,   FileName:  Labeled_CSV_cyj_tug_005.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj_tug  ,   FileName:  Labeled_CSV_cyj_tug_006.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj_tug  ,   FileName:  Labeled_CSV_cyj_tug_007.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj_tug  ,   FileName:  Labeled_CSV_cyj_tug_008.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/cyj_tug  ,   FileName:  Labeled_CSV_cyj_tug_009.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_03_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/NHJ_60  ,   FileName:  Labeled_CSV_NHJ_60_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kw  ,   FileName:  Labeled_CSV_kw_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kw  ,   FileName:  Labeled_CSV_kw_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kw  ,   FileName:  Labeled_CSV_kw_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kw  ,   FileName:  Labeled_CSV_kw_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kw  ,   FileName:  Labeled_CSV_kw_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kw  ,   FileName:  Labeled_CSV_kw_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kw  ,   FileName:  Labeled_CSV_kw_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kw  ,   FileName:  Labeled_CSV_kw_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kw  ,   FileName:  Labeled_CSV_kw_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kw  ,   FileName:  Labeled_CSV_kw_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kyh  ,   FileName:  Labeled_CSV_kyh_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kyh  ,   FileName:  Labeled_CSV_kyh_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kyh  ,   FileName:  Labeled_CSV_kyh_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kyh  ,   FileName:  Labeled_CSV_kyh_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kyh  ,   FileName:  Labeled_CSV_kyh_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kyh  ,   FileName:  Labeled_CSV_kyh_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kyh  ,   FileName:  Labeled_CSV_kyh_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kyh  ,   FileName:  Labeled_CSV_kyh_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kyh  ,   FileName:  Labeled_CSV_kyh_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/kyh  ,   FileName:  Labeled_CSV_kyh_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/lhs  ,   FileName:  Labeled_CSV_lhs_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/lhs  ,   FileName:  Labeled_CSV_lhs_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/lhs  ,   FileName:  Labeled_CSV_lhs_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/lhs  ,   FileName:  Labeled_CSV_lhs_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/lhs  ,   FileName:  Labeled_CSV_lhs_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/lhs  ,   FileName:  Labeled_CSV_lhs_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/lhs  ,   FileName:  Labeled_CSV_lhs_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/lhs  ,   FileName:  Labeled_CSV_lhs_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/lhs  ,   FileName:  Labeled_CSV_lhs_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/lhs  ,   FileName:  Labeled_CSV_lhs_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/nhs  ,   FileName:  Labeled_CSV_nhs_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/nhs  ,   FileName:  Labeled_CSV_nhs_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/nhs  ,   FileName:  Labeled_CSV_nhs_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/nhs  ,   FileName:  Labeled_CSV_nhs_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/nhs  ,   FileName:  Labeled_CSV_nhs_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/nhs  ,   FileName:  Labeled_CSV_nhs_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/nhs  ,   FileName:  Labeled_CSV_nhs_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/nhs  ,   FileName:  Labeled_CSV_nhs_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/nhs  ,   FileName:  Labeled_CSV_nhs_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/nhs  ,   FileName:  Labeled_CSV_nhs_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/nhs  ,   FileName:  Labeled_CSV_nhs_10.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pjh  ,   FileName:  Labeled_CSV_pjh_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pjh  ,   FileName:  Labeled_CSV_pjh_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pjh  ,   FileName:  Labeled_CSV_pjh_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pjh  ,   FileName:  Labeled_CSV_pjh_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pjh  ,   FileName:  Labeled_CSV_pjh_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pjh  ,   FileName:  Labeled_CSV_pjh_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pjh  ,   FileName:  Labeled_CSV_pjh_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pjh  ,   FileName:  Labeled_CSV_pjh_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pjh  ,   FileName:  Labeled_CSV_pjh_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pjh  ,   FileName:  Labeled_CSV_pjh_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/pss  ,   FileName:  Labeled_CSV_pss_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/rjh  ,   FileName:  Labeled_CSV_rjh_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/rjh  ,   FileName:  Labeled_CSV_rjh_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/rjh  ,   FileName:  Labeled_CSV_rjh_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/rjh  ,   FileName:  Labeled_CSV_rjh_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/rjh  ,   FileName:  Labeled_CSV_rjh_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/rjh  ,   FileName:  Labeled_CSV_rjh_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/rjh  ,   FileName:  Labeled_CSV_rjh_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/rjh  ,   FileName:  Labeled_CSV_rjh_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/rjh  ,   FileName:  Labeled_CSV_rjh_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/rjh  ,   FileName:  Labeled_CSV_rjh_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/yjh  ,   FileName:  Labeled_CSV_yjh_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/yjh  ,   FileName:  Labeled_CSV_yjh_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/yjh  ,   FileName:  Labeled_CSV_yjh_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/yjh  ,   FileName:  Labeled_CSV_yjh_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/yjh  ,   FileName:  Labeled_CSV_yjh_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/yjh  ,   FileName:  Labeled_CSV_yjh_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/yjh  ,   FileName:  Labeled_CSV_yjh_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/yjh  ,   FileName:  Labeled_CSV_yjh_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/yjh  ,   FileName:  Labeled_CSV_yjh_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v1_(result)/Labeled_CSV/yjh  ,   FileName:  Labeled_CSV_yjh_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/bys  ,   FileName:  Labeled_CSV_bys_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/bys  ,   FileName:  Labeled_CSV_bys_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/bys  ,   FileName:  Labeled_CSV_bys_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/bys  ,   FileName:  Labeled_CSV_bys_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/bys  ,   FileName:  Labeled_CSV_bys_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/bys  ,   FileName:  Labeled_CSV_bys_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/bys  ,   FileName:  Labeled_CSV_bys_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/bys  ,   FileName:  Labeled_CSV_bys_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/bys  ,   FileName:  Labeled_CSV_bys_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/bys  ,   FileName:  Labeled_CSV_bys_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cbd  ,   FileName:  Labeled_CSV_cbd_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cbd  ,   FileName:  Labeled_CSV_cbd_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cbd  ,   FileName:  Labeled_CSV_cbd_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cbd  ,   FileName:  Labeled_CSV_cbd_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cbd  ,   FileName:  Labeled_CSV_cbd_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cbd  ,   FileName:  Labeled_CSV_cbd_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cbd  ,   FileName:  Labeled_CSV_cbd_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cbd  ,   FileName:  Labeled_CSV_cbd_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cbd  ,   FileName:  Labeled_CSV_cbd_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cbd  ,   FileName:  Labeled_CSV_cbd_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj  ,   FileName:  Labeled_CSV_cyj_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj  ,   FileName:  Labeled_CSV_cyj_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj  ,   FileName:  Labeled_CSV_cyj_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj  ,   FileName:  Labeled_CSV_cyj_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj  ,   FileName:  Labeled_CSV_cyj_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj  ,   FileName:  Labeled_CSV_cyj_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj  ,   FileName:  Labeled_CSV_cyj_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj  ,   FileName:  Labeled_CSV_cyj_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj  ,   FileName:  Labeled_CSV_cyj_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj  ,   FileName:  Labeled_CSV_cyj_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/cyj2  ,   FileName:  Labeled_CSV_cyj2_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jdh  ,   FileName:  Labeled_CSV_jdh_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jdh  ,   FileName:  Labeled_CSV_jdh_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jdh  ,   FileName:  Labeled_CSV_jdh_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jdh  ,   FileName:  Labeled_CSV_jdh_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jdh  ,   FileName:  Labeled_CSV_jdh_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jdh  ,   FileName:  Labeled_CSV_jdh_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jdh  ,   FileName:  Labeled_CSV_jdh_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jdh  ,   FileName:  Labeled_CSV_jdh_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jdh  ,   FileName:  Labeled_CSV_jdh_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jdh  ,   FileName:  Labeled_CSV_jdh_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jek  ,   FileName:  Labeled_CSV_jek_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jek  ,   FileName:  Labeled_CSV_jek_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jek  ,   FileName:  Labeled_CSV_jek_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jek  ,   FileName:  Labeled_CSV_jek_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jek  ,   FileName:  Labeled_CSV_jek_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jek  ,   FileName:  Labeled_CSV_jek_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jek  ,   FileName:  Labeled_CSV_jek_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jek  ,   FileName:  Labeled_CSV_jek_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jek  ,   FileName:  Labeled_CSV_jek_09.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/jek  ,   FileName:  Labeled_CSV_jek_10.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/kch  ,   FileName:  Labeled_CSV_kch_00.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/kch  ,   FileName:  Labeled_CSV_kch_01.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/kch  ,   FileName:  Labeled_CSV_kch_02.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/kch  ,   FileName:  Labeled_CSV_kch_03.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/kch  ,   FileName:  Labeled_CSV_kch_04.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/kch  ,   FileName:  Labeled_CSV_kch_05.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/kch  ,   FileName:  Labeled_CSV_kch_06.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/kch  ,   FileName:  Labeled_CSV_kch_07.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/kch  ,   FileName:  Labeled_CSV_kch_08.csv
# Dir:  /home/sang/dataset/TUG/arrangedData_LabelSave/2020_11_20_v2_(result)/Labeled_CSV/kch  ,   FileName:  Labeled_CSV_kch_09.csv
# Train Set(x,y): (54751, 4) , (54751, 5) , Test Set(x,y): (32184, 4) , (32184, 5)

# %%
sliding_window_size = 15 # 30.. 1sec.. 50 Equals to 1 sec for MotionSense Dataset (it is on 50Hz samplig rate)
step_size_of_sliding_window = 3 #10 
print("--> Sectioning Training and Test datasets: shape of each section will be: (",numFeature,"x",sliding_window_size,")")
train_x_secs, train_y_secs, train_mean, train_std = utilsCNN.time_series_to_section(train_x_data.copy(),train_y_data.copy(), numActions, sliding_window_size,step_size_of_sliding_window,standardize = True)

test_x_secs, test_y_secs, test_mean, test_std = utilsCNN.time_series_to_section(test_x_data.copy(), test_y_data.copy(), 
                                                                                          numActions,
                                                                                          sliding_window_size,
                                                                                          step_size_of_sliding_window,
                                                                                          standardize = True,
                                                                                          mean = train_mean, 
                                                                                          std = train_std)

print("\n\n---> Training X Section: {0} , Training Label Section: {1} \n---> Test X Sections: {2} , Test Label Sections: {3}".format(train_x_secs.shape, train_y_secs.shape, test_x_secs.shape, test_y_secs.shape))
# Out:
# --> Sectioning Training and Test datasets: shape of each section will be: ( 4 x 15 )
# Training Data has been standardized:
#  the mean is =  1215.5237984730875  ; and the std is =  453.1977491211859
# number of sections:  18245 size of data 54751
# Test Data has been standardized:
# number of sections:  10723 size of data 32184
#
#
# ---> Training X Section: (14319, 4, 15) , Training Label Section: (14319, 5)
# ---> Test X Sections: (8515, 4, 15) , Test Label Sections: (8515, 5)

# %%
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Flatten, Reshape
from tensorflow.keras.layers import Conv2D , MaxPooling2D, Dropout

## Here we add an extra dimension to the datasets just to be ready for using with Convolution2D
train_x = np.expand_dims(train_x_secs, axis=3)
test_x = np.expand_dims(test_x_secs, axis=3)
print("---> Training Section: {0} , Test Sections: {1}".format(train_x.shape, test_x.shape))
# Out:
# ---> Training Section: (14319, 4, 15, 1) , Test Sections: (8515, 4, 15, 1)

# %%
num_train, height, width, channel = train_x.shape  #   (13298, 4, 15, 1) =  (number_of_secs , size_features , sliding_window_size, 1)
metrics = ['acc']

## MTCNN
drop_prob_1 = 0.2 
drop_prob_2 = 0.4 


## Action model 
action_layer_dim = numActions # 4  # dws, ups, wlk, jog # , sit,  std 
action_activation_func = 'softmax'
action_loss_func = 'categorical_crossentropy'


# feature 가 row 에 하나씩 있음 -> kernel, pooling  시 (1, k) 로 수행 
def activityModel():

    input_layer = Input(shape = (height, width, 1) ) # (4, 15, 1) = (feature, sliding_window, 1)

    conv_0 = Conv2D(15, kernel_size=(1, 5), strides=(1, 1), padding='valid',  activation='relu') (input_layer) #5
    conv_1 = Conv2D(15, kernel_size=(1, 5), strides=(1, 1), padding='same', activation='relu') (conv_0)
    dense_1 = Dense(50, activation='relu') (conv_1)
    pool_1 = MaxPooling2D(pool_size=(1,2)) (dense_1)
    drop_1 = Dropout(drop_prob_1)(pool_1)


    conv_2 = Conv2D(11, kernel_size=(1, 3), strides=(1, 1), padding='valid',  activation='relu') (drop_1)# 5
    dense_2 = Dense(40, activation='relu') (conv_2)
    pool_2 = MaxPooling2D(pool_size=(1, 3)) (dense_2)  
    drop_2 = Dropout(drop_prob_1) (pool_2)

    conv_3 = Conv2D(10, kernel_size=(1, 3), strides=(1, 1), padding='same',  activation='relu') (drop_2)
    drop_3 = Dropout(drop_prob_1)(conv_3)

    flat = Flatten() (drop_3)
    hidden = Dense(400, activation = 'relu') (flat)
    drop_4 = Dropout(drop_prob_2)(hidden)

    action_out = Dense(action_layer_dim, activation = action_activation_func, name = 'ACTION') (drop_4)
    
    # --------- Model input/ Output Definition
    activity_model = Model(inputs=input_layer, outputs = action_out)
    activity_model.summary()

    activity_model.compile(loss=action_loss_func, 
          optimizer=keras.optimizers.Adam(0.001),
          metrics=metrics)

    return activity_model

# %%
## Training Phase
batch_size = 64
num_of_epochs = 30 # 35
verbosity = 1

# Model Training 
model = activityModel()
history = model.fit(train_x, train_y_secs,                
              batch_size = batch_size,
              epochs = num_of_epochs,
              verbose = verbosity)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 4, 15, 1)]        0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 4, 11, 15)         90
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 11, 15)         1140
# _________________________________________________________________
# dense (Dense)                (None, 4, 11, 50)         800
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 4, 5, 50)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 4, 5, 50)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 3, 11)          1661
# _________________________________________________________________
# dense_1 (Dense)              (None, 4, 3, 40)          480
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 1, 40)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 1, 40)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 1, 10)          1210
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 1, 10)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 40)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               16400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 400)               0
# _________________________________________________________________
# ACTION (Dense)               (None, 5)                 2005
# =================================================================
# Total params: 23,786
# Trainable params: 23,786
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-6-1291804d4ba3> in <module>
#       6 # Model Training
#       7 model = activityModel()
# ----> 8 history = model.fit(train_x, train_y_secs,
#       9               batch_size = batch_size,
#      10               epochs = num_of_epochs,
#
# ~/miniconda3/envs/tug/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/miniconda3/envs/tug/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/miniconda3/envs/tug/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/miniconda3/envs/tug/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     642         # Lifting succeeded, so variables are initialized and we can run the
#     643         # stateless function.
# --> 644         return self._stateless_fn(*args, **kwds)
#     645     else:
#     646       canon_args, canon_kwds = \
#
# ~/miniconda3/envs/tug/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/miniconda3/envs/tug/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~/miniconda3/envs/tug/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/miniconda3/envs/tug/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~/miniconda3/envs/tug/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# UnknownError:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node model/conv2d/Conv2D (defined at <ipython-input-6-1291804d4ba3>:8) ]] [Op:__inference_train_function_1509]
#
# Function call stack:
# train_function

# %%
#------------- Evaluation 
results_1 = model.evaluate(test_x, test_y_secs, verbose = verbosity)
print("--> Evaluation on Test Dataset:")
print("**** Accuracy for Activity Recognition task is: ", results_1)
# Out:
# 165/165 [==============================] - 0s 2ms/step - loss: 0.1344 - acc: 0.9404
# --> Evaluation on Test Dataset:
# **** Accuracy for Activity Recognition task is:  [0.13441205024719238, 0.9404150247573853]

# %%
y_predict = model.predict(test_x) # (6161, 5)  
y_pred_index = y_predict.argmax(axis=1) # print(y_pred_index) 
y_true_idx = np.argmax(test_y_secs, axis=1) # print(y_true_idx)

correct = np.nonzero(y_true_idx == y_pred_index) # print(correct, len(correct[0]))
incorrect = np.nonzero(y_true_idx != y_pred_index) # print(incorrect, len(incorrect[0]))

valid_num = len(correct[0]) + len(incorrect[0])
tot_num = len(y_true_idx)
# print("[must same] # of real data: ", tot_num, "==  # of pred data: ", valid_num)
percent_correct = len(correct[0]) /tot_num
percent_incorrect = len(incorrect[0])/tot_num
print(" correct: ", percent_correct," [%]", ",  incorrect: ", percent_incorrect," [%]")
# Out:
#  correct:  0.9305158956786598  [%] ,  incorrect:  0.06948410432134018  [%]

# %%
def getOriginShape(x_data, y_data, x_secs, y_secs):
    
    k = 0
    for i in range(0, (size_data) - sliding_window_size, step_size_of_sliding_window):
        j = i // step_size_of_sliding_window
        if(j >= number_of_secs):
                break

        if(not (act_labels[i] == act_labels[i+sliding_window_size-1]).all()):
                continue
            
            
        secs_data[k] = data[0:size_features, i:i+sliding_window_size]
        act_secs_labels[k] = act_labels[i].astype(int)
        k = k+1
    secs_data = secs_data[0:k]    
    act_secs_labels = act_secs_labels[0:k]

getOriginShape(test_x_data.copy(), test_y_data.copy(), test_x_secs.copy(), test_y_secs.copy())

# %%
# Out:
# (92415, 4)

# %%
# pelvis_y = 2
# # for dataIdx in range(tot_num):
# #     print(test_x_secs[:,2,:])
    
# fig, ax = plt.subplots(nrows=5, ncols=1, figsize=(20, 10))
# ax[0].plot(test_x_secs[:,0,0], test_x_secs[:,2,0], 'g--', lw=0.1, label='sitting')
# ax[1].plot(x, y_predict[:,1], 'b*', lw=0.1, label='sitStand')
# ax[2].plot(x, y_predict[:,2], 'r*', lw=0.1, label='walking')
# ax[3].plot(x, y_predict[:,3], 'g*', lw=0.1, label='Turning')
# ax[4].plot(x, y_predict[:,4], 'b*', lw=0.1, label='standSit')
# plt.legend()
# plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
y_predict = model.predict(test_x_secs)
print(y_predict.shape) # (6161, 5)  , sliding window size 
print(y_predict.argmax(axis=1)) 
print(test_y_secs[y_predict.argmax(axis=1)])

x = np.arange(len(y_predict))

fig, ax = plt.subplots(nrows=5, ncols=1, figsize=(20, 10))
ax[0].plot(x, y_predict[:,0], 'r--', lw=1, label='sitting')
ax[1].plot(x, y_predict[:,1], 'b--', lw=1, label='sitStand')
ax[2].plot(x, y_predict[:,2], 'g--', lw=1, label='walking')
ax[3].plot(x, y_predict[:,3], 'r--', lw=1, label='Turning')
ax[4].plot(x, y_predict[:,4], 'b--', lw=1, label='standSit')
plt.legend()
plt.show()

# %%
y_pred = test_y[y_predict.argmax(axis=1)]
y_test =np.argmax(test_y,axis=1)

correct = np.nonzero(y_pred == y_test)
incorrect = np.nonzero(y_pred != y_test)
print("correct: ", correct)

### Check the correctly-predicted samples
plt.figure(1)
for i, cor in enumerate(correct[:9]):
    plt.subplot(3,3,i+1)
    plt.subplots_adjust(hspace=1.0,wspace=1.0)
    plt.plot(test_x.iloc[cor,:])
    plt.title("Predicted:{}\nTrue:{}".format(activity_types[y_pred[cor]-1], 
                                              activity_types[y_test[cor]-1]))
    plt.xticks([]) # turn off x labels
    plt.yticks([])  # turn off y labels
    #plt.tight_layout()
plt.show()
### Check the incorrectly-predicted samples
plt.figure(2)
for i, cor in enumerate(incorrect[:9]):
    plt.subplot(3,3,i+1)
    plt.subplots_adjust(hspace=1.0,wspace=1.0)
    plt.plot(test_x.iloc[cor,:])
    plt.title("Predicted:{}\nTrue:{}".format(activity_types[y_pred[cor]-1], 
                                              activity_types[y_test[cor]-1]))
    plt.xticks([]) # turn off x labels
    plt.yticks([])  # turn off y labels
    #plt.tight_layout()
plt.show()

# %%
### Confusion matrix (predictive performance on different classes)
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    function provided by sklearn example
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cnf_matrix = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cnf_matrix, classes=activity_types,
                      title='Confusion matrix, without normalization')

# %% [markdown]
# ### Get Pelvis data - LPF + Norm (save Figure + csv)
# ### Get oneHot encoded Label
# ### Interpolation (Univariate Interpolation)

# %%
import os
import numpy as np 
import matplotlib.pyplot as plt
from IPython.display import clear_output
import time


from scipy.signal import butter, lfilter, filtfilt  
from scipy.interpolate import UnivariateSpline  # missing value -> np.nan -> to zero -> 

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold  # 라벨 x_data, y_data 분포를 유지 (함께 fold)
import tensorflow as tf 

np.random.seed(7)
np.set_printoptions(precision=4, suppress=True)  # 과학적 표기 대신 소숫점 자리 4자리까지 표현

rootDir = "/DockerProjects/Dataset/TUG/trainSet"
expertFolder = "/" + "HMM_saveResults_최윤정"  # --- 변경 할 부분
viewFolder = "/" + "0_sideView"

print(" [Home Dir.] Current path", os.getcwd())  

datasetDir = rootDir + expertFolder + viewFolder
os.chdir(datasetDir) ; print(" Current workaing path [dataset] ", os.getcwd())  # -- Dataset 있는 곳으로 경로 변경
# Out:
#  [Home Dir.] Current path /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel
#  Current workaing path [dataset]  /DockerProjects/Dataset/TUG/trainSet/HMM_saveResults_최윤정/0_sideView

# %% [markdown]
# ### Train/Test Subject Split

# %%
def get_subjectList(datasetDir, shuffle = False):      
    expDates = next(os.walk(datasetDir))[1]   #['2020_11_03', '2020_11_20_v1', '2020_11_20_v2', '2020_11_23', '2020_12_09', '2020_12_30']
    subject_number = 0
    subjects_list = []
    
    for dateFolder in expDates:
        dateDir = os.path.join(datasetDir, dateFolder)   # D:/바탕화면/Dataset/TUG/trainSet/2021_01_24_saveResults_최윤정/0_sideView\2020_11_03
        tmpSubjects = next(os.walk(dateDir))[1]
        subjects_list.append(tmpSubjects)  
 

    # ------ 2D -> 1D [[sub1, sub2], [sub3, sub4]] -> [sub1, sub2, sub3, sub4]
    subjects = []
    for eachSub in subjects_list:
        for sub in eachSub:
            if ".ipynb_checkpoints" == sub:
                pass
            else:
                subjects.append(sub)
                subject_number +=1

    if shuffle:
        np.random.shuffle(subjects)
        
    print(" 1D sub list: " , subjects, len(subjects))
    return subjects, subject_number

def fold_trainNames(subList, Kfold_num = 5):
    assert (Kfold_num is not 0), print("check kfold_num. should not be zero")
    Fold_results =[]
    kfold = KFold(n_splits=  Kfold_num)
    
    for trainIdx, testIdx in kfold.split(subList):
        Fold_results.append([trainIdx, testIdx])      
        
    train_Fold= []
    test_Fold = []
        
    for i in range(Kfold_num):    # bind fold pair
        tmp_train = []
        tmp_test = []
        for subIdx in range(len(subList)): 
            if subIdx in Fold_results[i][0]:  # -- K-fold train
                tmp_train.append(subList[subIdx])
               
            if subIdx in Fold_results[i][1]:  # -- K-fold test
                tmp_test.append(subList[subIdx])
          
        train_Fold.append(tmp_train)
        test_Fold.append(tmp_test)
        print("\t [process]", i, "-fold:", train_Fold[i], "\n\t\t\t   ,", test_Fold[i])
    print("\n [results]  trainSet: ", len(train_Fold[0]) , " 명 , testSet: ", len(test_Fold[0]), " 명" )
    
    return train_Fold, test_Fold

# %%
train_ratio = 0.6
valid_ratio = 0.2

shuffle = True
arbitrarySplit = True
Kfold = False
Kfold_num = 5 # if kfold_num = 0 (arbitrary train/test set will be used)s


numFeature = 4 # time + numPelvis = 4
numPelvis = 3 
numActions = 5
dataset_columns = numFeature + numActions

subList, numOfsubjects = get_subjectList(datasetDir, shuffle = shuffle) ; print("\n")

if arbitrarySplit is not True:
    if Kfold:
        print(" K-fold : ", Kfold_num)
        trainFold, testFold = fold_trainNames(subList = subList, Kfold_num = Kfold_num)

        selected_foldNum = 0 

        train_subjects = trainFold[selected_foldNum]
        test_subjects = testFold[selected_foldNum]
        print("\t ------>  Selected Fold num: %d \n   Train Subjects: %s\n   Test Subjects: %s"%(selected_foldNum, train_subjects, test_subjects))
    else:

        trainSub_number = np.round( (numOfsubjects*train_ratio), 0).astype(int)
        validSub_number = np.round( (numOfsubjects*valid_ratio), 0).astype(int)
        testSub_number = numOfsubjects - trainSub_number - validSub_number

        train_subjects = subList[ :trainSub_number]
        valid_subjects = subList[ trainSub_number : (trainSub_number+validSub_number)]
        test_subjects = subList[ (trainSub_number+validSub_number): ]
        print("   No-fold \t [results] \n\t Train: " ,train_subjects, "\n\t Valid: ", valid_subjects, "\n\t Test: ", test_subjects)
        print("\n\t--> # of train  : " + str(trainSub_number) +" 명 ,  # of valid : "+ str(validSub_number) + " 명 ,  # of test :" + str(testSub_number) + "명")

else:

                # 정상인 (20-40대) --- 17명, 166 Trials (중복 3명 빼면 14명, 138 Trials )
                # ['bys_tug', 'cyj_tug', 'cbd_tug', 'kw' , 'pjh',     'pss', 'yjh', 'kyh' , 'lhs', 'nhs',    'bys', 'cyj', 'cbd', 'cyj2', 'jdh',   'jet', 'kch']
            
            
                # 정상인 (50-70대)  ---- 총 31명  227 Trials 
                # ['rjh', 'NHJ_60', 'YJY_TUG'(0), 'LKO_TUG', 'LSJ_TUG',    'GYH_TUG', 'KYS3_TUG','PBK_TUG','KJK_TUG', 'WHS_TUG'(0),    'UMS_TUG','JJS_TUG','HOJ_TUG','SJJ_TUG','YSS2_TUG',   'KJH_TUG','CSY_TUG','LBL_TUG','UKO_TUG'(0), 'BKS_TUG', 
                # 'LSC_TUG','YMR_TUG','PSM_TUG','HSN_TUG','SOS_TUG',     'LSS_TUG', 'KDS_TUG'(0), 'KHM_TUG', 'LJS_TUG', 'LJE_TUG',     'KBH_TUG' ]


                # 뇌졸중 (연령 X) --- 총 20 명 , 85 Trials
                # [  'BGD_TUG'(0), 'KNG_TUG', 'KSG_TUG', 'YBJ_TUG', 'RJD_TUG',    'YSS_TUG'(0), 'SRK_TUG', 'KWB_TUG'(0), 'KYS_TUG', 'KTS_TUG',    'SRH_TUG', 'YDS_TUG'(0)', 'HHS_TUG', 'KYS2_TUG', 'KSJ_TUG',      
                #    'KYB_TUG', 'CES_TUG', 'PCW_TUG', 'WJS_TUG','HKH_TUG',        'HJY_TUG', 'SHW_TUG']
    
    
    norm20 = ['bys_tug', 'cyj_tug', 'cbd_tug', 'kw' , 'pjh',     'pss', 'yjh', 'kyh' , 'lhs', 'nhs',    'bys', 'cyj', 'cbd', 'cyj2', 'jdh',   'jet', 'kch']
    norm60 = ['rjh', 'NHJ_60', 'LKO_TUG', 'LSJ_TUG',    'GYH_TUG', 'KYS3_TUG','PBK_TUG','KJK_TUG', 'UMS_TUG','JJS_TUG',   'HOJ_TUG','SJJ_TUG','YSS2_TUG',   'KJH_TUG','CSY_TUG','LBL_TUG','BKS_TUG', 
              'LSC_TUG','YMR_TUG','PSM_TUG','HSN_TUG','SOS_TUG',     'LSS_TUG', 'KHM_TUG', 'LJS_TUG', 'LJE_TUG',     'KBH_TUG' ]
    stroke = ['KNG_TUG', 'KSG_TUG', 'YBJ_TUG', 'RJD_TUG',  'SRK_TUG',     'KYS_TUG', 'KTS_TUG','SRH_TUG', 'HHS_TUG', 'KYS2_TUG',      'KSJ_TUG', 'KYB_TUG', 'CES_TUG', 'PCW_TUG', 'WJS_TUG',
              'HKH_TUG', 'HJY_TUG', 'SHW_TUG']
    
    specific_group = norm20 # -------------------------------------------------- Change This part 
    numOfsubjects = len( specific_group )
    
    
    np.random.shuffle(specific_group)
    
    trainSub_number = np.round( (numOfsubjects*train_ratio), 0).astype(int)
    validSub_number = np.round( (numOfsubjects*valid_ratio), 0).astype(int)
    testSub_number = numOfsubjects - trainSub_number - validSub_number

    train_subjects = specific_group[ :trainSub_number]
    valid_subjects = specific_group[ trainSub_number : (trainSub_number+validSub_number)]
    test_subjects = specific_group[ (trainSub_number+validSub_number): ]
    print(" No-fold --- (arbitrary) \t [results] \n\t Train 명: " ,len(train_subjects), "\n\t Valid 명: ", len(valid_subjects), "\n\t Test 명: ", len(test_subjects))
    print(" No-fold --- (arbitrary) \t [results] \n\t Train: " ,train_subjects, "\n\t Valid: ", valid_subjects, "\n\t Test: ", test_subjects)
# Out:
#  1D sub list:  ['LJE_TUG', 'CYJ_TUG', 'HJY_TUG', 'HHS_TUG', 'CSY_TUG', 'jdh', 'LSC_TUG', 'LSS_TUG', 'YBJ_TUG', 'jek', 'LBL_TUG', 'KHM_TUG', 'KNG_TUG', 'KYS2_TUG', 'UMS_TUG', 'KYS_TUG', 'HSN_TUG', 'KSG_TUG', 'YSS2_TUG', 'kch', 'HOJ_TUG', 'SHW_TUG', 'WJS_TUG', 'YSJ_TUG', 'KJH_TUG', 'KSJ_TUG', 'JDW_tug', 'kyh', 'pjh', 'yjh', 'cyj_tug', 'bys_tug', 'bys', 'rjh', 'PBK_TUG', 'cbd_tug', 'KTS_TUG', 'SRK_TUG', 'GYH_TUG', 'NHJ_60', 'KJK_TUG', 'SJJ_TUG', 'PHE_TUG', 'LSJ_TUG', 'CES_TUG', 'HKH_TUG', 'nhs', 'pss', 'BKS_TUG', 'cbd', 'cyj', 'KYB_TUG', 'LKO_TUG', 'kw', 'JJS_TUG', 'PSM_TUG', 'PCW_TUG', 'RJD_TUG', 'LJS_TUG', 'BYS_TUG', 'lhs', 'SOS_TUG', 'KYS3_TUG', 'cyj2'] 64
#
#
#  No-fold --- (arbitrary) 	 [results]
# 	 Train 명:  10
# 	 Valid 명:  3
# 	 Test 명:  4
#  No-fold --- (arbitrary) 	 [results]
# 	 Train:  ['bys_tug', 'bys', 'cyj2', 'kch', 'kyh', 'yjh', 'lhs', 'jet', 'cbd_tug', 'jdh']
# 	 Valid:  ['cbd', 'pss', 'nhs']
# 	 Test:  ['cyj', 'cyj_tug', 'kw', 'pjh']

# %%
def get_rawData(csvFile):
    interCheck = False
    continuous_errorVal_Check = 30

    csv_data_ = np.loadtxt(csvFile, delimiter=',', dtype=str, skiprows=2, usecols=(0,1,2,3)) 
    frameNum = csv_data_[:,0].astype(np.int)  # int로 type conversion
    max_frame = len(frameNum)
    
    rawPelvis_x = np.array(frameNum).astype(np.float32)
    rawPelvis_y = np.array(frameNum).astype(np.float32)
    rawPelvis_z = np.array(frameNum).astype(np.float32)
    

    #--- if have "empty value" ---- Interpolation  
    for i, v in enumerate(csv_data_[:, 1]):
        if v == " ": 
            interCheck = True
            csv_data_[i,1] = np.nan
            csv_data_[i,2] = np.nan
            csv_data_[i,3] = np.nan
        rawPelvis_x[i] = csv_data_[i, 1].astype(np.float32)
        rawPelvis_y[i] = csv_data_[i, 2].astype(np.float32)
        rawPelvis_z[i] = csv_data_[i, 3].astype(np.float32)
  
    if interCheck: 
        w_x = np.isnan(rawPelvis_x) 
        rawPelvis_x[w_x] = 0
        Fx = UnivariateSpline(frameNum,rawPelvis_x,w=~w_x)
        newPelvis_x = Fx(frameNum)

        w_y = np.isnan(rawPelvis_y) 
        rawPelvis_y[w_y] = 0
        Fy = UnivariateSpline(frameNum,rawPelvis_y,w=~w_y)
        newPelvis_y = Fy(frameNum)

        w_z = np.isnan(rawPelvis_z) 
        rawPelvis_z[w_z] = 0
        Fz = UnivariateSpline(frameNum,rawPelvis_z,w=~w_z)
        newPelvis_z = Fz(frameNum)

    else:
        newPelvis_x = rawPelvis_x
        newPelvis_y = rawPelvis_y
        newPelvis_z = rawPelvis_z
   

    if np.max(newPelvis_z) >= 5000:
        # ----------- if have garbage value (not "empty..") ... 
        for i in range(continuous_errorVal_Check): # 30 
            newPelvis_x[np.where(np.abs(newPelvis_x[1+i:]-newPelvis_x[:-(1+i)]) > 100)[0]] = newPelvis_x[np.where(np.abs(newPelvis_x[1+i:]-newPelvis_x[:-(1+i)]) > 100)[0]-1]
            newPelvis_y[np.where(np.abs(newPelvis_y[1+i:]-newPelvis_y[:-(1+i)]) > 100)[0]] = newPelvis_y[np.where(np.abs(newPelvis_y[1+i:]-newPelvis_y[:-(1+i)]) > 100)[0]-1]
            newPelvis_z[np.where(np.abs(newPelvis_z[1+i:]-newPelvis_z[:-(1+i)]) > 100)[0]] = newPelvis_z[np.where(np.abs(newPelvis_z[1+i:]-newPelvis_z[:-(1+i)]) > 100)[0]-1]

    
    timeData = np.loadtxt(csvFile, delimiter=',', skiprows=2, dtype=np.float32, usecols=[97, 98, 99, 100]) #  # skiprows=2 (header + first data.. 가끔 첫 줄 data 이상함)
    timestamp_diff_msec = np.array([rawPelvis_x])
    for i in range(max_frame):
        before_time_msec = timeData[i-1, 0] * 60 * 60 * 1000 + timeData[i-1, 1] * 60 * 1000 +  timeData[i-1, 2] * 1000 + timeData[i-1, 3] 
        current_time_msec = timeData[i, 0] * 60 * 60 * 1000 + timeData[i, 1] * 60 * 1000 + timeData[i, 2] * 1000 + timeData[i, 3]
        if i is 0:
            timestamp_diff_msec[0, i] = 0
        else:
            timestamp_diff_msec[0, i] = int(current_time_msec - before_time_msec)
                            
        time_sum_msec = 0
        eachTimestamp_sec = np.array(frameNum, dtype=float) # sec (?,1)
        for timeIdx in range(timestamp_diff_msec.shape[1]):
            time_sum_msec = int(time_sum_msec + timestamp_diff_msec[0, timeIdx])
            eachTimestamp_sec[timeIdx] = time_sum_msec / 1000  
  
    return frameNum, eachTimestamp_sec, newPelvis_x, newPelvis_y, newPelvis_z

    
def get_normData(pelvis_x, pelvis_y, pelvis_z, normMethod = 'min_max'):    
    if normMethod == "min_max":
        normPelvis_x = (pelvis_x -np.min(pelvis_x)) / ( np.max(pelvis_x) - np.min(pelvis_x))
        normPelvis_y = (pelvis_y -np.min(pelvis_y)) / ( np.max(pelvis_y) - np.min(pelvis_y))
        normPelvis_z = (pelvis_z -np.min(pelvis_z)) / ( np.max(pelvis_z) - np.min(pelvis_z))
        
    elif normMethod == "z_score":
        normPelvis_x = (pelvis_x -np.mean(pelvis_x)) / np.std(pelvis_x)
        normPelvis_y = (pelvis_y -np.mean(pelvis_y)) / np.std(pelvis_y)
        normPelvis_z = (pelvis_z -np.mean(pelvis_z)) / np.std(pelvis_z)
        
    return normPelvis_x, normPelvis_y, normPelvis_z

def get_LPFData(pelvis_x, pelvis_y, pelvis_z, cutoff_freq = 0.5, order=1):
    sampling_freq = 30
    number_of_samples = len(pelvis_y)
    normalized_cutoff_freq = 2 * cutoff_freq / sampling_freq
    numerator_coeffs, denominator_coeffs = butter(order, normalized_cutoff_freq)
    Filtered_x = filtfilt(numerator_coeffs, denominator_coeffs, pelvis_x)  # Phase shift 없음
    Filtered_y = filtfilt(numerator_coeffs, denominator_coeffs, pelvis_y)
    Filtered_z = filtfilt(numerator_coeffs, denominator_coeffs, pelvis_z)
    return Filtered_x, Filtered_y, Filtered_z


def getLPF_PelvisData(csvFile):
    rawData = np.loadtxt(csvFile, delimiter=",")
    timestamp = rawData[:,0]
    pelvis_x = rawData[:,1]
    pelvis_y = rawData[:,2]
    pelvis_z = rawData[:,3]
    actionList = rawData[:,4:]
    return timestamp, pelvis_x, pelvis_y, pelvis_z, actionList

  
def pltSkeleton(timeSec, pelvis_x, pelvis_y, pelvis_z, saveDir, saveFile,  actLabel, addFolder="raw", actSplit=False, save=True):
    fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(8, 7))
    title = addFolder + "_" + saveFile
    ax[0].set_title(title)
    ax[0].set_ylabel('Side axis(X) of Pelvis [mm]')
    ax[1].set_ylabel('Vertical axis(Y) of Pelvis [mm]')
    ax[2].set_ylabel('Depth Axis of Pelvis [mm]')
    ax[2].set_xlabel('Time [Sec]')
    ax[0].plot(timeSec, pelvis_x, "r--", lw=1, label="pelvis_x")
    ax[1].plot(timeSec, pelvis_y, "g--", lw=1, label="pelvis_y")
    ax[2].plot(timeSec, pelvis_z, "b--", lw=1, label="pelvis_z")
    
    if actSplit:
        for i in range(3):
            if i ==0:
                ax[i].axvline(x=timeSec[actLabel[0]], color='r', linestyle="--", linewidth=3, label="start move")
                ax[i].axvline(x=timeSec[actLabel[1]], color='r', linestyle=":", linewidth=3, label="start walk")
                
                ax[i].axvline(x=timeSec[actLabel[2]], color='k', linestyle="--", linewidth=3, label="start turn")
                ax[i].axvline(x=timeSec[actLabel[3]], color='k', linestyle=":", linewidth=3, label="end turn")
                
                ax[i].axvline(x=timeSec[actLabel[4]], color='g', linestyle="--", linewidth=3, label="start sit")
                ax[i].axvline(x=timeSec[actLabel[5]], color='g', linestyle=":", linewidth=3, label="end sit")
            else:
                ax[i].axvline(x=timeSec[actLabel[0]], color='r', linestyle="--", linewidth=3)
                ax[i].axvline(x=timeSec[actLabel[1]], color='k', linestyle="--", linewidth=3)
                ax[i].axvline(x=timeSec[actLabel[2]], color='g', linestyle="--", linewidth=3)

                ax[i].axvline(x=timeSec[actLabel[3]], color='r', linestyle=":", linewidth=3)
                ax[i].axvline(x=timeSec[actLabel[4]], color='k', linestyle=":", linewidth=3)
                ax[i].axvline(x=timeSec[actLabel[5]], color='g', linestyle=":", linewidth=3)

    fig.legend()
    plt.show()
    
    if save:
        if  os.path.isfile(saveDir+"/"+title):
            os.remove(saveDir+"/"+title)
        fig.savefig(saveDir+"/"+title)
    plt.close()

# %%
def get_actFrameNumber(csvFile): 
    actFrame = []
    with open(csvFile, 'r', encoding='utf-8') as readCSV:
        data = readCSV.read()
        lines = data.split("\n") # lines[0] = header, [1] = act label data
        tmpLabel = lines[1].split(",")
       
        for i in range(len(tmpLabel)):           
            actFrame.append( int(tmpLabel[i].split("_")[1].split(".")[0]) ) 
        return actFrame   
    
def sliding_window(timestamp, data_x, data_y, lookback_window=8):
    time = []
    x = []
    y = []
    enc = MinMaxScaler(feature_range = (0, 1))
    enc_y = enc.fit_transform(data_y)
    for i in range(lookback_window, len(data_x)+1):
        time.append(timestamp[i-1])
        x.append(data_x[i - lookback_window:i])
        y.append(data_y[i-1])
  
    x = np.array(x)
    x = x.reshape(-1, lookback_window, numPelvis, 1)
    
    y = np.array(y)
    time = np.array(time)
   
    return time, x, y, enc

#------------------ Origin... sit, sit-to-stand, walk, turn, stand-to-sit (5action)
def convert_act2oneHot(actFrame, frameNum):
    actionList = []
    for timeIdx in range(len(frameNum)):
        if (timeIdx < actFrame[0]):  # frame Num < move start fram (sit)
            actionList.append(np.array([1, 0, 0, 0, 0],dtype=np.int))
                    # moveStartIdx ~ startWalk 까지 (sit-to-stand)
        elif (timeIdx >= actFrame[0]) and (timeIdx < actFrame[1]):
            actionList.append(np.array([0, 1, 0, 0, 0],dtype=np.int))
                    # startWalk ~ turnStartIdx 까지 (walk)
        elif (timeIdx >= actFrame[1]) and (timeIdx < actFrame[2]):
            actionList.append(np.array([0, 0, 1, 0, 0],dtype=np.int))
                    # turnStartIdx ~ turnEndIdx 까지 (turn)
        elif (timeIdx >= actFrame[2]) and (timeIdx < actFrame[3]):
            actionList.append(np.array([0, 0, 0, 1, 0],dtype=np.int))
                    # turnEndIdx ~ startSitIdx 까지 (walk)
        elif (timeIdx >= actFrame[3]) and (timeIdx < actFrame[4]):
            actionList.append(np.array([0, 0, 1, 0, 0],dtype=np.int))
                    # startSitIdx ~ moveEndIdx 까지 (stand-to-sit)
        elif (timeIdx >= actFrame[4]) and (timeIdx < actFrame[5]):
            actionList.append(np.array([0, 0, 0, 0, 1],dtype=np.int))
            
        elif (timeIdx >= actFrame[5]):
            actionList.append(np.array([1, 0, 0, 0, 0],dtype=np.int))
        
            
        else:
            AssertionError("Check getLabel_forEveryTrial func. in utils_labeling_all")
        oneTrial_actionList = np.array(actionList)
    return np.array(oneTrial_actionList)

# %%
def readLPF_createDataset(train_subjects, test_subjects, lookback_window = 8):
    train_x = np.zeros((0, lookback_window,numPelvis , 1)) 
    train_y = np.zeros((0, numActions))
    
    valid_x = np.zeros((0, lookback_window, numPelvis, 1))
    valid_y = np.zeros((0, numActions))
    
    test_x = np.zeros((0, lookback_window, numPelvis,1 ))
    test_y = np.zeros((0, numActions)) 
    
    total_Trials = 0
    for dirpath, foldername, files in sorted(os.walk(datasetDir)):
        actPath = None
        pelvisPath= None
        actFrame = []
        if ".ipynb_checkpoints" in dirpath:
            continue
        else:
            for filename in sorted(files):
                if ".csv" in filename:
                    if "Originact5_lpf_" in filename:     # 
                        pelvisPath = dirpath    
                        subname = dirpath.split("/")[-2] 
                        pelvis_csv = os.path.join(dirpath, filename)

                        timstamp_ms, lpfPelvis_x, lpfPelvis_y, lpfPelvis_z, oneHot_actionList  = getLPF_PelvisData(pelvis_csv)  # raw                 
     
                        
                        total_Trials +=1   
  
                        pelvisData = np.array([lpfPelvis_x, lpfPelvis_y, lpfPelvis_z]).T  # (335,3) 
                        actionData = np.array(oneHot_actionList)    # # (335, 5)
                            
                        blockTime, blockPelvis, blockLable, enc = sliding_window(timstamp_ms, data_x = pelvisData, data_y = actionData, lookback_window=lookback_window) # pelvis - (327, 8, 3)
#                         print(dirpath, "\t", blockLable.shape)
                        if Kfold is not True:
                            if subname in train_subjects:
                                train_x = np.append(train_x, blockPelvis, axis = 0 )
                                train_y = np.append(train_y, blockLable, axis = 0 )

                            elif subname in valid_subjects:
                                valid_x = np.append(valid_x, blockPelvis, axis = 0 )
                                valid_y = np.append(valid_y, blockLable, axis = 0 )

                            elif subname in test_subjects:
                                test_x = np.append(test_x, blockPelvis, axis = 0 )
                                test_y = np.append(test_y, blockLable, axis = 0 )    
                        else:
                            if subname in train_subjects:
                                train_x = np.append(train_x, blockPelvis, axis = 0 )
                                train_y = np.append(train_y, blockLable, axis = 0 )
                            elif subname in test_subjects:
                                test_x = np.append(test_x, blockPelvis, axis = 0 )
                                test_y = np.append(test_y, blockLable, axis = 0 )  

    return total_Trials, train_x, train_y, valid_x, valid_y, test_x, test_y




def readRaw_createDataset(train_subjects, test_subjects, lookback_window = 8):
    train_x = np.zeros((0, lookback_window, numPelvis , 1)) 
    train_y = np.zeros((0, numActions))
    
    valid_x = np.zeros((0, lookback_window, numPelvis, 1))
    valid_y = np.zeros((0, numActions))
    
    test_x = np.zeros((0, lookback_window, numPelvis,1 ))
    test_y = np.zeros((0, numActions)) 
    
    total_Trials = 0
    for dirpath, foldername, files in sorted(os.walk(datasetDir)):
        clear_output(wait=True)
        actPath = None
        pelvisPath= None
        actFrame = []
        if ".ipynb_checkpoints" in dirpath:
            continue
        else:
            for filename in sorted(files):
                if ".csv" in filename:
                    if "label_" in filename:
                        labelPath = dirpath
                        label_csv = os.path.join(labelPath,filename)
                        actFrame = get_actFrameNumber( label_csv)

                    if "skeleton_" in filename:          
                        pelvisPath = dirpath    
                        subname = dirpath.split("/")[-2] 
                        pelvis_csv = os.path.join(dirpath, filename)

                        frameNum, timstamp_ms, pelvis_x, pelvis_y, pelvis_z  = get_rawData(pelvis_csv)  # raw                 
                        normPelvis_x, normPelvis_y, normPelvis_z = get_normData(pelvis_x, pelvis_y, pelvis_z, normMethod = 'min_max') # norm         
                        lpfPelvis_x, lpfPelvis_y, lpfPelvis_z = get_LPFData(normPelvis_x, normPelvis_y, normPelvis_z, cutoff_freq=0.5, order=1)  # lpf 
                    
                        total_Trials +=1   
                        
                        if labelPath == pelvisPath:  
                            oneHot_actionList = convert_act2oneHot(actFrame, frameNum)
                            
                            pelvisData = np.array([lpfPelvis_x, lpfPelvis_y, lpfPelvis_z]).T  # (335,3) 
                            actionData = np.array(oneHot_actionList)    # # (335, 5)
                            
                            blockTime, blockPelvis, blockLable, enc = sliding_window(timstamp_ms, data_x = pelvisData, data_y = actionData, lookback_window=lookback_window) # pelvis - (327, 8, 3)
                            
                            
                            if Kfold is not True:
                                if subname in train_subjects:
                                    train_x = np.append(train_x, blockPelvis, axis = 0 )
                                    train_y = np.append(train_y, blockLable, axis = 0 )

                                elif subname in valid_subjects:
                                    valid_x = np.append(valid_x, blockPelvis, axis = 0 )
                                    valid_y = np.append(valid_y, blockLable, axis = 0 )

                                elif subname in test_subjects:
                                    test_x = np.append(test_x, blockPelvis, axis = 0 )
                                    test_y = np.append(test_y, blockLable, axis = 0 )    
                            else:
                                if subname in train_subjects:
                                    train_x = np.append(train_x, blockPelvis, axis = 0 )
                                    train_y = np.append(train_y, blockLable, axis = 0 )
                                elif subname in test_subjects:
                                    test_x = np.append(test_x, blockPelvis, axis = 0 )
                                    test_y = np.append(test_y, blockLable, axis = 0 )  

    return total_Trials, train_x, train_y, valid_x, valid_y, test_x, test_y

# %%
lookback_window = 8

# total_Trials, train_x, train_y, valid_x, valid_y, test_x, test_y =  readRaw_createDataset(train_subjects, test_subjects, lookback_window = lookback_window)
total_Trials, train_x, train_y, valid_x, valid_y, test_x, test_y =  readLPF_createDataset(train_subjects, test_subjects, lookback_window = lookback_window)
print("train_x: ", train_x.shape," , train_y: ", train_y.shape)
print("valid_x: ",valid_x.shape, " , valid_y: ",valid_y.shape)
print("test_x: ",test_x.shape, "  , test_y: ",test_y.shape)
# Out:
# train_x:  (34129, 8, 3, 1)  , train_y:  (34129, 5)
# valid_x:  (12033, 8, 3, 1)  , valid_y:  (12033, 5)
# test_x:  (13994, 8, 3, 1)   , test_y:  (13994, 5)

# %% [markdown]
# ### Model Build

# %%
from keras.layers import Conv1D, Input, Activation, Flatten, Dense, Conv2D
from keras.layers import BatchNormalization, add , Dropout
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tcn import TCN

# %%
ModelTime =  time.strftime('%Y%m%d-Time_%H-%M', time.localtime(time.time())) +  "/Model" 
MODEL_SAVE_FOLDER_PATH ="/DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results" + expertFolder +"/" + ModelTime

print(MODEL_SAVE_FOLDER_PATH)
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.makedirs(MODEL_SAVE_FOLDER_PATH)
    
model_path = MODEL_SAVE_FOLDER_PATH + "LookBack- "+ str(lookback_window) +" Origin" + "{epoch:04d} ---- {val_loss: .4f}.hdf5"
patience = 50

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor="val_loss", verbose=1, save_best_only=True)
cb_early_stopping = EarlyStopping(monitor="val_loss", patience=patience)
# Out:
# /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/Model

# %%
 #Residual block :: https://roadcom.tistory.com/95
def ResBlock(x,filters,kernel_size,dilation_rate):
    r=Conv2D(filters,kernel_size=kernel_size,padding='same',dilation_rate=dilation_rate,activation='relu')(x) #first convolution
    r=Conv2D(filters,kernel_size=kernel_size,padding='same',dilation_rate=dilation_rate)(r) #Second convolution
    if x.shape[-1]==filters:
        # Shortcut 의 channel 과 main path 의 channel 이 일치할 경우 단순 add 연산만 진행하는 블록 = identity block
        shortcut = x  # identity block 
    else: 
        # Shortcut 의 channel 과 main path 의 channel 이 다를 경우 shortcut path 를 적절히 변환
        # 즉, projection 을 통해 channel 을 맞춰주는 작업이(projection shortcut) 추가되기에 이를 convolution block 이라함
        shortcut=Conv2D(filters,kernel_size=kernel_size,padding='same')(x) 
    o=add([r,shortcut])
    o=Activation('relu')(o) 
    return o
 
 #Sequence Model
def TCN(optimizer='adam'):
    kernel_size = (3,3)
    input_shape =  (lookback_window, 3, 1) # (8,3, 1) = (feature, sliding_window, 1)
    
    inputs=Input(shape=input_shape)
    
    x=ResBlock(x = inputs,filters=32,kernel_size=kernel_size,dilation_rate=1)
    x = Dropout(0.2) (x)
    x=ResBlock(x,filters=32,kernel_size=kernel_size,dilation_rate=2)
    x = Dropout(0.4)(x)
    x=ResBlock(x,filters=16,kernel_size=kernel_size,dilation_rate=4)
    
    x=Flatten()(x)
    x=Dense(numActions, activation='softmax')(x)
    model=Model(inputs=inputs,outputs=x)
         
    model.summary()
        
    model.compile(optimizer=optimizer,loss='categorical_crossentropy', metrics=['accuracy'])
 
    return model

# %%
# (feature, sliding_window, 1) ...TCN,,,  
class_weight = {0:0.303, 1:1.0, 2: 0.144, 3:0.487, 4: 0.7}

batch_size = 512
epochs = 100000
# learning_rate = 0.00005

learning_rate = 0.00009

optimizer = tf.optimizers.Adam(learning_rate)

model = TCN(optimizer)
model.save(MODEL_SAVE_FOLDER_PATH+"/Origin_TCN_model")
hist = model.fit(train_x,train_y, batch_size= batch_size, epochs=epochs,verbose=2, validation_data= (valid_x, valid_y),   callbacks=[cb_checkpoint, cb_early_stopping], class_weight=class_weight)
eval_result = model.evaluate(test_x, test_y,batch_size= batch_size,verbose=2)

print('test_loss:',eval_result[0],'- test_acc:',eval_result[1])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8, 3, 1)]    0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 8, 3, 32)     320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 3, 32)     9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 3, 32)     320         input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8, 3, 32)     0           conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 8, 3, 32)     0           add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 8, 3, 32)     0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 3, 32)     9248        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 3, 32)     9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 3, 32)     0           conv2d_4[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8, 3, 32)     0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 3, 32)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 3, 16)     4624        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 3, 16)     2320        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 3, 16)     4624        dropout_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 3, 16)     0           conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 8, 3, 16)     0           add_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 384)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 5)            1925        flatten[0][0]
# ==================================================================================================
# Total params: 41,877
# Trainable params: 41,877
# Non-trainable params: 0
# __________________________________________________________________________________________________
# INFO:tensorflow:Assets written to: /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/Model/Origin_TCN_model/assets
# Epoch 1/100000
# 67/67 - 93s - loss: 0.5067 - accuracy: 0.3127 - val_loss: 1.4571 - val_accuracy: 0.4496
#
# Epoch 00001: val_loss improved from inf to 1.45713, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0001 ----  1.4571.hdf5
# Epoch 2/100000
# 67/67 - 0s - loss: 0.4375 - accuracy: 0.5211 - val_loss: 1.1154 - val_accuracy: 0.6444
#
# Epoch 00002: val_loss improved from 1.45713 to 1.11540, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0002 ----  1.1154.hdf5
# Epoch 3/100000
# 67/67 - 0s - loss: 0.3275 - accuracy: 0.6471 - val_loss: 0.7703 - val_accuracy: 0.7064
#
# Epoch 00003: val_loss improved from 1.11540 to 0.77031, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0003 ----  0.7703.hdf5
# Epoch 4/100000
# 67/67 - 0s - loss: 0.2459 - accuracy: 0.7276 - val_loss: 0.5504 - val_accuracy: 0.8381
#
# Epoch 00004: val_loss improved from 0.77031 to 0.55036, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0004 ----  0.5504.hdf5
# Epoch 5/100000
# 67/67 - 0s - loss: 0.2060 - accuracy: 0.8048 - val_loss: 0.4257 - val_accuracy: 0.8868
#
# Epoch 00005: val_loss improved from 0.55036 to 0.42566, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0005 ----  0.4257.hdf5
# Epoch 6/100000
# 67/67 - 0s - loss: 0.1814 - accuracy: 0.8437 - val_loss: 0.3828 - val_accuracy: 0.8945
#
# Epoch 00006: val_loss improved from 0.42566 to 0.38281, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0006 ----  0.3828.hdf5
# Epoch 7/100000
# 67/67 - 0s - loss: 0.1621 - accuracy: 0.8678 - val_loss: 0.2933 - val_accuracy: 0.9161
#
# Epoch 00007: val_loss improved from 0.38281 to 0.29329, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0007 ----  0.2933.hdf5
# Epoch 8/100000
# 67/67 - 0s - loss: 0.1500 - accuracy: 0.8791 - val_loss: 0.3077 - val_accuracy: 0.9086
#
# Epoch 00008: val_loss did not improve from 0.29329
# Epoch 9/100000
# 67/67 - 0s - loss: 0.1396 - accuracy: 0.8863 - val_loss: 0.2890 - val_accuracy: 0.9155
#
# Epoch 00009: val_loss improved from 0.29329 to 0.28896, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0009 ----  0.2890.hdf5
# Epoch 10/100000
# 67/67 - 0s - loss: 0.1319 - accuracy: 0.8936 - val_loss: 0.2585 - val_accuracy: 0.9230
#
# Epoch 00010: val_loss improved from 0.28896 to 0.25854, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0010 ----  0.2585.hdf5
# Epoch 11/100000
# 67/67 - 0s - loss: 0.1233 - accuracy: 0.8999 - val_loss: 0.2547 - val_accuracy: 0.9242
#
# Epoch 00011: val_loss improved from 0.25854 to 0.25473, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0011 ----  0.2547.hdf5
# Epoch 12/100000
# 67/67 - 0s - loss: 0.1175 - accuracy: 0.9027 - val_loss: 0.2349 - val_accuracy: 0.9255
#
# Epoch 00012: val_loss improved from 0.25473 to 0.23491, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0012 ----  0.2349.hdf5
# Epoch 13/100000
# 67/67 - 0s - loss: 0.1133 - accuracy: 0.9042 - val_loss: 0.2272 - val_accuracy: 0.9288
#
# Epoch 00013: val_loss improved from 0.23491 to 0.22715, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0013 ----  0.2272.hdf5
# Epoch 14/100000
# 67/67 - 0s - loss: 0.1078 - accuracy: 0.9064 - val_loss: 0.2327 - val_accuracy: 0.9258
#
# Epoch 00014: val_loss did not improve from 0.22715
# Epoch 15/100000
# 67/67 - 0s - loss: 0.1061 - accuracy: 0.9093 - val_loss: 0.2330 - val_accuracy: 0.9206
#
# Epoch 00015: val_loss did not improve from 0.22715
# Epoch 16/100000
# 67/67 - 0s - loss: 0.1016 - accuracy: 0.9115 - val_loss: 0.2173 - val_accuracy: 0.9283
#
# Epoch 00016: val_loss improved from 0.22715 to 0.21729, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0016 ----  0.2173.hdf5
# Epoch 17/100000
# 67/67 - 0s - loss: 0.1005 - accuracy: 0.9131 - val_loss: 0.2164 - val_accuracy: 0.9279
#
# Epoch 00017: val_loss improved from 0.21729 to 0.21636, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0017 ----  0.2164.hdf5
# Epoch 18/100000
# 67/67 - 0s - loss: 0.0972 - accuracy: 0.9139 - val_loss: 0.2145 - val_accuracy: 0.9289
#
# Epoch 00018: val_loss improved from 0.21636 to 0.21451, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0018 ----  0.2145.hdf5
# Epoch 19/100000
# 67/67 - 0s - loss: 0.0952 - accuracy: 0.9166 - val_loss: 0.1939 - val_accuracy: 0.9381
#
# Epoch 00019: val_loss improved from 0.21451 to 0.19386, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0019 ----  0.1939.hdf5
# Epoch 20/100000
# 67/67 - 0s - loss: 0.0940 - accuracy: 0.9156 - val_loss: 0.2433 - val_accuracy: 0.9200
#
# Epoch 00020: val_loss did not improve from 0.19386
# Epoch 21/100000
# 67/67 - 0s - loss: 0.0913 - accuracy: 0.9159 - val_loss: 0.2105 - val_accuracy: 0.9307
#
# Epoch 00021: val_loss did not improve from 0.19386
# Epoch 22/100000
# 67/67 - 0s - loss: 0.0915 - accuracy: 0.9166 - val_loss: 0.2417 - val_accuracy: 0.9177
#
# Epoch 00022: val_loss did not improve from 0.19386
# Epoch 23/100000
# 67/67 - 0s - loss: 0.0897 - accuracy: 0.9197 - val_loss: 0.1817 - val_accuracy: 0.9416
#
# Epoch 00023: val_loss improved from 0.19386 to 0.18170, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0023 ----  0.1817.hdf5
# Epoch 24/100000
# 67/67 - 0s - loss: 0.0880 - accuracy: 0.9223 - val_loss: 0.1881 - val_accuracy: 0.9381
#
# Epoch 00024: val_loss did not improve from 0.18170
# Epoch 25/100000
# 67/67 - 0s - loss: 0.0880 - accuracy: 0.9208 - val_loss: 0.1913 - val_accuracy: 0.9374
#
# Epoch 00025: val_loss did not improve from 0.18170
# Epoch 26/100000
# 67/67 - 0s - loss: 0.0864 - accuracy: 0.9219 - val_loss: 0.2155 - val_accuracy: 0.9318
#
# Epoch 00026: val_loss did not improve from 0.18170
# Epoch 27/100000
# 67/67 - 0s - loss: 0.0852 - accuracy: 0.9236 - val_loss: 0.1930 - val_accuracy: 0.9347
#
# Epoch 00027: val_loss did not improve from 0.18170
# Epoch 28/100000
# 67/67 - 0s - loss: 0.0843 - accuracy: 0.9235 - val_loss: 0.2094 - val_accuracy: 0.9308
#
# Epoch 00028: val_loss did not improve from 0.18170
# Epoch 29/100000
# 67/67 - 0s - loss: 0.0845 - accuracy: 0.9225 - val_loss: 0.2021 - val_accuracy: 0.9322
#
# Epoch 00029: val_loss did not improve from 0.18170
# Epoch 30/100000
# 67/67 - 0s - loss: 0.0832 - accuracy: 0.9247 - val_loss: 0.1796 - val_accuracy: 0.9405
#
# Epoch 00030: val_loss improved from 0.18170 to 0.17961, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0030 ----  0.1796.hdf5
# Epoch 31/100000
# 67/67 - 0s - loss: 0.0829 - accuracy: 0.9244 - val_loss: 0.2126 - val_accuracy: 0.9294
#
# Epoch 00031: val_loss did not improve from 0.17961
# Epoch 32/100000
# 67/67 - 0s - loss: 0.0824 - accuracy: 0.9250 - val_loss: 0.1980 - val_accuracy: 0.9343
#
# Epoch 00032: val_loss did not improve from 0.17961
# Epoch 33/100000
# 67/67 - 0s - loss: 0.0803 - accuracy: 0.9266 - val_loss: 0.1983 - val_accuracy: 0.9337
#
# Epoch 00033: val_loss did not improve from 0.17961
# Epoch 34/100000
# 67/67 - 0s - loss: 0.0803 - accuracy: 0.9273 - val_loss: 0.1924 - val_accuracy: 0.9357
#
# Epoch 00034: val_loss did not improve from 0.17961
# Epoch 35/100000
# 67/67 - 0s - loss: 0.0808 - accuracy: 0.9259 - val_loss: 0.2053 - val_accuracy: 0.9304
#
# Epoch 00035: val_loss did not improve from 0.17961
# Epoch 36/100000
# 67/67 - 0s - loss: 0.0786 - accuracy: 0.9273 - val_loss: 0.1865 - val_accuracy: 0.9364
#
# Epoch 00036: val_loss did not improve from 0.17961
# Epoch 37/100000
# 67/67 - 0s - loss: 0.0782 - accuracy: 0.9283 - val_loss: 0.2050 - val_accuracy: 0.9303
#
# Epoch 00037: val_loss did not improve from 0.17961
# Epoch 38/100000
# 67/67 - 0s - loss: 0.0776 - accuracy: 0.9277 - val_loss: 0.1882 - val_accuracy: 0.9370
#
# Epoch 00038: val_loss did not improve from 0.17961
# Epoch 39/100000
# 67/67 - 0s - loss: 0.0786 - accuracy: 0.9286 - val_loss: 0.2000 - val_accuracy: 0.9317
#
# Epoch 00039: val_loss did not improve from 0.17961
# Epoch 40/100000
# 67/67 - 0s - loss: 0.0776 - accuracy: 0.9283 - val_loss: 0.2014 - val_accuracy: 0.9319
#
# Epoch 00040: val_loss did not improve from 0.17961
# Epoch 41/100000
# 67/67 - 0s - loss: 0.0754 - accuracy: 0.9292 - val_loss: 0.2143 - val_accuracy: 0.9250
#
# Epoch 00041: val_loss did not improve from 0.17961
# Epoch 42/100000
# 67/67 - 0s - loss: 0.0759 - accuracy: 0.9303 - val_loss: 0.2020 - val_accuracy: 0.9317
#
# Epoch 00042: val_loss did not improve from 0.17961
# Epoch 43/100000
# 67/67 - 0s - loss: 0.0756 - accuracy: 0.9295 - val_loss: 0.1975 - val_accuracy: 0.9323
#
# Epoch 00043: val_loss did not improve from 0.17961
# Epoch 44/100000
# 67/67 - 0s - loss: 0.0760 - accuracy: 0.9302 - val_loss: 0.1922 - val_accuracy: 0.9334
#
# Epoch 00044: val_loss did not improve from 0.17961
# Epoch 45/100000
# 67/67 - 0s - loss: 0.0744 - accuracy: 0.9292 - val_loss: 0.1849 - val_accuracy: 0.9378
#
# Epoch 00045: val_loss did not improve from 0.17961
# Epoch 46/100000
# 67/67 - 0s - loss: 0.0731 - accuracy: 0.9313 - val_loss: 0.2046 - val_accuracy: 0.9306
#
# Epoch 00046: val_loss did not improve from 0.17961
# Epoch 47/100000
# 67/67 - 0s - loss: 0.0728 - accuracy: 0.9311 - val_loss: 0.1948 - val_accuracy: 0.9342
#
# Epoch 00047: val_loss did not improve from 0.17961
# Epoch 48/100000
# 67/67 - 0s - loss: 0.0726 - accuracy: 0.9322 - val_loss: 0.1922 - val_accuracy: 0.9343
#
# Epoch 00048: val_loss did not improve from 0.17961
# Epoch 49/100000
# 67/67 - 0s - loss: 0.0714 - accuracy: 0.9342 - val_loss: 0.2034 - val_accuracy: 0.9299
#
# Epoch 00049: val_loss did not improve from 0.17961
# Epoch 50/100000
# 67/67 - 0s - loss: 0.0717 - accuracy: 0.9311 - val_loss: 0.1946 - val_accuracy: 0.9326
#
# Epoch 00050: val_loss did not improve from 0.17961
# Epoch 51/100000
# 67/67 - 0s - loss: 0.0712 - accuracy: 0.9339 - val_loss: 0.1961 - val_accuracy: 0.9332
#
# Epoch 00051: val_loss did not improve from 0.17961
# Epoch 52/100000
# 67/67 - 0s - loss: 0.0712 - accuracy: 0.9325 - val_loss: 0.1982 - val_accuracy: 0.9314
#
# Epoch 00052: val_loss did not improve from 0.17961
# Epoch 53/100000
# 67/67 - 0s - loss: 0.0702 - accuracy: 0.9335 - val_loss: 0.1980 - val_accuracy: 0.9308
#
# Epoch 00053: val_loss did not improve from 0.17961
# Epoch 54/100000
# 67/67 - 0s - loss: 0.0702 - accuracy: 0.9342 - val_loss: 0.1934 - val_accuracy: 0.9344
#
# Epoch 00054: val_loss did not improve from 0.17961
# Epoch 55/100000
# 67/67 - 0s - loss: 0.0700 - accuracy: 0.9335 - val_loss: 0.2011 - val_accuracy: 0.9294
#
# Epoch 00055: val_loss did not improve from 0.17961
# Epoch 56/100000
# 67/67 - 0s - loss: 0.0698 - accuracy: 0.9317 - val_loss: 0.1904 - val_accuracy: 0.9362
#
# Epoch 00056: val_loss did not improve from 0.17961
# Epoch 57/100000
# 67/67 - 0s - loss: 0.0696 - accuracy: 0.9322 - val_loss: 0.1842 - val_accuracy: 0.9359
#
# Epoch 00057: val_loss did not improve from 0.17961
# Epoch 58/100000
# 67/67 - 0s - loss: 0.0698 - accuracy: 0.9326 - val_loss: 0.1864 - val_accuracy: 0.9357
#
# Epoch 00058: val_loss did not improve from 0.17961
# Epoch 59/100000
# 67/67 - 0s - loss: 0.0686 - accuracy: 0.9338 - val_loss: 0.1911 - val_accuracy: 0.9323
#
# Epoch 00059: val_loss did not improve from 0.17961
# Epoch 60/100000
# 67/67 - 0s - loss: 0.0689 - accuracy: 0.9338 - val_loss: 0.2000 - val_accuracy: 0.9289
#
# Epoch 00060: val_loss did not improve from 0.17961
# Epoch 61/100000
# 67/67 - 0s - loss: 0.0681 - accuracy: 0.9340 - val_loss: 0.1749 - val_accuracy: 0.9398
#
# Epoch 00061: val_loss improved from 0.17961 to 0.17495, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0061 ----  0.1749.hdf5
# Epoch 62/100000
# 67/67 - 0s - loss: 0.0676 - accuracy: 0.9358 - val_loss: 0.1993 - val_accuracy: 0.9299
#
# Epoch 00062: val_loss did not improve from 0.17495
# Epoch 63/100000
# 67/67 - 0s - loss: 0.0663 - accuracy: 0.9357 - val_loss: 0.1993 - val_accuracy: 0.9294
#
# Epoch 00063: val_loss did not improve from 0.17495
# Epoch 64/100000
# 67/67 - 0s - loss: 0.0669 - accuracy: 0.9345 - val_loss: 0.1919 - val_accuracy: 0.9341
#
# Epoch 00064: val_loss did not improve from 0.17495
# Epoch 65/100000
# 67/67 - 0s - loss: 0.0661 - accuracy: 0.9337 - val_loss: 0.2072 - val_accuracy: 0.9280
#
# Epoch 00065: val_loss did not improve from 0.17495
# Epoch 66/100000
# 67/67 - 0s - loss: 0.0653 - accuracy: 0.9363 - val_loss: 0.1930 - val_accuracy: 0.9322
#
# Epoch 00066: val_loss did not improve from 0.17495
# Epoch 67/100000
# 67/67 - 0s - loss: 0.0651 - accuracy: 0.9357 - val_loss: 0.1917 - val_accuracy: 0.9326
#
# Epoch 00067: val_loss did not improve from 0.17495
# Epoch 68/100000
# 67/67 - 0s - loss: 0.0647 - accuracy: 0.9355 - val_loss: 0.1939 - val_accuracy: 0.9297
#
# Epoch 00068: val_loss did not improve from 0.17495
# Epoch 69/100000
# 67/67 - 0s - loss: 0.0646 - accuracy: 0.9370 - val_loss: 0.1979 - val_accuracy: 0.9316
#
# Epoch 00069: val_loss did not improve from 0.17495
# Epoch 70/100000
# 67/67 - 0s - loss: 0.0653 - accuracy: 0.9356 - val_loss: 0.1985 - val_accuracy: 0.9294
#
# Epoch 00070: val_loss did not improve from 0.17495
# Epoch 71/100000
# 67/67 - 0s - loss: 0.0648 - accuracy: 0.9367 - val_loss: 0.1726 - val_accuracy: 0.9391
#
# Epoch 00071: val_loss improved from 0.17495 to 0.17258, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0071 ----  0.1726.hdf5
# Epoch 72/100000
# 67/67 - 0s - loss: 0.0648 - accuracy: 0.9377 - val_loss: 0.1903 - val_accuracy: 0.9333
#
# Epoch 00072: val_loss did not improve from 0.17258
# Epoch 73/100000
# 67/67 - 0s - loss: 0.0633 - accuracy: 0.9386 - val_loss: 0.1924 - val_accuracy: 0.9329
#
# Epoch 00073: val_loss did not improve from 0.17258
# Epoch 74/100000
# 67/67 - 0s - loss: 0.0634 - accuracy: 0.9379 - val_loss: 0.1865 - val_accuracy: 0.9339
#
# Epoch 00074: val_loss did not improve from 0.17258
# Epoch 75/100000
# 67/67 - 0s - loss: 0.0640 - accuracy: 0.9366 - val_loss: 0.1737 - val_accuracy: 0.9393
#
# Epoch 00075: val_loss did not improve from 0.17258
# Epoch 76/100000
# 67/67 - 0s - loss: 0.0635 - accuracy: 0.9372 - val_loss: 0.2065 - val_accuracy: 0.9249
#
# Epoch 00076: val_loss did not improve from 0.17258
# Epoch 77/100000
# 67/67 - 0s - loss: 0.0636 - accuracy: 0.9363 - val_loss: 0.1835 - val_accuracy: 0.9330
#
# Epoch 00077: val_loss did not improve from 0.17258
# Epoch 78/100000
# 67/67 - 0s - loss: 0.0630 - accuracy: 0.9352 - val_loss: 0.1821 - val_accuracy: 0.9335
#
# Epoch 00078: val_loss did not improve from 0.17258
# Epoch 79/100000
# 67/67 - 0s - loss: 0.0629 - accuracy: 0.9374 - val_loss: 0.1790 - val_accuracy: 0.9380
#
# Epoch 00079: val_loss did not improve from 0.17258
# Epoch 80/100000
# 67/67 - 0s - loss: 0.0629 - accuracy: 0.9392 - val_loss: 0.1777 - val_accuracy: 0.9367
#
# Epoch 00080: val_loss did not improve from 0.17258
# Epoch 81/100000
# 67/67 - 0s - loss: 0.0619 - accuracy: 0.9374 - val_loss: 0.1803 - val_accuracy: 0.9359
#
# Epoch 00081: val_loss did not improve from 0.17258
# Epoch 82/100000
# 67/67 - 0s - loss: 0.0614 - accuracy: 0.9376 - val_loss: 0.1865 - val_accuracy: 0.9319
#
# Epoch 00082: val_loss did not improve from 0.17258
# Epoch 83/100000
# 67/67 - 0s - loss: 0.0618 - accuracy: 0.9389 - val_loss: 0.1809 - val_accuracy: 0.9337
#
# Epoch 00083: val_loss did not improve from 0.17258
# Epoch 84/100000
# 67/67 - 0s - loss: 0.0606 - accuracy: 0.9384 - val_loss: 0.1897 - val_accuracy: 0.9334
#
# Epoch 00084: val_loss did not improve from 0.17258
# Epoch 85/100000
# 67/67 - 0s - loss: 0.0606 - accuracy: 0.9379 - val_loss: 0.1966 - val_accuracy: 0.9270
#
# Epoch 00085: val_loss did not improve from 0.17258
# Epoch 86/100000
# 67/67 - 0s - loss: 0.0605 - accuracy: 0.9381 - val_loss: 0.1756 - val_accuracy: 0.9335
#
# Epoch 00086: val_loss did not improve from 0.17258
# Epoch 87/100000
# 67/67 - 0s - loss: 0.0615 - accuracy: 0.9367 - val_loss: 0.1809 - val_accuracy: 0.9333
#
# Epoch 00087: val_loss did not improve from 0.17258
# Epoch 88/100000
# 67/67 - 0s - loss: 0.0613 - accuracy: 0.9384 - val_loss: 0.2017 - val_accuracy: 0.9250
#
# Epoch 00088: val_loss did not improve from 0.17258
# Epoch 89/100000
# 67/67 - 0s - loss: 0.0606 - accuracy: 0.9372 - val_loss: 0.1855 - val_accuracy: 0.9314
#
# Epoch 00089: val_loss did not improve from 0.17258
# Epoch 90/100000
# 67/67 - 0s - loss: 0.0596 - accuracy: 0.9390 - val_loss: 0.1737 - val_accuracy: 0.9376
#
# Epoch 00090: val_loss did not improve from 0.17258
# Epoch 91/100000
# 67/67 - 0s - loss: 0.0598 - accuracy: 0.9385 - val_loss: 0.1907 - val_accuracy: 0.9289
#
# Epoch 00091: val_loss did not improve from 0.17258
# Epoch 92/100000
# 67/67 - 0s - loss: 0.0596 - accuracy: 0.9390 - val_loss: 0.1920 - val_accuracy: 0.9284
#
# Epoch 00092: val_loss did not improve from 0.17258
# Epoch 93/100000
# 67/67 - 0s - loss: 0.0597 - accuracy: 0.9390 - val_loss: 0.1863 - val_accuracy: 0.9322
#
# Epoch 00093: val_loss did not improve from 0.17258
# Epoch 94/100000
# 67/67 - 0s - loss: 0.0585 - accuracy: 0.9392 - val_loss: 0.1842 - val_accuracy: 0.9319
#
# Epoch 00094: val_loss did not improve from 0.17258
# Epoch 95/100000
# 67/67 - 0s - loss: 0.0594 - accuracy: 0.9384 - val_loss: 0.1683 - val_accuracy: 0.9390
#
# Epoch 00095: val_loss improved from 0.17258 to 0.16826, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0095 ----  0.1683.hdf5
# Epoch 96/100000
# 67/67 - 0s - loss: 0.0583 - accuracy: 0.9411 - val_loss: 0.1781 - val_accuracy: 0.9355
#
# Epoch 00096: val_loss did not improve from 0.16826
# Epoch 97/100000
# 67/67 - 0s - loss: 0.0582 - accuracy: 0.9399 - val_loss: 0.1893 - val_accuracy: 0.9317
#
# Epoch 00097: val_loss did not improve from 0.16826
# Epoch 98/100000
# 67/67 - 0s - loss: 0.0579 - accuracy: 0.9406 - val_loss: 0.1801 - val_accuracy: 0.9332
#
# Epoch 00098: val_loss did not improve from 0.16826
# Epoch 99/100000
# 67/67 - 0s - loss: 0.0574 - accuracy: 0.9399 - val_loss: 0.1850 - val_accuracy: 0.9314
#
# Epoch 00099: val_loss did not improve from 0.16826
# Epoch 100/100000
# 67/67 - 0s - loss: 0.0566 - accuracy: 0.9402 - val_loss: 0.2039 - val_accuracy: 0.9236
#
# Epoch 00100: val_loss did not improve from 0.16826
# Epoch 101/100000
# 67/67 - 0s - loss: 0.0577 - accuracy: 0.9394 - val_loss: 0.1843 - val_accuracy: 0.9314
#
# Epoch 00101: val_loss did not improve from 0.16826
# Epoch 102/100000
# 67/67 - 0s - loss: 0.0584 - accuracy: 0.9383 - val_loss: 0.1779 - val_accuracy: 0.9340
#
# Epoch 00102: val_loss did not improve from 0.16826
# Epoch 103/100000
# 67/67 - 0s - loss: 0.0575 - accuracy: 0.9402 - val_loss: 0.1818 - val_accuracy: 0.9326
#
# Epoch 00103: val_loss did not improve from 0.16826
# Epoch 104/100000
# 67/67 - 0s - loss: 0.0574 - accuracy: 0.9407 - val_loss: 0.2016 - val_accuracy: 0.9276
#
# Epoch 00104: val_loss did not improve from 0.16826
# Epoch 105/100000
# 67/67 - 0s - loss: 0.0554 - accuracy: 0.9414 - val_loss: 0.1767 - val_accuracy: 0.9336
#
# Epoch 00105: val_loss did not improve from 0.16826
# Epoch 106/100000
# 67/67 - 0s - loss: 0.0564 - accuracy: 0.9408 - val_loss: 0.1870 - val_accuracy: 0.9311
#
# Epoch 00106: val_loss did not improve from 0.16826
# Epoch 107/100000
# 67/67 - 0s - loss: 0.0560 - accuracy: 0.9396 - val_loss: 0.1699 - val_accuracy: 0.9369
#
# Epoch 00107: val_loss did not improve from 0.16826
# Epoch 108/100000
# 67/67 - 0s - loss: 0.0559 - accuracy: 0.9417 - val_loss: 0.1788 - val_accuracy: 0.9323
#
# Epoch 00108: val_loss did not improve from 0.16826
# Epoch 109/100000
# 67/67 - 0s - loss: 0.0560 - accuracy: 0.9400 - val_loss: 0.1652 - val_accuracy: 0.9387
#
# Epoch 00109: val_loss improved from 0.16826 to 0.16524, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0109 ----  0.1652.hdf5
# Epoch 110/100000
# 67/67 - 0s - loss: 0.0559 - accuracy: 0.9416 - val_loss: 0.1772 - val_accuracy: 0.9312
#
# Epoch 00110: val_loss did not improve from 0.16524
# Epoch 111/100000
# 67/67 - 0s - loss: 0.0551 - accuracy: 0.9407 - val_loss: 0.1702 - val_accuracy: 0.9352
#
# Epoch 00111: val_loss did not improve from 0.16524
# Epoch 112/100000
# 67/67 - 0s - loss: 0.0551 - accuracy: 0.9405 - val_loss: 0.1608 - val_accuracy: 0.9396
#
# Epoch 00112: val_loss improved from 0.16524 to 0.16083, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0112 ----  0.1608.hdf5
# Epoch 113/100000
# 67/67 - 0s - loss: 0.0555 - accuracy: 0.9401 - val_loss: 0.1788 - val_accuracy: 0.9340
#
# Epoch 00113: val_loss did not improve from 0.16083
# Epoch 114/100000
# 67/67 - 0s - loss: 0.0551 - accuracy: 0.9413 - val_loss: 0.1645 - val_accuracy: 0.9384
#
# Epoch 00114: val_loss did not improve from 0.16083
# Epoch 115/100000
# 67/67 - 0s - loss: 0.0546 - accuracy: 0.9416 - val_loss: 0.1794 - val_accuracy: 0.9328
#
# Epoch 00115: val_loss did not improve from 0.16083
# Epoch 116/100000
# 67/67 - 0s - loss: 0.0542 - accuracy: 0.9427 - val_loss: 0.1714 - val_accuracy: 0.9350
#
# Epoch 00116: val_loss did not improve from 0.16083
# Epoch 117/100000
# 67/67 - 0s - loss: 0.0548 - accuracy: 0.9418 - val_loss: 0.1519 - val_accuracy: 0.9411
#
# Epoch 00117: val_loss improved from 0.16083 to 0.15190, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0117 ----  0.1519.hdf5
# Epoch 118/100000
# 67/67 - 0s - loss: 0.0552 - accuracy: 0.9413 - val_loss: 0.1753 - val_accuracy: 0.9355
#
# Epoch 00118: val_loss did not improve from 0.15190
# Epoch 119/100000
# 67/67 - 0s - loss: 0.0542 - accuracy: 0.9416 - val_loss: 0.1989 - val_accuracy: 0.9246
#
# Epoch 00119: val_loss did not improve from 0.15190
# Epoch 120/100000
# 67/67 - 0s - loss: 0.0546 - accuracy: 0.9418 - val_loss: 0.1878 - val_accuracy: 0.9294
#
# Epoch 00120: val_loss did not improve from 0.15190
# Epoch 121/100000
# 67/67 - 0s - loss: 0.0545 - accuracy: 0.9415 - val_loss: 0.1689 - val_accuracy: 0.9349
#
# Epoch 00121: val_loss did not improve from 0.15190
# Epoch 122/100000
# 67/67 - 0s - loss: 0.0532 - accuracy: 0.9421 - val_loss: 0.1576 - val_accuracy: 0.9398
#
# Epoch 00122: val_loss did not improve from 0.15190
# Epoch 123/100000
# 67/67 - 0s - loss: 0.0549 - accuracy: 0.9415 - val_loss: 0.1609 - val_accuracy: 0.9367
#
# Epoch 00123: val_loss did not improve from 0.15190
# Epoch 124/100000
# 67/67 - 0s - loss: 0.0548 - accuracy: 0.9405 - val_loss: 0.1682 - val_accuracy: 0.9368
#
# Epoch 00124: val_loss did not improve from 0.15190
# Epoch 125/100000
# 67/67 - 0s - loss: 0.0539 - accuracy: 0.9417 - val_loss: 0.1605 - val_accuracy: 0.9385
#
# Epoch 00125: val_loss did not improve from 0.15190
# Epoch 126/100000
# 67/67 - 0s - loss: 0.0531 - accuracy: 0.9421 - val_loss: 0.1765 - val_accuracy: 0.9341
#
# Epoch 00126: val_loss did not improve from 0.15190
# Epoch 127/100000
# 67/67 - 0s - loss: 0.0526 - accuracy: 0.9418 - val_loss: 0.1663 - val_accuracy: 0.9362
#
# Epoch 00127: val_loss did not improve from 0.15190
# Epoch 128/100000
# 67/67 - 0s - loss: 0.0517 - accuracy: 0.9424 - val_loss: 0.1639 - val_accuracy: 0.9372
#
# Epoch 00128: val_loss did not improve from 0.15190
# Epoch 129/100000
# 67/67 - 0s - loss: 0.0522 - accuracy: 0.9434 - val_loss: 0.1761 - val_accuracy: 0.9330
#
# Epoch 00129: val_loss did not improve from 0.15190
# Epoch 130/100000
# 67/67 - 0s - loss: 0.0520 - accuracy: 0.9415 - val_loss: 0.1702 - val_accuracy: 0.9352
#
# Epoch 00130: val_loss did not improve from 0.15190
# Epoch 131/100000
# 67/67 - 0s - loss: 0.0526 - accuracy: 0.9421 - val_loss: 0.1684 - val_accuracy: 0.9363
#
# Epoch 00131: val_loss did not improve from 0.15190
# Epoch 132/100000
# 67/67 - 0s - loss: 0.0523 - accuracy: 0.9420 - val_loss: 0.1587 - val_accuracy: 0.9368
#
# Epoch 00132: val_loss did not improve from 0.15190
# Epoch 133/100000
# 67/67 - 0s - loss: 0.0512 - accuracy: 0.9428 - val_loss: 0.1789 - val_accuracy: 0.9307
#
# Epoch 00133: val_loss did not improve from 0.15190
# Epoch 134/100000
# 67/67 - 0s - loss: 0.0521 - accuracy: 0.9429 - val_loss: 0.1680 - val_accuracy: 0.9345
#
# Epoch 00134: val_loss did not improve from 0.15190
# Epoch 135/100000
# 67/67 - 0s - loss: 0.0518 - accuracy: 0.9422 - val_loss: 0.1682 - val_accuracy: 0.9375
#
# Epoch 00135: val_loss did not improve from 0.15190
# Epoch 136/100000
# 67/67 - 0s - loss: 0.0524 - accuracy: 0.9422 - val_loss: 0.1499 - val_accuracy: 0.9422
#
# Epoch 00136: val_loss improved from 0.15190 to 0.14991, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0136 ----  0.1499.hdf5
# Epoch 137/100000
# 67/67 - 0s - loss: 0.0519 - accuracy: 0.9414 - val_loss: 0.1570 - val_accuracy: 0.9363
#
# Epoch 00137: val_loss did not improve from 0.14991
# Epoch 138/100000
# 67/67 - 0s - loss: 0.0512 - accuracy: 0.9416 - val_loss: 0.1689 - val_accuracy: 0.9369
#
# Epoch 00138: val_loss did not improve from 0.14991
# Epoch 139/100000
# 67/67 - 0s - loss: 0.0516 - accuracy: 0.9424 - val_loss: 0.1600 - val_accuracy: 0.9377
#
# Epoch 00139: val_loss did not improve from 0.14991
# Epoch 140/100000
# 67/67 - 0s - loss: 0.0523 - accuracy: 0.9412 - val_loss: 0.1692 - val_accuracy: 0.9356
#
# Epoch 00140: val_loss did not improve from 0.14991
# Epoch 141/100000
# 67/67 - 0s - loss: 0.0502 - accuracy: 0.9446 - val_loss: 0.1597 - val_accuracy: 0.9359
#
# Epoch 00141: val_loss did not improve from 0.14991
# Epoch 142/100000
# 67/67 - 0s - loss: 0.0509 - accuracy: 0.9425 - val_loss: 0.1491 - val_accuracy: 0.9411
#
# Epoch 00142: val_loss improved from 0.14991 to 0.14913, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0142 ----  0.1491.hdf5
# Epoch 143/100000
# 67/67 - 0s - loss: 0.0503 - accuracy: 0.9441 - val_loss: 0.1756 - val_accuracy: 0.9297
#
# Epoch 00143: val_loss did not improve from 0.14913
# Epoch 144/100000
# 67/67 - 0s - loss: 0.0502 - accuracy: 0.9428 - val_loss: 0.1632 - val_accuracy: 0.9363
#
# Epoch 00144: val_loss did not improve from 0.14913
# Epoch 145/100000
# 67/67 - 0s - loss: 0.0489 - accuracy: 0.9444 - val_loss: 0.1544 - val_accuracy: 0.9405
#
# Epoch 00145: val_loss did not improve from 0.14913
# Epoch 146/100000
# 67/67 - 0s - loss: 0.0500 - accuracy: 0.9436 - val_loss: 0.1711 - val_accuracy: 0.9348
#
# Epoch 00146: val_loss did not improve from 0.14913
# Epoch 147/100000
# 67/67 - 0s - loss: 0.0503 - accuracy: 0.9425 - val_loss: 0.1472 - val_accuracy: 0.9427
#
# Epoch 00147: val_loss improved from 0.14913 to 0.14719, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0147 ----  0.1472.hdf5
# Epoch 148/100000
# 67/67 - 0s - loss: 0.0497 - accuracy: 0.9442 - val_loss: 0.1683 - val_accuracy: 0.9372
#
# Epoch 00148: val_loss did not improve from 0.14719
# Epoch 149/100000
# 67/67 - 0s - loss: 0.0487 - accuracy: 0.9448 - val_loss: 0.1610 - val_accuracy: 0.9373
#
# Epoch 00149: val_loss did not improve from 0.14719
# Epoch 150/100000
# 67/67 - 0s - loss: 0.0497 - accuracy: 0.9449 - val_loss: 0.1590 - val_accuracy: 0.9362
#
# Epoch 00150: val_loss did not improve from 0.14719
# Epoch 151/100000
# 67/67 - 0s - loss: 0.0500 - accuracy: 0.9425 - val_loss: 0.1486 - val_accuracy: 0.9414
#
# Epoch 00151: val_loss did not improve from 0.14719
# Epoch 152/100000
# 67/67 - 0s - loss: 0.0499 - accuracy: 0.9438 - val_loss: 0.1501 - val_accuracy: 0.9402
#
# Epoch 00152: val_loss did not improve from 0.14719
# Epoch 153/100000
# 67/67 - 0s - loss: 0.0502 - accuracy: 0.9420 - val_loss: 0.1714 - val_accuracy: 0.9349
#
# Epoch 00153: val_loss did not improve from 0.14719
# Epoch 154/100000
# 67/67 - 0s - loss: 0.0497 - accuracy: 0.9436 - val_loss: 0.1532 - val_accuracy: 0.9415
#
# Epoch 00154: val_loss did not improve from 0.14719
# Epoch 155/100000
# 67/67 - 0s - loss: 0.0505 - accuracy: 0.9439 - val_loss: 0.1831 - val_accuracy: 0.9308
#
# Epoch 00155: val_loss did not improve from 0.14719
# Epoch 156/100000
# 67/67 - 0s - loss: 0.0494 - accuracy: 0.9433 - val_loss: 0.1472 - val_accuracy: 0.9426
#
# Epoch 00156: val_loss improved from 0.14719 to 0.14715, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0156 ----  0.1472.hdf5
# Epoch 157/100000
# 67/67 - 0s - loss: 0.0482 - accuracy: 0.9453 - val_loss: 0.1587 - val_accuracy: 0.9363
#
# Epoch 00157: val_loss did not improve from 0.14715
# Epoch 158/100000
# 67/67 - 0s - loss: 0.0488 - accuracy: 0.9446 - val_loss: 0.1694 - val_accuracy: 0.9337
#
# Epoch 00158: val_loss did not improve from 0.14715
# Epoch 159/100000
# 67/67 - 0s - loss: 0.0473 - accuracy: 0.9444 - val_loss: 0.1532 - val_accuracy: 0.9404
#
# Epoch 00159: val_loss did not improve from 0.14715
# Epoch 160/100000
# 67/67 - 0s - loss: 0.0485 - accuracy: 0.9437 - val_loss: 0.1526 - val_accuracy: 0.9396
#
# Epoch 00160: val_loss did not improve from 0.14715
# Epoch 161/100000
# 67/67 - 0s - loss: 0.0487 - accuracy: 0.9433 - val_loss: 0.1571 - val_accuracy: 0.9368
#
# Epoch 00161: val_loss did not improve from 0.14715
# Epoch 162/100000
# 67/67 - 0s - loss: 0.0477 - accuracy: 0.9440 - val_loss: 0.1458 - val_accuracy: 0.9412
#
# Epoch 00162: val_loss improved from 0.14715 to 0.14585, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0162 ----  0.1458.hdf5
# Epoch 163/100000
# 67/67 - 0s - loss: 0.0490 - accuracy: 0.9435 - val_loss: 0.1921 - val_accuracy: 0.9242
#
# Epoch 00163: val_loss did not improve from 0.14585
# Epoch 164/100000
# 67/67 - 0s - loss: 0.0496 - accuracy: 0.9426 - val_loss: 0.1907 - val_accuracy: 0.9284
#
# Epoch 00164: val_loss did not improve from 0.14585
# Epoch 165/100000
# 67/67 - 0s - loss: 0.0489 - accuracy: 0.9426 - val_loss: 0.1678 - val_accuracy: 0.9329
#
# Epoch 00165: val_loss did not improve from 0.14585
# Epoch 166/100000
# 67/67 - 0s - loss: 0.0483 - accuracy: 0.9442 - val_loss: 0.1685 - val_accuracy: 0.9330
#
# Epoch 00166: val_loss did not improve from 0.14585
# Epoch 167/100000
# 67/67 - 0s - loss: 0.0476 - accuracy: 0.9455 - val_loss: 0.1712 - val_accuracy: 0.9335
#
# Epoch 00167: val_loss did not improve from 0.14585
# Epoch 168/100000
# 67/67 - 0s - loss: 0.0485 - accuracy: 0.9447 - val_loss: 0.1465 - val_accuracy: 0.9405
#
# Epoch 00168: val_loss did not improve from 0.14585
# Epoch 169/100000
# 67/67 - 0s - loss: 0.0476 - accuracy: 0.9443 - val_loss: 0.1483 - val_accuracy: 0.9388
#
# Epoch 00169: val_loss did not improve from 0.14585
# Epoch 170/100000
# 67/67 - 0s - loss: 0.0473 - accuracy: 0.9454 - val_loss: 0.1662 - val_accuracy: 0.9338
#
# Epoch 00170: val_loss did not improve from 0.14585
# Epoch 171/100000
# 67/67 - 0s - loss: 0.0476 - accuracy: 0.9446 - val_loss: 0.1580 - val_accuracy: 0.9364
#
# Epoch 00171: val_loss did not improve from 0.14585
# Epoch 172/100000
# 67/67 - 0s - loss: 0.0469 - accuracy: 0.9449 - val_loss: 0.1903 - val_accuracy: 0.9280
#
# Epoch 00172: val_loss did not improve from 0.14585
# Epoch 173/100000
# 67/67 - 0s - loss: 0.0482 - accuracy: 0.9440 - val_loss: 0.1734 - val_accuracy: 0.9346
#
# Epoch 00173: val_loss did not improve from 0.14585
# Epoch 174/100000
# 67/67 - 0s - loss: 0.0474 - accuracy: 0.9453 - val_loss: 0.1689 - val_accuracy: 0.9319
#
# Epoch 00174: val_loss did not improve from 0.14585
# Epoch 175/100000
# 67/67 - 0s - loss: 0.0470 - accuracy: 0.9447 - val_loss: 0.1925 - val_accuracy: 0.9267
#
# Epoch 00175: val_loss did not improve from 0.14585
# Epoch 176/100000
# 67/67 - 0s - loss: 0.0474 - accuracy: 0.9446 - val_loss: 0.1669 - val_accuracy: 0.9340
#
# Epoch 00176: val_loss did not improve from 0.14585
# Epoch 177/100000
# 67/67 - 0s - loss: 0.0457 - accuracy: 0.9452 - val_loss: 0.1617 - val_accuracy: 0.9374
#
# Epoch 00177: val_loss did not improve from 0.14585
# Epoch 178/100000
# 67/67 - 0s - loss: 0.0475 - accuracy: 0.9446 - val_loss: 0.1566 - val_accuracy: 0.9362
#
# Epoch 00178: val_loss did not improve from 0.14585
# Epoch 179/100000
# 67/67 - 0s - loss: 0.0468 - accuracy: 0.9447 - val_loss: 0.1667 - val_accuracy: 0.9337
#
# Epoch 00179: val_loss did not improve from 0.14585
# Epoch 180/100000
# 67/67 - 0s - loss: 0.0469 - accuracy: 0.9432 - val_loss: 0.1429 - val_accuracy: 0.9417
#
# Epoch 00180: val_loss improved from 0.14585 to 0.14288, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0180 ----  0.1429.hdf5
# Epoch 181/100000
# 67/67 - 0s - loss: 0.0470 - accuracy: 0.9442 - val_loss: 0.1639 - val_accuracy: 0.9359
#
# Epoch 00181: val_loss did not improve from 0.14288
# Epoch 182/100000
# 67/67 - 0s - loss: 0.0476 - accuracy: 0.9433 - val_loss: 0.1498 - val_accuracy: 0.9368
#
# Epoch 00182: val_loss did not improve from 0.14288
# Epoch 183/100000
# 67/67 - 0s - loss: 0.0474 - accuracy: 0.9447 - val_loss: 0.1572 - val_accuracy: 0.9353
#
# Epoch 00183: val_loss did not improve from 0.14288
# Epoch 184/100000
# 67/67 - 0s - loss: 0.0483 - accuracy: 0.9431 - val_loss: 0.1488 - val_accuracy: 0.9380
#
# Epoch 00184: val_loss did not improve from 0.14288
# Epoch 185/100000
# 67/67 - 0s - loss: 0.0493 - accuracy: 0.9432 - val_loss: 0.2266 - val_accuracy: 0.9103
#
# Epoch 00185: val_loss did not improve from 0.14288
# Epoch 186/100000
# 67/67 - 0s - loss: 0.0482 - accuracy: 0.9438 - val_loss: 0.1641 - val_accuracy: 0.9356
#
# Epoch 00186: val_loss did not improve from 0.14288
# Epoch 187/100000
# 67/67 - 0s - loss: 0.0465 - accuracy: 0.9451 - val_loss: 0.1539 - val_accuracy: 0.9397
#
# Epoch 00187: val_loss did not improve from 0.14288
# Epoch 188/100000
# 67/67 - 0s - loss: 0.0484 - accuracy: 0.9440 - val_loss: 0.1443 - val_accuracy: 0.9407
#
# Epoch 00188: val_loss did not improve from 0.14288
# Epoch 189/100000
# 67/67 - 0s - loss: 0.0455 - accuracy: 0.9455 - val_loss: 0.1763 - val_accuracy: 0.9305
#
# Epoch 00189: val_loss did not improve from 0.14288
# Epoch 190/100000
# 67/67 - 0s - loss: 0.0466 - accuracy: 0.9444 - val_loss: 0.1508 - val_accuracy: 0.9373
#
# Epoch 00190: val_loss did not improve from 0.14288
# Epoch 191/100000
# 67/67 - 0s - loss: 0.0462 - accuracy: 0.9449 - val_loss: 0.1447 - val_accuracy: 0.9387
#
# Epoch 00191: val_loss did not improve from 0.14288
# Epoch 192/100000
# 67/67 - 0s - loss: 0.0461 - accuracy: 0.9444 - val_loss: 0.1642 - val_accuracy: 0.9370
#
# Epoch 00192: val_loss did not improve from 0.14288
# Epoch 193/100000
# 67/67 - 0s - loss: 0.0467 - accuracy: 0.9451 - val_loss: 0.1683 - val_accuracy: 0.9309
#
# Epoch 00193: val_loss did not improve from 0.14288
# Epoch 194/100000
# 67/67 - 0s - loss: 0.0460 - accuracy: 0.9441 - val_loss: 0.1509 - val_accuracy: 0.9405
#
# Epoch 00194: val_loss did not improve from 0.14288
# Epoch 195/100000
# 67/67 - 0s - loss: 0.0458 - accuracy: 0.9452 - val_loss: 0.1679 - val_accuracy: 0.9321
#
# Epoch 00195: val_loss did not improve from 0.14288
# Epoch 196/100000
# 67/67 - 0s - loss: 0.0462 - accuracy: 0.9434 - val_loss: 0.1705 - val_accuracy: 0.9344
#
# Epoch 00196: val_loss did not improve from 0.14288
# Epoch 197/100000
# 67/67 - 0s - loss: 0.0461 - accuracy: 0.9452 - val_loss: 0.1507 - val_accuracy: 0.9386
#
# Epoch 00197: val_loss did not improve from 0.14288
# Epoch 198/100000
# 67/67 - 0s - loss: 0.0447 - accuracy: 0.9458 - val_loss: 0.1637 - val_accuracy: 0.9346
#
# Epoch 00198: val_loss did not improve from 0.14288
# Epoch 199/100000
# 67/67 - 0s - loss: 0.0457 - accuracy: 0.9443 - val_loss: 0.1532 - val_accuracy: 0.9372
#
# Epoch 00199: val_loss did not improve from 0.14288
# Epoch 200/100000
# 67/67 - 0s - loss: 0.0456 - accuracy: 0.9461 - val_loss: 0.1546 - val_accuracy: 0.9362
#
# Epoch 00200: val_loss did not improve from 0.14288
# Epoch 201/100000
# 67/67 - 0s - loss: 0.0462 - accuracy: 0.9436 - val_loss: 0.1446 - val_accuracy: 0.9378
#
# Epoch 00201: val_loss did not improve from 0.14288
# Epoch 202/100000
# 67/67 - 0s - loss: 0.0468 - accuracy: 0.9438 - val_loss: 0.1439 - val_accuracy: 0.9399
#
# Epoch 00202: val_loss did not improve from 0.14288
# Epoch 203/100000
# 67/67 - 0s - loss: 0.0448 - accuracy: 0.9459 - val_loss: 0.1610 - val_accuracy: 0.9329
#
# Epoch 00203: val_loss did not improve from 0.14288
# Epoch 204/100000
# 67/67 - 0s - loss: 0.0452 - accuracy: 0.9452 - val_loss: 0.1531 - val_accuracy: 0.9379
#
# Epoch 00204: val_loss did not improve from 0.14288
# Epoch 205/100000
# 67/67 - 0s - loss: 0.0454 - accuracy: 0.9441 - val_loss: 0.1730 - val_accuracy: 0.9304
#
# Epoch 00205: val_loss did not improve from 0.14288
# Epoch 206/100000
# 67/67 - 0s - loss: 0.0445 - accuracy: 0.9455 - val_loss: 0.1554 - val_accuracy: 0.9346
#
# Epoch 00206: val_loss did not improve from 0.14288
# Epoch 207/100000
# 67/67 - 0s - loss: 0.0455 - accuracy: 0.9447 - val_loss: 0.1634 - val_accuracy: 0.9312
#
# Epoch 00207: val_loss did not improve from 0.14288
# Epoch 208/100000
# 67/67 - 0s - loss: 0.0450 - accuracy: 0.9434 - val_loss: 0.1526 - val_accuracy: 0.9358
#
# Epoch 00208: val_loss did not improve from 0.14288
# Epoch 209/100000
# 67/67 - 0s - loss: 0.0457 - accuracy: 0.9454 - val_loss: 0.1694 - val_accuracy: 0.9318
#
# Epoch 00209: val_loss did not improve from 0.14288
# Epoch 210/100000
# 67/67 - 0s - loss: 0.0452 - accuracy: 0.9447 - val_loss: 0.1550 - val_accuracy: 0.9356
#
# Epoch 00210: val_loss did not improve from 0.14288
# Epoch 211/100000
# 67/67 - 0s - loss: 0.0452 - accuracy: 0.9432 - val_loss: 0.1597 - val_accuracy: 0.9342
#
# Epoch 00211: val_loss did not improve from 0.14288
# Epoch 212/100000
# 67/67 - 0s - loss: 0.0445 - accuracy: 0.9444 - val_loss: 0.1536 - val_accuracy: 0.9379
#
# Epoch 00212: val_loss did not improve from 0.14288
# Epoch 213/100000
# 67/67 - 0s - loss: 0.0440 - accuracy: 0.9457 - val_loss: 0.1519 - val_accuracy: 0.9376
#
# Epoch 00213: val_loss did not improve from 0.14288
# Epoch 214/100000
# 67/67 - 0s - loss: 0.0438 - accuracy: 0.9468 - val_loss: 0.1611 - val_accuracy: 0.9342
#
# Epoch 00214: val_loss did not improve from 0.14288
# Epoch 215/100000
# 67/67 - 0s - loss: 0.0449 - accuracy: 0.9447 - val_loss: 0.1768 - val_accuracy: 0.9319
#
# Epoch 00215: val_loss did not improve from 0.14288
# Epoch 216/100000
# 67/67 - 0s - loss: 0.0461 - accuracy: 0.9456 - val_loss: 0.1449 - val_accuracy: 0.9396
#
# Epoch 00216: val_loss did not improve from 0.14288
# Epoch 217/100000
# 67/67 - 0s - loss: 0.0446 - accuracy: 0.9460 - val_loss: 0.1554 - val_accuracy: 0.9368
#
# Epoch 00217: val_loss did not improve from 0.14288
# Epoch 218/100000
# 67/67 - 0s - loss: 0.0457 - accuracy: 0.9447 - val_loss: 0.1429 - val_accuracy: 0.9397
#
# Epoch 00218: val_loss did not improve from 0.14288
# Epoch 219/100000
# 67/67 - 0s - loss: 0.0470 - accuracy: 0.9432 - val_loss: 0.1409 - val_accuracy: 0.9410
#
# Epoch 00219: val_loss improved from 0.14288 to 0.14093, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0219 ----  0.1409.hdf5
# Epoch 220/100000
# 67/67 - 0s - loss: 0.0448 - accuracy: 0.9470 - val_loss: 0.1699 - val_accuracy: 0.9329
#
# Epoch 00220: val_loss did not improve from 0.14093
# Epoch 221/100000
# 67/67 - 0s - loss: 0.0447 - accuracy: 0.9456 - val_loss: 0.1873 - val_accuracy: 0.9278
#
# Epoch 00221: val_loss did not improve from 0.14093
# Epoch 222/100000
# 67/67 - 0s - loss: 0.0438 - accuracy: 0.9460 - val_loss: 0.1626 - val_accuracy: 0.9324
#
# Epoch 00222: val_loss did not improve from 0.14093
# Epoch 223/100000
# 67/67 - 0s - loss: 0.0454 - accuracy: 0.9451 - val_loss: 0.1364 - val_accuracy: 0.9437
#
# Epoch 00223: val_loss improved from 0.14093 to 0.13639, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0223 ----  0.1364.hdf5
# Epoch 224/100000
# 67/67 - 0s - loss: 0.0450 - accuracy: 0.9451 - val_loss: 0.1430 - val_accuracy: 0.9384
#
# Epoch 00224: val_loss did not improve from 0.13639
# Epoch 225/100000
# 67/67 - 0s - loss: 0.0440 - accuracy: 0.9457 - val_loss: 0.1422 - val_accuracy: 0.9421
#
# Epoch 00225: val_loss did not improve from 0.13639
# Epoch 226/100000
# 67/67 - 0s - loss: 0.0455 - accuracy: 0.9446 - val_loss: 0.1334 - val_accuracy: 0.9442
#
# Epoch 00226: val_loss improved from 0.13639 to 0.13336, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0226 ----  0.1334.hdf5
# Epoch 227/100000
# 67/67 - 0s - loss: 0.0456 - accuracy: 0.9447 - val_loss: 0.1499 - val_accuracy: 0.9379
#
# Epoch 00227: val_loss did not improve from 0.13336
# Epoch 228/100000
# 67/67 - 0s - loss: 0.0454 - accuracy: 0.9435 - val_loss: 0.1422 - val_accuracy: 0.9394
#
# Epoch 00228: val_loss did not improve from 0.13336
# Epoch 229/100000
# 67/67 - 0s - loss: 0.0442 - accuracy: 0.9446 - val_loss: 0.1472 - val_accuracy: 0.9397
#
# Epoch 00229: val_loss did not improve from 0.13336
# Epoch 230/100000
# 67/67 - 0s - loss: 0.0440 - accuracy: 0.9452 - val_loss: 0.1706 - val_accuracy: 0.9325
#
# Epoch 00230: val_loss did not improve from 0.13336
# Epoch 231/100000
# 67/67 - 0s - loss: 0.0444 - accuracy: 0.9441 - val_loss: 0.1609 - val_accuracy: 0.9352
#
# Epoch 00231: val_loss did not improve from 0.13336
# Epoch 232/100000
# 67/67 - 0s - loss: 0.0432 - accuracy: 0.9455 - val_loss: 0.1547 - val_accuracy: 0.9361
#
# Epoch 00232: val_loss did not improve from 0.13336
# Epoch 233/100000
# 67/67 - 0s - loss: 0.0434 - accuracy: 0.9463 - val_loss: 0.1945 - val_accuracy: 0.9260
#
# Epoch 00233: val_loss did not improve from 0.13336
# Epoch 234/100000
# 67/67 - 0s - loss: 0.0432 - accuracy: 0.9459 - val_loss: 0.1507 - val_accuracy: 0.9368
#
# Epoch 00234: val_loss did not improve from 0.13336
# Epoch 235/100000
# 67/67 - 0s - loss: 0.0451 - accuracy: 0.9450 - val_loss: 0.1404 - val_accuracy: 0.9400
#
# Epoch 00235: val_loss did not improve from 0.13336
# Epoch 236/100000
# 67/67 - 0s - loss: 0.0445 - accuracy: 0.9444 - val_loss: 0.1482 - val_accuracy: 0.9388
#
# Epoch 00236: val_loss did not improve from 0.13336
# Epoch 237/100000
# 67/67 - 0s - loss: 0.0433 - accuracy: 0.9452 - val_loss: 0.1488 - val_accuracy: 0.9368
#
# Epoch 00237: val_loss did not improve from 0.13336
# Epoch 238/100000
# 67/67 - 0s - loss: 0.0443 - accuracy: 0.9446 - val_loss: 0.1315 - val_accuracy: 0.9422
#
# Epoch 00238: val_loss improved from 0.13336 to 0.13147, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/HMM_saveResults_최윤정/20210414-Time_08-06/ModelLookBack- 8 Origin0238 ----  0.1315.hdf5
# Epoch 239/100000
# 67/67 - 0s - loss: 0.0439 - accuracy: 0.9453 - val_loss: 0.1415 - val_accuracy: 0.9399
#
# Epoch 00239: val_loss did not improve from 0.13147
# Epoch 240/100000
# 67/67 - 0s - loss: 0.0435 - accuracy: 0.9457 - val_loss: 0.1690 - val_accuracy: 0.9334
#
# Epoch 00240: val_loss did not improve from 0.13147
# Epoch 241/100000
# 67/67 - 0s - loss: 0.0447 - accuracy: 0.9453 - val_loss: 0.1576 - val_accuracy: 0.9356
#
# Epoch 00241: val_loss did not improve from 0.13147
# Epoch 242/100000
# 67/67 - 0s - loss: 0.0427 - accuracy: 0.9463 - val_loss: 0.1643 - val_accuracy: 0.9314
#
# Epoch 00242: val_loss did not improve from 0.13147
# Epoch 243/100000
# 67/67 - 0s - loss: 0.0421 - accuracy: 0.9466 - val_loss: 0.1436 - val_accuracy: 0.9397
#
# Epoch 00243: val_loss did not improve from 0.13147
# Epoch 244/100000
# 67/67 - 0s - loss: 0.0441 - accuracy: 0.9448 - val_loss: 0.1389 - val_accuracy: 0.9399
#
# Epoch 00244: val_loss did not improve from 0.13147
# Epoch 245/100000
# 67/67 - 0s - loss: 0.0427 - accuracy: 0.9463 - val_loss: 0.1538 - val_accuracy: 0.9371
#
# Epoch 00245: val_loss did not improve from 0.13147
# Epoch 246/100000
# 67/67 - 0s - loss: 0.0435 - accuracy: 0.9455 - val_loss: 0.1607 - val_accuracy: 0.9356
#
# Epoch 00246: val_loss did not improve from 0.13147
# Epoch 247/100000
# 67/67 - 0s - loss: 0.0425 - accuracy: 0.9455 - val_loss: 0.1485 - val_accuracy: 0.9373
#
# Epoch 00247: val_loss did not improve from 0.13147
# Epoch 248/100000
# 67/67 - 0s - loss: 0.0428 - accuracy: 0.9446 - val_loss: 0.1324 - val_accuracy: 0.9442
#
# Epoch 00248: val_loss did not improve from 0.13147
# Epoch 249/100000
# 67/67 - 0s - loss: 0.0436 - accuracy: 0.9457 - val_loss: 0.1610 - val_accuracy: 0.9347
#
# Epoch 00249: val_loss did not improve from 0.13147
# Epoch 250/100000
# 67/67 - 0s - loss: 0.0444 - accuracy: 0.9446 - val_loss: 0.1496 - val_accuracy: 0.9375
#
# Epoch 00250: val_loss did not improve from 0.13147
# Epoch 251/100000
# 67/67 - 0s - loss: 0.0432 - accuracy: 0.9461 - val_loss: 0.1588 - val_accuracy: 0.9354
#
# Epoch 00251: val_loss did not improve from 0.13147
# Epoch 252/100000
# 67/67 - 0s - loss: 0.0431 - accuracy: 0.9451 - val_loss: 0.1509 - val_accuracy: 0.9348
#
# Epoch 00252: val_loss did not improve from 0.13147
# Epoch 253/100000
# 67/67 - 0s - loss: 0.0435 - accuracy: 0.9453 - val_loss: 0.1375 - val_accuracy: 0.9409
#
# Epoch 00253: val_loss did not improve from 0.13147
# Epoch 254/100000
# 67/67 - 0s - loss: 0.0435 - accuracy: 0.9451 - val_loss: 0.1507 - val_accuracy: 0.9368
#
# Epoch 00254: val_loss did not improve from 0.13147
# Epoch 255/100000
# 67/67 - 0s - loss: 0.0427 - accuracy: 0.9467 - val_loss: 0.1428 - val_accuracy: 0.9407
#
# Epoch 00255: val_loss did not improve from 0.13147
# Epoch 256/100000
# 67/67 - 0s - loss: 0.0426 - accuracy: 0.9463 - val_loss: 0.1442 - val_accuracy: 0.9419
#
# Epoch 00256: val_loss did not improve from 0.13147
# Epoch 257/100000
# 67/67 - 0s - loss: 0.0456 - accuracy: 0.9451 - val_loss: 0.1640 - val_accuracy: 0.9344
#
# Epoch 00257: val_loss did not improve from 0.13147
# Epoch 258/100000
# 67/67 - 0s - loss: 0.0426 - accuracy: 0.9458 - val_loss: 0.1592 - val_accuracy: 0.9332
#
# Epoch 00258: val_loss did not improve from 0.13147
# Epoch 259/100000
# 67/67 - 0s - loss: 0.0417 - accuracy: 0.9462 - val_loss: 0.1443 - val_accuracy: 0.9390
#
# Epoch 00259: val_loss did not improve from 0.13147
# Epoch 260/100000
# 67/67 - 0s - loss: 0.0445 - accuracy: 0.9457 - val_loss: 0.1520 - val_accuracy: 0.9367
#
# Epoch 00260: val_loss did not improve from 0.13147
# Epoch 261/100000
# 67/67 - 0s - loss: 0.0419 - accuracy: 0.9456 - val_loss: 0.1379 - val_accuracy: 0.9402
#
# Epoch 00261: val_loss did not improve from 0.13147
# Epoch 262/100000
# 67/67 - 0s - loss: 0.0430 - accuracy: 0.9464 - val_loss: 0.1581 - val_accuracy: 0.9349
#
# Epoch 00262: val_loss did not improve from 0.13147
# Epoch 263/100000
# 67/67 - 0s - loss: 0.0421 - accuracy: 0.9451 - val_loss: 0.1496 - val_accuracy: 0.9358
#
# Epoch 00263: val_loss did not improve from 0.13147
# Epoch 264/100000
# 67/67 - 0s - loss: 0.0452 - accuracy: 0.9434 - val_loss: 0.1594 - val_accuracy: 0.9349
#
# Epoch 00264: val_loss did not improve from 0.13147
# Epoch 265/100000
# 67/67 - 0s - loss: 0.0438 - accuracy: 0.9443 - val_loss: 0.1345 - val_accuracy: 0.9414
#
# Epoch 00265: val_loss did not improve from 0.13147
# Epoch 266/100000
# 67/67 - 0s - loss: 0.0417 - accuracy: 0.9468 - val_loss: 0.1636 - val_accuracy: 0.9318
#
# Epoch 00266: val_loss did not improve from 0.13147
# Epoch 267/100000
# 67/67 - 0s - loss: 0.0422 - accuracy: 0.9470 - val_loss: 0.1414 - val_accuracy: 0.9389
#
# Epoch 00267: val_loss did not improve from 0.13147
# Epoch 268/100000
# 67/67 - 0s - loss: 0.0422 - accuracy: 0.9452 - val_loss: 0.1601 - val_accuracy: 0.9313
#
# Epoch 00268: val_loss did not improve from 0.13147
# Epoch 269/100000
# 67/67 - 0s - loss: 0.0412 - accuracy: 0.9460 - val_loss: 0.1377 - val_accuracy: 0.9422
#
# Epoch 00269: val_loss did not improve from 0.13147
# Epoch 270/100000
# 67/67 - 0s - loss: 0.0424 - accuracy: 0.9456 - val_loss: 0.1639 - val_accuracy: 0.9334
#
# Epoch 00270: val_loss did not improve from 0.13147
# Epoch 271/100000
# 67/67 - 0s - loss: 0.0438 - accuracy: 0.9449 - val_loss: 0.1489 - val_accuracy: 0.9377
#
# Epoch 00271: val_loss did not improve from 0.13147
# Epoch 272/100000
# 67/67 - 0s - loss: 0.0429 - accuracy: 0.9454 - val_loss: 0.1453 - val_accuracy: 0.9386
#
# Epoch 00272: val_loss did not improve from 0.13147
# Epoch 273/100000
# 67/67 - 0s - loss: 0.0423 - accuracy: 0.9466 - val_loss: 0.1568 - val_accuracy: 0.9333
#
# Epoch 00273: val_loss did not improve from 0.13147
# Epoch 274/100000
# 67/67 - 0s - loss: 0.0425 - accuracy: 0.9461 - val_loss: 0.1646 - val_accuracy: 0.9340
#
# Epoch 00274: val_loss did not improve from 0.13147
# Epoch 275/100000
# 67/67 - 0s - loss: 0.0423 - accuracy: 0.9460 - val_loss: 0.1488 - val_accuracy: 0.9374
#
# Epoch 00275: val_loss did not improve from 0.13147
# Epoch 276/100000
# 67/67 - 0s - loss: 0.0429 - accuracy: 0.9447 - val_loss: 0.1588 - val_accuracy: 0.9352
#
# Epoch 00276: val_loss did not improve from 0.13147
# Epoch 277/100000
# 67/67 - 0s - loss: 0.0439 - accuracy: 0.9461 - val_loss: 0.1461 - val_accuracy: 0.9368
#
# Epoch 00277: val_loss did not improve from 0.13147
# Epoch 278/100000
# 67/67 - 0s - loss: 0.0431 - accuracy: 0.9459 - val_loss: 0.1400 - val_accuracy: 0.9381
#
# Epoch 00278: val_loss did not improve from 0.13147
# Epoch 279/100000
# 67/67 - 0s - loss: 0.0422 - accuracy: 0.9455 - val_loss: 0.1551 - val_accuracy: 0.9348
#
# Epoch 00279: val_loss did not improve from 0.13147
# Epoch 280/100000
# 67/67 - 0s - loss: 0.0418 - accuracy: 0.9468 - val_loss: 0.1599 - val_accuracy: 0.9346
#
# Epoch 00280: val_loss did not improve from 0.13147
# Epoch 281/100000
# 67/67 - 0s - loss: 0.0422 - accuracy: 0.9463 - val_loss: 0.1638 - val_accuracy: 0.9338
#
# Epoch 00281: val_loss did not improve from 0.13147
# Epoch 282/100000
# 67/67 - 0s - loss: 0.0414 - accuracy: 0.9462 - val_loss: 0.1352 - val_accuracy: 0.9418
#
# Epoch 00282: val_loss did not improve from 0.13147
# Epoch 283/100000
# 67/67 - 0s - loss: 0.0430 - accuracy: 0.9457 - val_loss: 0.1569 - val_accuracy: 0.9327
#
# Epoch 00283: val_loss did not improve from 0.13147
# Epoch 284/100000
# 67/67 - 0s - loss: 0.0404 - accuracy: 0.9475 - val_loss: 0.1426 - val_accuracy: 0.9393
#
# Epoch 00284: val_loss did not improve from 0.13147
# Epoch 285/100000
# 67/67 - 0s - loss: 0.0413 - accuracy: 0.9473 - val_loss: 0.1527 - val_accuracy: 0.9349
#
# Epoch 00285: val_loss did not improve from 0.13147
# Epoch 286/100000
# 67/67 - 0s - loss: 0.0425 - accuracy: 0.9450 - val_loss: 0.1421 - val_accuracy: 0.9382
#
# Epoch 00286: val_loss did not improve from 0.13147
# Epoch 287/100000
# 67/67 - 0s - loss: 0.0417 - accuracy: 0.9461 - val_loss: 0.1899 - val_accuracy: 0.9233
#
# Epoch 00287: val_loss did not improve from 0.13147
# Epoch 288/100000
# 67/67 - 0s - loss: 0.0418 - accuracy: 0.9452 - val_loss: 0.1386 - val_accuracy: 0.9402
#
# Epoch 00288: val_loss did not improve from 0.13147
# 28/28 - 16s - loss: 0.1471 - accuracy: 0.9413
# test_loss: 0.14708194136619568 - test_acc: 0.9412605166435242

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='lower left')

plt.savefig(MODEL_SAVE_FOLDER_PATH+"/lr_"+str(learning_rate)+"_patience_"+ str(patience)+"_Loss_Acc.png")
plt.show()

# %%
def action_frames(y_pred_argmax, ratio_display = False):
    action_label =  {"sit": 0, "sit-stand": 1,  "walk": 2, "turn": 3,  "stand-sit": 4}
    action_cnt =  {"total_frames": 0,"sit": 0, "sit-stand": 0,  "walk": 0, "turn": 0,"stand-sit": 0}

    for i in range(len(y_pred_argmax)):
        action_cnt["total_frames"] +=1
        if y_pred_argmax[i] == action_label["sit"]:
            action_cnt["sit"] +=1
            
        elif y_pred_argmax[i] == action_label["sit-stand"]:
            action_cnt["sit-stand"] +=1
            
        elif y_pred_argmax[i] == action_label["walk"]:
            action_cnt["walk"] +=1
            
        elif y_pred_argmax[i] == action_label["turn"]:
            action_cnt["turn"] +=1
        
            
        elif y_pred_argmax[i] == action_label["stand-sit"]:
            action_cnt["stand-sit"] +=1
        
    if ratio_display:     
        print("[ Action Ratio ]")
        print("\t [ 0 - Sit] ratio of sit: ",  action_cnt["sit"]/action_cnt["total_frames"] )
        print("\t [ 1 - sit-stand] ratio of sit-stand: ",  action_cnt["sit-stand"]/action_cnt["total_frames"])
        print("\t [ 2 - walk] ratio of walk: ",  action_cnt["walk"]/action_cnt["total_frames"])
        print("\t [ 3 - turn] ratio of turn: ",  action_cnt["turn"]/action_cnt["total_frames"])
        print("\t [ 4 - stand-sit] ratio of stand-sit: ",  action_cnt["stand-sit"]/action_cnt["total_frames"])
    return action_cnt
    
    
    
y_pred = model.predict(test_x)
y_pred_onehot = np.argmax(y_pred, axis=1)
print(y_pred.shape)
print(y_pred[200] ,"===> onehot: ", y_pred_onehot[200])

y_test_argmax = np.argmax(test_y ,axis=1) 
y_pred_argmax = np.argmax(y_pred ,axis=1)
print(y_test_argmax.shape, y_pred_argmax.shape)


y_pred_frames = action_frames(y_pred_argmax, ratio_display= True)
y_test_frames = action_frames(y_test_argmax,  ratio_display= True)   

print("--->  # of Each Action Frames  \n\t y_pred: {0}, \n\t y_test: {1}".format(y_pred_frames, y_test_frames))
# Out:
# (13994, 5)
# [0.     0.     0.9998 0.0002 0.    ] ===> onehot:  2
# (13994,) (13994,)
# [ Action Ratio ]
# 	 [ 0 - Sit] ratio of sit:  0.20180077175932543
# 	 [ 1 - sit-stand] ratio of sit-stand:  0.07674717736172645
# 	 [ 2 - walk] ratio of walk:  0.4722023724453337
# 	 [ 3 - turn] ratio of turn:  0.17014434757753322
# 	 [ 4 - stand-sit] ratio of stand-sit:  0.07910533085608118
# [ Action Ratio ]
# 	 [ 0 - Sit] ratio of sit:  0.20730312991281977
# 	 [ 1 - sit-stand] ratio of sit-stand:  0.07195941117621837
# 	 [ 2 - walk] ratio of walk:  0.5014291839359726
# 	 [ 3 - turn] ratio of turn:  0.14334714877804774
# 	 [ 4 - stand-sit] ratio of stand-sit:  0.07596112619694155
# --->  # of Each Action Frames
# 	 y_pred: {'total_frames': 13994, 'sit': 2824, 'sit-stand': 1074, 'walk': 6608, 'turn': 2381, 'stand-sit': 1107},
# 	 y_test: {'total_frames': 13994, 'sit': 2901, 'sit-stand': 1007, 'walk': 7017, 'turn': 2006, 'stand-sit': 1063}

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import cohen_kappa_score
import seaborn as sns


kappa = cohen_kappa_score(y_test_argmax, y_pred_argmax)
print('Cohens kappa: %f' % kappa)

print(classification_report(y_test_argmax, y_pred_argmax))
conf_matrix = confusion_matrix(y_test_argmax, y_pred_argmax)
print("\n---> Confusion Matrix \n" ,conf_matrix) # sit, sit-stand, walking, turning, stand-sit

plt.figure(figsize = (15,7) )
sns.heatmap(conf_matrix, annot=True)
plt.title("Confusion Matrix")
plt.savefig(MODEL_SAVE_FOLDER_PATH+"/pred_Confusion_Matrix.png")
plt.show()
# Out:
# Cohens kappa: 0.914308
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96      2901
#            1       0.86      0.92      0.89      1007
#            2       0.99      0.93      0.96      7017
#            3       0.84      1.00      0.91      2006
#            4       0.89      0.92      0.91      1063
#
#     accuracy                           0.94     13994
#    macro avg       0.91      0.94      0.92     13994
# weighted avg       0.95      0.94      0.94     13994
#
#
# ---> Confusion Matrix
#  [[2755   79    0    0   67]
#  [  50  923   34    0    0]
#  [   0   70 6510  380   57]
#  [   0    0    5 2001    0]
#  [  19    2   59    0  983]]

# %% [markdown]
# ## POST processing (DTW)

# %%
from dtw import dtw
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import cohen_kappa_score
import seaborn as sns

act_dict = {"sit":0, "sit-to-stand":1, "walk": 2, "turn": 3, "stand-to-sit":4}
answer_y = [act_dict["sit"], act_dict["sit-to-stand"], act_dict["walk"], act_dict["turn"], act_dict["walk"], act_dict["stand-to-sit"], act_dict["sit"] ]
target_names = ["sit", "sit-to-stand", "walk", "turn", "stand-to-sit"]


def post_process_DTW(pred_y, answer_y):
    dtw_index ={"walk":4, "stand-to-sit": 5, "sit": 6}
    dtw_alignment  = dtw(pred_y,answer_y, keep_internals=True)

    results =[]
    for elements in dtw_alignment.index2:
        if elements == dtw_index["walk"]: 
            elements = act_dict["walk"]
        elif elements == dtw_index["stand-to-sit"]:  #
            elements = act_dict["stand-to-sit"]
        elif elements == dtw_index["sit"]:  #
            elements =  act_dict["sit"]     
        results.append(elements)

    
    # 간혹.. dtw 결과가 1개 더 많이 나올 때 있음.. 걍 뒤에 하나 지워버려..
    if len(dtw_alignment.index2) > len(pred_y):
        new_result = results[:-1]
    else:
        new_result = results
        
    return dtw_alignment, new_result


def plot_postResults(answer_y, pred_y, results, title="dtw"):
    fig = plt.figure(figsize=(18,12))
    
    Gnd_fig = fig.add_subplot(2,3,1)
    Gnd_fig.set_title(" Ground Truth ")
    Gnd_fig.plot(answer_y, "g", label = "Ground Truth")
    plt.legend()
    
    pred_fig = fig.add_subplot(2,3,2)
    pred_fig.set_title(" Prediction Result (Before DTW) ")
    pred_fig.plot(pred_y, "b", label=" pred_y (before DTW)")
    plt.legend()
    
    dtw_fig = fig.add_subplot(2,3,3)
    dtw_fig.set_title(" PostProcessing Results (DTW) ")
    dtw_fig.plot(results, "r",  label="dtw_result")
    plt.legend()
    
    gnd_pred_fig = fig.add_subplot(2,3,4)
    gnd_pred_fig.set_title(" Comparison: Ground Truth vs Prediction")
    gnd_pred_fig.plot(answer_y, "g", label="Ground Truth") # linewidth=3
    gnd_pred_fig.plot(pred_y, "b--", label=" pred_y (before DTW)")
    plt.legend()
    
    pred_dtw_fig = fig.add_subplot(2,3,5)
    pred_dtw_fig.set_title(" Comparison: Prediction vs DTW alignment")
    pred_dtw_fig.plot(pred_y, "b--", label=" pred_y (before DTW)") # linewidth=3
    pred_dtw_fig.plot(results, "r", label=" dtw_result")
    plt.legend()
    
    gnd_dtw_fig = fig.add_subplot(2,3,6)
    gnd_dtw_fig.set_title(" Comparison: Ground Truth vs DTW alignment ")
    gnd_dtw_fig.plot(answer_y, "g--", label="Ground Truth")
    gnd_dtw_fig.plot(results, "r", label="dtw_result")  # linewidth=3
    
    plt.legend()
    plt.savefig(MODEL_SAVE_FOLDER_PATH+"/DTW_Comparison_" + title  + ".png")
    
def create_testdata(pelvis_csv, lookback_window = 8):
    test_x = np.zeros((0, lookback_window, numPelvis,1 ))
    test_y = np.zeros((0, numActions)) 
    
   
    timstamp_ms, lpfPelvis_x, lpfPelvis_y, lpfPelvis_z, oneHot_actionList  = getLPF_PelvisData(pelvis_csv)  # raw                 
    
    pelvisData = np.array([lpfPelvis_x, lpfPelvis_y, lpfPelvis_z]).T  # (335,3) 
    actionData = np.array(oneHot_actionList)    # # (335, 5)
                            
    blockTime, blockPelvis, blockLable, enc = sliding_window(timstamp_ms, data_x = pelvisData, data_y = actionData, lookback_window=lookback_window) 

    test_x = np.append(test_x, blockPelvis, axis = 0 )
    test_y = np.append(test_y, blockLable, axis = 0 )    

    return test_x, test_y
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %% [markdown]
# ### 정상인 20대, 30대, 60대

# %%
test_normal_20 = "/DockerProjects/Dataset/TUG/trainSet/HMM_saveResults_최윤정/0_sideView/2020_11_03 TUG/bys_tug/001/Originact5_lpf_labeled_bys_tug_001.csv"
test_normal_20_x, test_normal_20_y_onehot = create_testdata(test_normal_20) 
test_normal_20_y = np.argmax(test_normal_20_y_onehot, axis=1).reshape(-1) # GND one-hot decode

pred_normal_20_y_onehot = model.predict(test_normal_20_x) 
pred_normal_20_y = np.argmax(pred_normal_20_y_onehot, axis=1) #  # pred one-hot decode

normal_20_alignment, normal_20_results = post_process_DTW(test_normal_20_y, answer_y)
normal_20_alignment.plot(type="threeway")
plot_postResults(test_normal_20_y, pred_normal_20_y, normal_20_results, title="normal_20")

# ----- [Before DTW] Model Test
norm_20_eval = model.evaluate(test_normal_20_x, test_normal_20_y_onehot, batch_size= batch_size,verbose=2)

report_dtw = open(MODEL_SAVE_FOLDER_PATH + "/Comp_DTW_Norm_20.txt",'w+t')
print("[Before DTW] Before_DTW_Norm_20 \n", classification_report(test_normal_20_y, pred_normal_20_y, target_names=target_names), file = report_dtw)
print("------------------------------\n", file = report_dtw)
print("[After DTW] After_DTW_Norm_20 \n", classification_report(test_normal_20_y, normal_20_results, target_names=target_names), file = report_dtw)
report_dtw.close()

# ----------- Visualize in cell
print("[Before DTW] Before_DTW_Norm_20 \n", classification_report(test_normal_20_y, pred_normal_20_y, target_names=target_names))
print("------------------------------\n")
print("[After DTW] After_DTW_Norm_20 \n", classification_report(test_normal_20_y, normal_20_results, target_names=target_names))
# Out:
# 1/1 - 16s - loss: 0.0733 - accuracy: 0.9664
# [Before DTW] Before_DTW_Norm_20
#                precision    recall  f1-score   support
#
#          sit       0.99      0.97      0.98        76
# sit-to-stand       1.00      0.95      0.97        19
#         walk       0.95      0.99      0.97       144
#         turn       1.00      0.89      0.94        64
# stand-to-sit       0.89      1.00      0.94        24
#
#     accuracy                           0.97       327
#    macro avg       0.97      0.96      0.96       327
# weighted avg       0.97      0.97      0.97       327
#
# ------------------------------
#
# [After DTW] After_DTW_Norm_20
#                precision    recall  f1-score   support
#
#          sit       1.00      1.00      1.00        76
# sit-to-stand       1.00      1.00      1.00        19
#         walk       1.00      1.00      1.00       144
#         turn       1.00      1.00      1.00        64
# stand-to-sit       1.00      1.00      1.00        24
#
#     accuracy                           1.00       327
#    macro avg       1.00      1.00      1.00       327
# weighted avg       1.00      1.00      1.00       327

# %%
test_normal_30 = "/DockerProjects/Dataset/TUG/trainSet/HMM_saveResults_최윤정/0_sideView/2020_11_20_v2 TUG/cyj2/03/Originact5_lpf_labeled_cyj2_03.csv"
test_normal_30_x, test_normal_30_y_onehot = create_testdata(test_normal_30) 
test_normal_30_y = np.argmax(test_normal_30_y_onehot, axis=1).reshape(-1) # one-hot decode

pred_normal_30_onehot = model.predict(test_normal_30_x)
pred_normal_30_y = np.argmax(pred_normal_30_onehot, axis=1)

normal_30_alignment, normal_30_results = post_process_DTW(pred_normal_30_y, answer_y)
normal_30_alignment.plot(type="threeway")
plot_postResults(test_normal_30_y, pred_normal_30_y, normal_30_results, title="normal_30")

# ----- [Before DTW] Model Test

norm_30_eval = model.evaluate(test_normal_30_x, test_normal_30_y_onehot,batch_size= batch_size,verbose=2)


report_dtw = open(MODEL_SAVE_FOLDER_PATH + "/Comp_DTW_Norm_30.txt",'w+t')
print("[Before DTW] Before_DTW_Norm_30 \n", classification_report(test_normal_30_y, pred_normal_30_y, target_names=target_names), file = report_dtw)
print("------------------------------\n", file = report_dtw)
print("[After DTW] After_DTW_Norm_30 \n", classification_report(test_normal_30_y, normal_30_results, target_names=target_names), file = report_dtw)
report_dtw.close()

# ----------- Visualize in cell
print("[Before DTW] Before_DTW_Norm_30 \n", classification_report(test_normal_30_y, pred_normal_30_y, target_names=target_names))
print("------------------------------\n")
print("[After DTW] After_DTW_Norm_30 \n", classification_report(test_normal_30_y, normal_30_results, target_names=target_names))
# Out:
# 1/1 - 16s - loss: 0.0893 - accuracy: 0.9622
# [Before DTW] Before_DTW_Norm_30
#                precision    recall  f1-score   support
#
#          sit       1.00      0.97      0.99        69
# sit-to-stand       0.85      1.00      0.92        23
#         walk       0.99      0.94      0.97       190
#         turn       0.96      0.98      0.97        66
# stand-to-sit       0.79      1.00      0.88        22
#
#     accuracy                           0.96       370
#    macro avg       0.92      0.98      0.94       370
# weighted avg       0.97      0.96      0.96       370
#
# ------------------------------
#
# [After DTW] After_DTW_Norm_30
#                precision    recall  f1-score   support
#
#          sit       1.00      0.97      0.99        69
# sit-to-stand       0.85      1.00      0.92        23
#         walk       0.99      0.94      0.97       190
#         turn       0.96      0.98      0.97        66
# stand-to-sit       0.79      1.00      0.88        22
#
#     accuracy                           0.96       370
#    macro avg       0.92      0.98      0.94       370
# weighted avg       0.97      0.96      0.96       370

# %%
test_normal_60 = "/DockerProjects/Dataset/TUG/trainSet/HMM_saveResults_최윤정/0_sideView/2021_02_09 TUG/UMS_TUG/05/Originact5_lpf_labeled_UMS_TUG_05.csv"
test_normal_60_x, test_normal_60_y_onehot = create_testdata(test_normal_60) 
test_normal_60_y = np.argmax(test_normal_60_y_onehot, axis=1).reshape(-1) # one-hot decode


pred_normal_60_onehot = model.predict(test_normal_60_x)
pred_normal_60_y = np.argmax(pred_normal_60_onehot, axis=1).reshape(-1) 

normal_60_alignment, normal_60_results = post_process_DTW(pred_normal_60_y, answer_y)
normal_60_alignment.plot(type="threeway")
plot_postResults(test_normal_60_y, pred_normal_60_y, normal_60_results, title="normal_60")


# ----- [Before DTW] Model Test
norm_60_eval = model.evaluate(test_normal_60_x, test_normal_60_y_onehot, batch_size= batch_size,verbose=2)

report_dtw = open(MODEL_SAVE_FOLDER_PATH + "/Comp_DTW_Norm_60.txt",'w+t')
print("[Before DTW] Before DTW Norm 60 \n", classification_report(test_normal_60_y, pred_normal_60_y, target_names=target_names), file = report_dtw)
print("------------------------------\n",file = report_dtw)
print("[After DTW] After_DTW_Norm_60 \n", classification_report(test_normal_60_y, normal_60_results, target_names=target_names), file =   report_dtw)
report_dtw.close()


# ----------- Visualize in cell
print("[Before DTW] Before DTW Norm 60 \n", classification_report(test_normal_60_y, pred_normal_60_y, target_names=target_names))
print("------------------------------\n")
print("[After DTW] After_DTW_Norm_60 \n", classification_report(test_normal_60_y, normal_60_results, target_names=target_names))
# Out:
# 1/1 - 16s - loss: 0.4601 - accuracy: 0.8668
# [Before DTW] Before DTW Norm 60
#                precision    recall  f1-score   support
#
#          sit       1.00      0.78      0.88       139
# sit-to-stand       0.62      0.83      0.71        18
#         walk       0.93      0.94      0.94       142
#         turn       0.88      1.00      0.94        45
# stand-to-sit       0.40      0.67      0.50        24
#
#     accuracy                           0.87       368
#    macro avg       0.77      0.85      0.79       368
# weighted avg       0.90      0.87      0.88       368
#
# ------------------------------
#
# [After DTW] After_DTW_Norm_60
#                precision    recall  f1-score   support
#
#          sit       1.00      0.78      0.87       139
# sit-to-stand       0.58      1.00      0.73        18
#         walk       0.94      0.94      0.94       142
#         turn       0.88      1.00      0.94        45
# stand-to-sit       0.42      0.62      0.50        24
#
#     accuracy                           0.87       368
#    macro avg       0.76      0.87      0.80       368
# weighted avg       0.90      0.87      0.87       368

# %% [markdown]
# ###  Stroke -- 보조필요 없는 수준의 편마비, 케인/지팡이 사용,  모방 보행

# %%
test_stroke_1 =  "/DockerProjects/Dataset/TUG/trainSet/HMM_saveResults_최윤정/0_sideView/2020_12_09 TUG/JDW_tug/01/Originact5_lpf_labeled_JDW_tug_01.csv"
test_stroke_1_x, test_stroke_1_y_onehot = create_testdata(test_stroke_1)  
test_stroke_1_y = np.argmax(test_stroke_1_y_onehot, axis=1).reshape(-1) # one-hot decode

pred_stroke_1_one_hot = model.predict(test_stroke_1_x)
pred_stroke_1_y = np.argmax(pred_stroke_1_one_hot, axis=1)

stroke_1_alignment, stroke_1_results = post_process_DTW(pred_stroke_1_y, answer_y)

stroke_1_alignment.plot(type="threeway")
plot_postResults(test_stroke_1_y, pred_stroke_1_y, stroke_1_results, title="stroke_1")


# # ----- [Before DTW] Model Test
stroke_1_eval = model.evaluate(test_stroke_1_x, test_stroke_1_y_onehot, batch_size= batch_size,verbose=2)

report_dtw = open(MODEL_SAVE_FOLDER_PATH + "/Comp_DTW_stroke_1.txt",'w+t')
print("[Before DTW] Before DTW stroke_1 \n", classification_report(test_stroke_1_y, pred_stroke_1_y, target_names=target_names), file = report_dtw)
print("------------------------------\n", file = report_dtw)
print("[After DTW] After DTW stroke_1 \n", classification_report(test_stroke_1_y, stroke_1_results, target_names=target_names), file = report_dtw)
report_dtw.close()

# ----------- Visualize in cell
print("[Before DTW] Before DTW stroke_1 \n", classification_report(test_stroke_1_y, pred_stroke_1_y, target_names=target_names))
print("------------------------------\n")
print("[After DTW] After DTW stroke_1 \n", classification_report(test_stroke_1_y, stroke_1_results, target_names=target_names))
# Out:
# 2/2 - 0s - loss: 0.5391 - accuracy: 0.8648
# [Before DTW] Before DTW stroke_1
#                precision    recall  f1-score   support
#
#          sit       0.98      0.92      0.95       101
# sit-to-stand       0.94      0.39      0.56        38
#         walk       0.93      0.88      0.91       283
#         turn       0.63      1.00      0.77        58
# stand-to-sit       0.71      0.87      0.78        45
#
#     accuracy                           0.86       525
#    macro avg       0.84      0.81      0.79       525
# weighted avg       0.89      0.86      0.86       525
#
# ------------------------------
#
# [After DTW] After DTW stroke_1
#                precision    recall  f1-score   support
#
#          sit       0.97      0.92      0.94       101
# sit-to-stand       1.00      0.39      0.57        38
#         walk       0.92      0.88      0.90       283
#         turn       0.63      1.00      0.77        58
# stand-to-sit       0.84      0.93      0.88        45
#
#     accuracy                           0.87       525
#    macro avg       0.87      0.83      0.81       525
# weighted avg       0.89      0.87      0.87       525

# %%
test_stroke_tool = "/DockerProjects/Dataset/TUG/trainSet/HMM_saveResults_최윤정/0_sideView/2021_01_20 TUG/KSG_TUG/02/Originact5_lpf_labeled_KSG_TUG_02.csv"
test_stroke_tool_x, test_stroke_tool_y_onehot = create_testdata(test_stroke_tool) 
test_stroke_tool_y = np.argmax(test_stroke_tool_y_onehot, axis=1).reshape(-1) #one-hot decode

pred_stroke_tool_onehot = model.predict(test_stroke_tool_x)
pred_stroke_tool_y = np.argmax(pred_stroke_tool_onehot, axis=1)

stroke_tool_alignment, stroke_tool_results = post_process_DTW(pred_stroke_tool_y, answer_y)
stroke_tool_alignment.plot(type="threeway")
plot_postResults(test_stroke_tool_y, pred_stroke_tool_y, stroke_tool_results, title="stroke_tool")


# ----- [Before DTW] Model Test
stroke_tool_eval = model.evaluate(test_stroke_tool_x, test_stroke_tool_y_onehot,batch_size= batch_size,verbose=2)

report_dtw = open(MODEL_SAVE_FOLDER_PATH + "/Comp_DTW_stroke_tool.txt",'w+t')
print("[Before DTW] Before DTW stroke_tool \n", classification_report(test_stroke_tool_y, pred_stroke_tool_y, target_names=target_names), file = report_dtw)
print("------------------------------\n ", file = report_dtw)
print("[After DTW] After DTW stroke_tool \n", classification_report(test_stroke_tool_y, stroke_tool_results, target_names=target_names), file = report_dtw)
report_dtw.close()

# ----------- Visualize in cell
print("[Before DTW] Before DTW stroke_tool \n", classification_report(test_stroke_tool_y, pred_stroke_tool_y, target_names=target_names))
print("------------------------------\n ")
print("[After DTW] After DTW stroke_tool \n", classification_report(test_stroke_tool_y, stroke_tool_results, target_names=target_names))
# Out:
# 3/3 - 16s - loss: 0.6622 - accuracy: 0.7754
# [Before DTW] Before DTW stroke_tool
#                precision    recall  f1-score   support
#
#          sit       0.97      0.58      0.73        62
# sit-to-stand       0.59      0.31      0.40       147
#         walk       1.00      0.80      0.89       840
#         turn       0.78      1.00      0.88       220
# stand-to-sit       0.21      0.90      0.35        62
#
#     accuracy                           0.78      1331
#    macro avg       0.71      0.72      0.65      1331
# weighted avg       0.88      0.78      0.80      1331
#
# ------------------------------
#
# [After DTW] After DTW stroke_tool
#                precision    recall  f1-score   support
#
#          sit       0.83      0.40      0.54        62
# sit-to-stand       0.53      0.28      0.36       147
#         walk       0.88      0.90      0.89       840
#         turn       0.78      1.00      0.88       220
# stand-to-sit       0.72      0.92      0.81        62
#
#     accuracy                           0.83      1331
#    macro avg       0.75      0.70      0.70      1331
# weighted avg       0.81      0.83      0.81      1331

# %%
test_copy_stroke = "/DockerProjects/Dataset/TUG/trainSet/HMM_saveResults_최윤정/0_sideView/2020_12_30 TUG/YSJ_TUG/03/Originact5_lpf_labeled_YSJ_TUG_03.csv"
test_copy_stroke_x, test_copy_stroke_y_onehot = create_testdata(test_copy_stroke) 
test_copy_stroke_y = np.argmax(test_copy_stroke_y_onehot, axis=1).reshape(-1) #one-hot decode

pred_copy_stroke_onehot = model.predict(test_copy_stroke_x)
pred_copy_stroke_y = np.argmax(pred_copy_stroke_onehot, axis=1)


copy_stroke_alignment, copy_stroke_results = post_process_DTW(pred_copy_stroke_y, answer_y)
copy_stroke_alignment.plot(type="threeway")
plot_postResults(test_copy_stroke_y, pred_copy_stroke_y, copy_stroke_results, title="copy_stroke")


# ----- [Before DTW] Model Test
copy_stroke_eval = model.evaluate(test_copy_stroke_x, test_copy_stroke_y_onehot,batch_size= batch_size,verbose=2)

report_dtw = open(MODEL_SAVE_FOLDER_PATH + "/Comp_DTW_copy_stroke.txt",'w+t')
print("[Before DTW] Before DTW copy_stroke \n", classification_report(test_copy_stroke_y, pred_copy_stroke_y, target_names=target_names), file = report_dtw)
print("------------------------------\n", file = report_dtw)
print("[After DTW] After DTW copy_stroke \n", classification_report(test_copy_stroke_y, copy_stroke_results, target_names=target_names), file = report_dtw)
report_dtw.close()


# ----------- Visualize in cell
print("[Before DTW] Before DTW copy_stroke \n", classification_report(test_copy_stroke_y, pred_copy_stroke_y, target_names=target_names))
print("------------------------------\n")
print("[After DTW] After DTW copy_stroke \n", classification_report(test_copy_stroke_y, copy_stroke_results, target_names=target_names))
# Out:
# 3/3 - 0s - loss: 0.3951 - accuracy: 0.9015
# [Before DTW] Before DTW copy_stroke
#                precision    recall  f1-score   support
#
#          sit       0.99      1.00      0.99       294
# sit-to-stand       0.93      0.33      0.48        43
#         walk       0.90      0.91      0.91       537
#         turn       0.69      1.00      0.82       108
# stand-to-sit       1.00      0.65      0.79        74
#
#     accuracy                           0.90      1056
#    macro avg       0.90      0.78      0.80      1056
# weighted avg       0.91      0.90      0.90      1056
#
# ------------------------------
#
# [After DTW] After DTW copy_stroke
#                precision    recall  f1-score   support
#
#          sit       0.99      1.00      0.99       294
# sit-to-stand       0.94      0.37      0.53        43
#         walk       0.91      0.91      0.91       537
#         turn       0.69      1.00      0.82       108
# stand-to-sit       1.00      0.65      0.79        74
#
#     accuracy                           0.90      1056
#    macro avg       0.91      0.79      0.81      1056
# weighted avg       0.92      0.90      0.90      1056

# %%
import os
import numpy as np 
from sklearn.model_selection import KFold  # 라벨 x_data, y_data 분포를 유지 (함께 fold)
import tensorflow as tf 
from IPython.display import clear_output

np.random.seed(7)
np.set_printoptions(precision=4, suppress=True)  # 과학적 표기 대신 소숫점 자리 4자리까지 표현

rootDir = "/DockerProjects/Dataset/TUG/trainSet"
expertFolder = "/" + "HMM_saveResults_최윤정"  # --- 변경 할 부분
viewFolder = "/" + "0_sideView"

print(" [Home Dir.] Current path", os.getcwd())  

datasetDir = rootDir + expertFolder + viewFolder
os.chdir(datasetDir) ; print(" Current workaing path [dataset] ", os.getcwd())  # -- Dataset 있는 곳으로 경로 변경
# Out:
#  [Home Dir.] Current path /DockerProjects/Dataset/TUG/trainSet/HMM_saveResults_최윤정/0_sideView
#  Current workaing path [dataset]  /DockerProjects/Dataset/TUG/trainSet/HMM_saveResults_최윤정/0_sideView

# %%
def get_subjectList(datasetDir, shuffle = False):      
    expDates = next(os.walk(datasetDir))[1]   #['2020_11_03', '2020_11_20_v1', '2020_11_20_v2', '2020_11_23', '2020_12_09', '2020_12_30']
    subject_number = 0
    subjects_list = []
    
    for dateFolder in expDates:
        dateDir = os.path.join(datasetDir, dateFolder)   # D:/바탕화면/Dataset/TUG/trainSet/2021_01_24_saveResults_최윤정/0_sideView\2020_11_03
        tmpSubjects = next(os.walk(dateDir))[1]
        subjects_list.append(tmpSubjects)  
        subject_number += len(tmpSubjects)

    # ------ 2D -> 1D [[sub1, sub2], [sub3, sub4]] -> [sub1, sub2, sub3, sub4]
    subjects = []
    for eachSub in subjects_list:
        subjects += eachSub

    if shuffle:
        np.random.shuffle(subjects)
        
    print(" 1D sub list: " , subjects)
    return subjects, subject_number

def fold_trainNames(subList, Kfold_num = 5):
    assert (Kfold_num is not 0), print("check kfold_num. should not be zero")
    Fold_results =[]
    kfold = KFold(n_splits=  Kfold_num)
    
    for trainIdx, testIdx in kfold.split(subList):
        Fold_results.append([trainIdx, testIdx])      
        
    train_Fold= []
    test_Fold = []
        
    # bind fold pair
    for i in range(Kfold_num):
        tmp_train = []
        tmp_test = []
        for subIdx in range(len(subList)): 
            if subIdx in Fold_results[i][0]:  # 
                tmp_train.append(subList[subIdx])
                    
            if subIdx in Fold_results[i][1]:  # -- K-fold test
                tmp_test.append(subList[subIdx])
          
        train_Fold.append(tmp_train)
        test_Fold.append(tmp_test)
        print("\t [process]", i, "-fold:", train_Fold[i], "\n\t\t\t   ,", test_Fold[i])
    print("\n [results]  trainSet: ", len(train_Fold[0]) , " 명 , testSet: ", len(test_Fold[0]), " 명" )
    
    return train_Fold, test_Fold

# %%
train_ratio = 0.6
valid_ratio = 0.2

arbitrarySplit = True
Kfold = False
Kfold_num = 5 # if kfold_num = 0 (arbitrary train/test set will be used)s


numFeature = 3
numActions = 5
dataset_columns = numFeature + numActions

subList, numOfsubjects = get_subjectList(datasetDir, shuffle = False) ; print("\n")

if arbitrarySplit is not True:
    if Kfold:
        print(" K-fold : ", Kfold_num)
        trainFold, testFold = fold_trainNames(subList = subList, Kfold_num = Kfold_num)

        selected_foldNum = 0 

        train_subjects = trainFold[selected_foldNum]
        test_subjects = testFold[selected_foldNum]
        print("\t ------>  Selected Fold num: %d \n   Train Subjects: %s\n   Test Subjects: %s"%(selected_foldNum, train_subjects, test_subjects))
    else:

        trainSub_number = np.round( (numOfsubjects*train_ratio), 0).astype(int)
        validSub_number = np.round( (numOfsubjects*valid_ratio), 0).astype(int)
        testSub_number = numOfsubjects - trainSub_number - validSub_number

        train_subjects = subList[ :trainSub_number]
        valid_subjects = subList[ trainSub_number : (trainSub_number+validSub_number)]
        test_subjects = subList[ (trainSub_number+validSub_number): ]
        print("   No-fold \t [results] \n\t Train: " ,train_subjects, "\n\t Valid: ", valid_subjects, "\n\t Test: ", test_subjects)
        print("\n\t--> # of train  : " + str(trainSub_number) +" 명 ,  # of valid : "+ str(validSub_number) + " 명 ,  # of test :" + str(testSub_number) + "명")

else:
    #         normal_subjects = ['bys_tug', 'cbd_tug', 'cyj_tug', 'kw', 'kyh', 'lhs', 'NHJ_60', 'nhs', 'pjh', 'pss', 'rjh', 'yjh', 'bys', 'cbd', 'cyj', 'cyj2', 'jdh', 'jek', 'kch', 'ryu'] 
#         patients_subjects = ['JDW_tug']
#         copy_patients_subjects = ['BYS_TUG', 'CYJ_TUG', 'PHE_TUG', 'YSJ_TUG'] 

#     train_subjects = ['bys_tug', 'cbd_tug', 'cyj_tug', 'kw', 'kyh', 'nhs', 'pjh', 'pss', 'rjh', 'yjh', 'bys', 'cbd', 'cyj'] 
#     valid_subjects = ['cyj2', 'jdh', 'jek', 'lhs' ] 
#     test_subjects =  ['kch', 'ryu', 'NHJ_60']
    train_subjects = ['bys_tug', 'cbd_tug', 'cyj_tug', 'pss', 'yjh', 'lhs', 'kyh', 'nhs', 'kw', 'NHJ_60', 'pjh', 'rjh', 'ryu','CYJ_TUG', 'BYS_TUG'] 
    valid_subjects = [ 'YSJ_TUG','jdh', 'cbd', 'kch', 'bys' ] 
    test_subjects =  ['jek', 'cyj', 'cyj2', 'JDW_tug', 'PHE_TUG']
    print(" No-fold --- (arbitrary) \t [results] \n\t Train: " ,train_subjects, "\n\t Valid: ", valid_subjects, "\n\t Test: ", test_subjects)
# Out:
#  1D sub list:  ['KYS_TUG', 'GYH_TUG', 'KJK_TUG', 'LSJ_TUG', 'LKO_TUG', 'PBK_TUG', 'bys_tug', 'cbd_tug', 'cyj_tug', 'SJJ_TUG', 'YSS_TUG', 'HOJ_TUG', 'WHS_TUG', 'UMS_TUG', 'JJS_TUG', 'LBL_TUG', 'KJH_TUG', 'CSY_TUG', 'pss', 'yjh', 'lhs', 'kyh', 'nhs', 'kw', 'NHJ_60', 'pjh', 'rjh', 'KYS_TUG', 'RJD_TUG', '.ipynb_checkpoints', 'YSS_TUG', 'SRK_TUG', 'KSG_TUG', 'KNG_TUG', 'YBJ_TUG', 'JDW_tug', 'PHE_TUG', 'YSJ_TUG', 'CYJ_TUG', 'BYS_TUG', 'KYS_TUG', '.ipynb_checkpoints', 'HHS_TUG', 'KTS_TUG', 'KSJ_TUG', 'jdh', 'cbd', 'kch', 'bys', 'jek', 'cyj', 'cyj2']
#
#
#  No-fold --- (arbitrary) 	 [results]
# 	 Train:  ['bys_tug', 'cbd_tug', 'cyj_tug', 'pss', 'yjh', 'lhs', 'kyh', 'nhs', 'kw', 'NHJ_60', 'pjh', 'rjh', 'ryu', 'CYJ_TUG', 'BYS_TUG']
# 	 Valid:  ['YSJ_TUG', 'jdh', 'cbd', 'kch', 'bys']
# 	 Test:  ['jek', 'cyj', 'cyj2', 'JDW_tug', 'PHE_TUG']

# %% [markdown]
# ### Subject name list -> train/valid/test split

# %%
def getPelvisData(csvFile):
    rawData = np.loadtxt(csvFile, delimiter=",", )
    timestamp = rawData[:,0]
    pelvis_x = rawData[:,1]
    pelvis_y = rawData[:,2]
    pelvis_z = rawData[:,3]
    actionList = rawData[:,4:9]
    return timestamp, pelvis_x, pelvis_y, pelvis_z, actionList

def sliding_window(timestamp, data_x, data_y, lookback_window=3):
    time = []
    x = []
    y = []
    enc = MinMaxScaler(feature_range = (0, 1))
    enc_y = enc.fit_transform(data_y)
    for i in range(lookback_window, len(data_x)+1):
        time.append(timestamp[i-1])
        x.append(data_x[i - lookback_window:i])
        y.append(data_y[i-1])
  
    x = np.array(x)
    x = x.reshape(-1, lookback_window, numFeature, 1)
    
    y = np.array(y)
    time = np.array(time)
   
    return time, x, y, enc


def create_dataset(Kfold, train_subjects, test_subjects, lookback_window = 3):
    train_x = np.zeros((0, lookback_window, numFeature, 1))
    train_y = np.zeros((0, numActions))
    
    valid_x = np.zeros((0, lookback_window, numFeature, 1))
    valid_y = np.zeros((0, numActions))
    
    test_x = np.zeros((0, lookback_window, numFeature,1 ))
    test_y = np.zeros((0, numActions))    
    
    
    for dirpath, foldername, files in sorted(os.walk(datasetDir)):
        for filename in files:
            if "lpf_" in filename:
                subname = dirpath.split("/")[-2] 
                csvFile = os.path.join(dirpath, filename)
                          
                timestamp, pelvis_x, pelvis_y, pelvis_z, actionList = getPelvisData(csvFile) 
                
                pelvisData = np.array([pelvis_x, pelvis_y, pelvis_z]).T  # (317,3)
                actionData = np.array(actionList)    # # (335, 5)
    
                blockTime, blockPelvis, blockLable, enc = sliding_window(timestamp, data_x = pelvisData, data_y = actionData, lookback_window=lookback_window) # pelvis - (327, 8, 3)

                if Kfold is not True:
                    if subname in train_subjects:
                        train_x = np.append(train_x, blockPelvis, axis = 0 )
                        train_y = np.append(train_y, blockLable, axis = 0 )

                    elif subname in valid_subjects:
                        valid_x = np.append(valid_x, blockPelvis, axis = 0 )
                        valid_y = np.append(valid_y, blockLable, axis = 0 )

                    elif subname in test_subjects:
                        test_x = np.append(test_x, blockPelvis, axis = 0 )
                        test_y = np.append(test_y, blockLable, axis = 0 )    
                else:
                    if subname in train_subjects:
                        train_x = np.append(train_x, blockPelvis, axis = 0 )
                        train_y = np.append(train_y, blockLable, axis = 0 )
                    elif subname in test_subjects:
                        test_x = np.append(test_x, blockPelvis, axis = 0 )
                        test_y = np.append(test_y, blockLable, axis = 0 )        
            
    return train_x, train_y, valid_x, valid_y, test_x, test_y

# %%
from sklearn.preprocessing import MinMaxScaler

lookback_window = 8
batch_size = 512
epochs = 1000
learning_rate = 0.00001

train_x, train_y, valid_x, valid_y, test_x, test_y = create_dataset(Kfold, train_subjects, test_subjects, lookback_window = lookback_window)
print("train_x: ", train_x.shape," , train_y: ", train_y.shape)
print("valid_x: ",valid_x.shape, " , valid_y: ",valid_y.shape)
print("test_x: ",test_x.shape, "  , test_y: ",test_y.shape)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-9-96bafdbfb48d> in <module>
#       6 learning_rate = 0.00001
#       7
# ----> 8 train_x, train_y, valid_x, valid_y, test_x, test_y = create_dataset(Kfold, train_subjects, test_subjects, lookback_window = lookback_window)
#       9 print("train_x: ", train_x.shape," , train_y: ", train_y.shape)
#      10 print("valid_x: ",valid_x.shape, " , valid_y: ",valid_y.shape)
#
# <ipython-input-8-f8a9544dbb4a> in create_dataset(Kfold, train_subjects, test_subjects, lookback_window)
#      45                 csvFile = os.path.join(dirpath, filename)
#      46
# ---> 47                 timestamp, pelvis_x, pelvis_y, pelvis_z, actionList = getPelvisData(csvFile)
#      48
#      49                 pelvisData = np.array([pelvis_x, pelvis_y, pelvis_z]).T  # (317,3)
#
# <ipython-input-8-f8a9544dbb4a> in getPelvisData(csvFile)
#       1 def getPelvisData(csvFile):
# ----> 2     rawData = np.loadtxt(csvFile, delimiter=",")
#       3     timestamp = rawData[:,0]
#       4     pelvis_x = rawData[:,1]
#       5     pelvis_y = rawData[:,2]
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1090         try:
#    1091             while not first_vals:
# -> 1092                 first_line = next(fh)
#    1093                 first_vals = split_line(first_line)
#    1094         except StopIteration:
#
# /usr/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte

# %% [markdown]
# ### Model Build

# %%
from keras.layers import Conv1D, Input, Activation, Flatten, Dense, Conv2D
from keras.layers import BatchNormalization, add , Dropout
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tcn import TCN

# %%
MODEL_SAVE_FOLDER_PATH = rootDir + "/"+ expertFolder +"/model_TCN/"

print(MODEL_SAVE_FOLDER_PATH)
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)
    
model_path = MODEL_SAVE_FOLDER_PATH + "WinSize- "+ str(lookback_window) +"TUG-" + "{epoch:02d} ---- {val_loss: .4f}.hdf5"

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor="val_loss", verbose=1, save_best_only=True)
cb_early_stopping = EarlyStopping(monitor="val_loss", patience=10)
# Out:
# /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/

# %%
 #Residual block :: https://roadcom.tistory.com/95
def ResBlock(x,filters,kernel_size,dilation_rate):
    r=Conv2D(filters,kernel_size=kernel_size,padding='same',dilation_rate=dilation_rate,activation='relu')(x) #first convolution
    r=Conv2D(filters,kernel_size=kernel_size,padding='same',dilation_rate=dilation_rate)(r) #Second convolution
    if x.shape[-1]==filters:
        # Shortcut 의 channel 과 main path 의 channel 이 일치할 경우 단순 add 연산만 진행하는 블록 = identity block
        shortcut = x  # identity block 
    else: 
        # Shortcut 의 channel 과 main path 의 channel 이 다를 경우 shortcut path 를 적절히 변환
        # 즉, projection 을 통해 channel 을 맞춰주는 작업이(projection shortcut) 추가되기에 이를 convolution block 이라함
        shortcut=Conv2D(filters,kernel_size=kernel_size,padding='same')(x) 
    o=add([r,shortcut])
    o=Activation('relu')(o) 
    return o
 
 #Sequence Model
def TCN(optimizer='adam'):
    kernel_size = (3,3)
    input_shape =  (lookback_window, 3, 1) # (8,3, 1) = (feature, sliding_window, 1)
    
    inputs=Input(shape=input_shape)
    
    x=ResBlock(x = inputs,filters=32,kernel_size=kernel_size,dilation_rate=1)
    x = Dropout(0.2) (x)
    x=ResBlock(x,filters=32,kernel_size=kernel_size,dilation_rate=2)
    x = Dropout(0.4)(x)
    x=ResBlock(x,filters=16,kernel_size=kernel_size,dilation_rate=4)
    
    x=Flatten()(x)
    x=Dense(5, activation='softmax')(x)
    model=Model(inputs=inputs,outputs=x)
         
    model.summary()
        
    model.compile(optimizer=optimizer,loss='categorical_crossentropy', metrics=['accuracy'])
 
    return model

# %%
# (feature, sliding_window, 1) ...TCN,,,  
# class_weight = {0:0.303, 1:1.0, 2: 0.144, 3:0.487, 4: 0.7}

optimizer = tf.optimizers.Adam(learning_rate)


model = TCN(optimizer)
# hist = model.fit(train_x,train_y,batch_size= batch_size, epochs=epochs,verbose=2, validation_data= (valid_x, valid_y),  callbacks=[cb_checkpoint, cb_early_stopping], class_weight=class_weight)
hist =  model.fit(train_x,train_y,batch_size = batch_size, epochs=epochs, verbose=2, validation_data= (valid_x, valid_y),  callbacks=[cb_early_stopping], class_weight=class_weight)
eval_result = eval_result = model.evaluate(test_x, test_y,batch_size= batch_size,verbose=2)

print('test_loss:',eval_result[0],'- test_acc:',eval_result[1])

# %%
optimizer = tf.optimizers.Adam(learning_rate)
model = TCN(optimizer)

hist =  model.fit(train_x,train_y,batch_size = batch_size, epochs=epochs, verbose=2, validation_data= (valid_x, valid_y),  callbacks=[cb_early_stopping])
eval_result = eval_result = model.evaluate(test_x, test_y,batch_size= batch_size,verbose=2)

print('test_loss:',eval_result[0],'- test_acc:',eval_result[1])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8, 3, 1)]    0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 8, 3, 32)     320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 3, 32)     9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 3, 32)     320         input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8, 3, 32)     0           conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 8, 3, 32)     0           add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 8, 3, 32)     0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 3, 32)     9248        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 3, 32)     9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 3, 32)     0           conv2d_4[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8, 3, 32)     0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 3, 32)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 3, 16)     4624        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 3, 16)     2320        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 3, 16)     4624        dropout_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 3, 16)     0           conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 8, 3, 16)     0           add_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 384)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 5)            1925        flatten[0][0]
# ==================================================================================================
# Total params: 41,877
# Trainable params: 41,877
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/1000
# 128/128 - 48s - loss: 1.6325 - accuracy: 0.1395 - val_loss: 1.5830 - val_accuracy: 0.4801
# Epoch 2/1000
# 128/128 - 1s - loss: 1.5432 - accuracy: 0.4327 - val_loss: 1.4966 - val_accuracy: 0.4793
# Epoch 3/1000
# 128/128 - 1s - loss: 1.4544 - accuracy: 0.5374 - val_loss: 1.4223 - val_accuracy: 0.4793
# Epoch 4/1000
# 128/128 - 1s - loss: 1.3787 - accuracy: 0.5395 - val_loss: 1.3705 - val_accuracy: 0.4793
# Epoch 5/1000
# 128/128 - 1s - loss: 1.3205 - accuracy: 0.5395 - val_loss: 1.3312 - val_accuracy: 0.4793
# Epoch 6/1000
# 128/128 - 1s - loss: 1.2769 - accuracy: 0.5402 - val_loss: 1.2964 - val_accuracy: 0.4793
# Epoch 7/1000
# 128/128 - 1s - loss: 1.2382 - accuracy: 0.5461 - val_loss: 1.2606 - val_accuracy: 0.4793
# Epoch 8/1000
# 128/128 - 1s - loss: 1.1994 - accuracy: 0.5776 - val_loss: 1.2213 - val_accuracy: 0.6314
# Epoch 9/1000
# 128/128 - 1s - loss: 1.1576 - accuracy: 0.6289 - val_loss: 1.1758 - val_accuracy: 0.6584
# Epoch 10/1000
# 128/128 - 1s - loss: 1.1096 - accuracy: 0.6796 - val_loss: 1.1244 - val_accuracy: 0.6592
# Epoch 11/1000
# 128/128 - 1s - loss: 1.0554 - accuracy: 0.7051 - val_loss: 1.0647 - val_accuracy: 0.6685
# Epoch 12/1000
# 128/128 - 1s - loss: 0.9942 - accuracy: 0.7165 - val_loss: 1.0008 - val_accuracy: 0.6890
# Epoch 13/1000
# 128/128 - 1s - loss: 0.9287 - accuracy: 0.7196 - val_loss: 0.9354 - val_accuracy: 0.7019
# Epoch 14/1000
# 128/128 - 1s - loss: 0.8677 - accuracy: 0.7201 - val_loss: 0.8821 - val_accuracy: 0.7033
# Epoch 15/1000
# 128/128 - 1s - loss: 0.8173 - accuracy: 0.7201 - val_loss: 0.8413 - val_accuracy: 0.7037
# Epoch 16/1000
# 128/128 - 1s - loss: 0.7811 - accuracy: 0.7201 - val_loss: 0.8120 - val_accuracy: 0.7037
# Epoch 17/1000
# 128/128 - 1s - loss: 0.7551 - accuracy: 0.7201 - val_loss: 0.7892 - val_accuracy: 0.7037
# Epoch 18/1000
# 128/128 - 1s - loss: 0.7359 - accuracy: 0.7206 - val_loss: 0.7688 - val_accuracy: 0.7037
# Epoch 19/1000
# 128/128 - 1s - loss: 0.7199 - accuracy: 0.7213 - val_loss: 0.7528 - val_accuracy: 0.7037
# Epoch 20/1000
# 128/128 - 1s - loss: 0.7050 - accuracy: 0.7243 - val_loss: 0.7361 - val_accuracy: 0.7074
# Epoch 21/1000
# 128/128 - 1s - loss: 0.6936 - accuracy: 0.7280 - val_loss: 0.7233 - val_accuracy: 0.7121
# Epoch 22/1000
# 128/128 - 1s - loss: 0.6819 - accuracy: 0.7318 - val_loss: 0.7122 - val_accuracy: 0.7164
# Epoch 23/1000
# 128/128 - 1s - loss: 0.6723 - accuracy: 0.7353 - val_loss: 0.6986 - val_accuracy: 0.7212
# Epoch 24/1000
# 128/128 - 1s - loss: 0.6622 - accuracy: 0.7383 - val_loss: 0.6900 - val_accuracy: 0.7249
# Epoch 25/1000
# 128/128 - 1s - loss: 0.6551 - accuracy: 0.7425 - val_loss: 0.6792 - val_accuracy: 0.7280
# Epoch 26/1000
# 128/128 - 1s - loss: 0.6484 - accuracy: 0.7445 - val_loss: 0.6704 - val_accuracy: 0.7317
# Epoch 27/1000
# 128/128 - 1s - loss: 0.6424 - accuracy: 0.7461 - val_loss: 0.6638 - val_accuracy: 0.7339
# Epoch 28/1000
# 128/128 - 1s - loss: 0.6340 - accuracy: 0.7480 - val_loss: 0.6563 - val_accuracy: 0.7369
# Epoch 29/1000
# 128/128 - 1s - loss: 0.6291 - accuracy: 0.7492 - val_loss: 0.6510 - val_accuracy: 0.7393
# Epoch 30/1000
# 128/128 - 1s - loss: 0.6248 - accuracy: 0.7518 - val_loss: 0.6467 - val_accuracy: 0.7414
# Epoch 31/1000
# 128/128 - 1s - loss: 0.6183 - accuracy: 0.7531 - val_loss: 0.6413 - val_accuracy: 0.7436
# Epoch 32/1000
# 128/128 - 1s - loss: 0.6126 - accuracy: 0.7547 - val_loss: 0.6362 - val_accuracy: 0.7450
# Epoch 33/1000
# 128/128 - 1s - loss: 0.6079 - accuracy: 0.7566 - val_loss: 0.6326 - val_accuracy: 0.7468
# Epoch 34/1000
# 128/128 - 1s - loss: 0.6064 - accuracy: 0.7583 - val_loss: 0.6290 - val_accuracy: 0.7483
# Epoch 35/1000
# 128/128 - 1s - loss: 0.6019 - accuracy: 0.7581 - val_loss: 0.6237 - val_accuracy: 0.7499
# Epoch 36/1000
# 128/128 - 1s - loss: 0.5993 - accuracy: 0.7587 - val_loss: 0.6246 - val_accuracy: 0.7507
# Epoch 37/1000
# 128/128 - 1s - loss: 0.5956 - accuracy: 0.7605 - val_loss: 0.6204 - val_accuracy: 0.7519
# Epoch 38/1000
# 128/128 - 1s - loss: 0.5927 - accuracy: 0.7608 - val_loss: 0.6179 - val_accuracy: 0.7512
# Epoch 39/1000
# 128/128 - 1s - loss: 0.5905 - accuracy: 0.7622 - val_loss: 0.6174 - val_accuracy: 0.7509
# Epoch 40/1000
# 128/128 - 1s - loss: 0.5879 - accuracy: 0.7625 - val_loss: 0.6145 - val_accuracy: 0.7520
# Epoch 41/1000
# 128/128 - 1s - loss: 0.5849 - accuracy: 0.7641 - val_loss: 0.6095 - val_accuracy: 0.7530
# Epoch 42/1000
# 128/128 - 1s - loss: 0.5818 - accuracy: 0.7654 - val_loss: 0.6109 - val_accuracy: 0.7534
# Epoch 43/1000
# 128/128 - 1s - loss: 0.5806 - accuracy: 0.7656 - val_loss: 0.6092 - val_accuracy: 0.7539
# Epoch 44/1000
# 128/128 - 1s - loss: 0.5783 - accuracy: 0.7664 - val_loss: 0.6074 - val_accuracy: 0.7544
# Epoch 45/1000
# 128/128 - 1s - loss: 0.5750 - accuracy: 0.7667 - val_loss: 0.6061 - val_accuracy: 0.7551
# Epoch 46/1000
# 128/128 - 1s - loss: 0.5734 - accuracy: 0.7675 - val_loss: 0.6055 - val_accuracy: 0.7544
# Epoch 47/1000
# 128/128 - 1s - loss: 0.5726 - accuracy: 0.7682 - val_loss: 0.6035 - val_accuracy: 0.7547
# Epoch 48/1000
# 128/128 - 1s - loss: 0.5706 - accuracy: 0.7682 - val_loss: 0.6009 - val_accuracy: 0.7553
# Epoch 49/1000
# 128/128 - 1s - loss: 0.5687 - accuracy: 0.7688 - val_loss: 0.6010 - val_accuracy: 0.7554
# Epoch 50/1000
# 128/128 - 1s - loss: 0.5675 - accuracy: 0.7692 - val_loss: 0.6018 - val_accuracy: 0.7546
# Epoch 51/1000
# 128/128 - 1s - loss: 0.5675 - accuracy: 0.7699 - val_loss: 0.5969 - val_accuracy: 0.7558
# Epoch 52/1000
# 128/128 - 1s - loss: 0.5639 - accuracy: 0.7708 - val_loss: 0.5971 - val_accuracy: 0.7572
# Epoch 53/1000
# 128/128 - 1s - loss: 0.5625 - accuracy: 0.7708 - val_loss: 0.5962 - val_accuracy: 0.7586
# Epoch 54/1000
# 128/128 - 1s - loss: 0.5613 - accuracy: 0.7709 - val_loss: 0.5914 - val_accuracy: 0.7597
# Epoch 55/1000
# 128/128 - 1s - loss: 0.5596 - accuracy: 0.7720 - val_loss: 0.5915 - val_accuracy: 0.7598
# Epoch 56/1000
# 128/128 - 1s - loss: 0.5588 - accuracy: 0.7724 - val_loss: 0.5872 - val_accuracy: 0.7613
# Epoch 57/1000
# 128/128 - 1s - loss: 0.5561 - accuracy: 0.7722 - val_loss: 0.5878 - val_accuracy: 0.7613
# Epoch 58/1000
# 128/128 - 1s - loss: 0.5556 - accuracy: 0.7742 - val_loss: 0.5865 - val_accuracy: 0.7608
# Epoch 59/1000
# 128/128 - 1s - loss: 0.5512 - accuracy: 0.7733 - val_loss: 0.5823 - val_accuracy: 0.7633
# Epoch 60/1000
# 128/128 - 1s - loss: 0.5509 - accuracy: 0.7741 - val_loss: 0.5820 - val_accuracy: 0.7631
# Epoch 61/1000
# 128/128 - 1s - loss: 0.5505 - accuracy: 0.7749 - val_loss: 0.5820 - val_accuracy: 0.7632
# Epoch 62/1000
# 128/128 - 1s - loss: 0.5491 - accuracy: 0.7749 - val_loss: 0.5759 - val_accuracy: 0.7649
# Epoch 63/1000
# 128/128 - 1s - loss: 0.5495 - accuracy: 0.7750 - val_loss: 0.5805 - val_accuracy: 0.7637
# Epoch 64/1000
# 128/128 - 1s - loss: 0.5456 - accuracy: 0.7760 - val_loss: 0.5775 - val_accuracy: 0.7649
# Epoch 65/1000
# 128/128 - 1s - loss: 0.5438 - accuracy: 0.7763 - val_loss: 0.5759 - val_accuracy: 0.7652
# Epoch 66/1000
# 128/128 - 1s - loss: 0.5412 - accuracy: 0.7777 - val_loss: 0.5743 - val_accuracy: 0.7656
# Epoch 67/1000
# 128/128 - 1s - loss: 0.5412 - accuracy: 0.7780 - val_loss: 0.5715 - val_accuracy: 0.7677
# Epoch 68/1000
# 128/128 - 1s - loss: 0.5392 - accuracy: 0.7782 - val_loss: 0.5697 - val_accuracy: 0.7678
# Epoch 69/1000
# 128/128 - 1s - loss: 0.5381 - accuracy: 0.7793 - val_loss: 0.5669 - val_accuracy: 0.7692
# Epoch 70/1000
# 128/128 - 1s - loss: 0.5372 - accuracy: 0.7797 - val_loss: 0.5691 - val_accuracy: 0.7672
# Epoch 71/1000
# 128/128 - 1s - loss: 0.5382 - accuracy: 0.7788 - val_loss: 0.5673 - val_accuracy: 0.7678
# Epoch 72/1000
# 128/128 - 1s - loss: 0.5356 - accuracy: 0.7800 - val_loss: 0.5717 - val_accuracy: 0.7673
# Epoch 73/1000
# 128/128 - 1s - loss: 0.5356 - accuracy: 0.7807 - val_loss: 0.5651 - val_accuracy: 0.7680
# Epoch 74/1000
# 128/128 - 1s - loss: 0.5335 - accuracy: 0.7815 - val_loss: 0.5641 - val_accuracy: 0.7693
# Epoch 75/1000
# 128/128 - 1s - loss: 0.5302 - accuracy: 0.7804 - val_loss: 0.5629 - val_accuracy: 0.7699
# Epoch 76/1000
# 128/128 - 1s - loss: 0.5293 - accuracy: 0.7807 - val_loss: 0.5599 - val_accuracy: 0.7710
# Epoch 77/1000
# 128/128 - 1s - loss: 0.5280 - accuracy: 0.7821 - val_loss: 0.5591 - val_accuracy: 0.7712
# Epoch 78/1000
# 128/128 - 1s - loss: 0.5289 - accuracy: 0.7821 - val_loss: 0.5593 - val_accuracy: 0.7714
# Epoch 79/1000
# 128/128 - 1s - loss: 0.5268 - accuracy: 0.7821 - val_loss: 0.5552 - val_accuracy: 0.7722
# Epoch 80/1000
# 128/128 - 1s - loss: 0.5251 - accuracy: 0.7826 - val_loss: 0.5524 - val_accuracy: 0.7726
# Epoch 81/1000
# 128/128 - 1s - loss: 0.5237 - accuracy: 0.7823 - val_loss: 0.5537 - val_accuracy: 0.7716
# Epoch 82/1000
# 128/128 - 1s - loss: 0.5221 - accuracy: 0.7848 - val_loss: 0.5553 - val_accuracy: 0.7712
# Epoch 83/1000
# 128/128 - 1s - loss: 0.5222 - accuracy: 0.7843 - val_loss: 0.5517 - val_accuracy: 0.7721
# Epoch 84/1000
# 128/128 - 1s - loss: 0.5200 - accuracy: 0.7863 - val_loss: 0.5473 - val_accuracy: 0.7739
# Epoch 85/1000
# 128/128 - 1s - loss: 0.5201 - accuracy: 0.7861 - val_loss: 0.5490 - val_accuracy: 0.7735
# Epoch 86/1000
# 128/128 - 1s - loss: 0.5174 - accuracy: 0.7858 - val_loss: 0.5488 - val_accuracy: 0.7732
# Epoch 87/1000
# 128/128 - 1s - loss: 0.5164 - accuracy: 0.7876 - val_loss: 0.5438 - val_accuracy: 0.7756
# Epoch 88/1000
# 128/128 - 1s - loss: 0.5164 - accuracy: 0.7871 - val_loss: 0.5440 - val_accuracy: 0.7756
# Epoch 89/1000
# 128/128 - 1s - loss: 0.5149 - accuracy: 0.7889 - val_loss: 0.5432 - val_accuracy: 0.7760
# Epoch 90/1000
# 128/128 - 1s - loss: 0.5143 - accuracy: 0.7881 - val_loss: 0.5421 - val_accuracy: 0.7752
# Epoch 91/1000
# 128/128 - 1s - loss: 0.5126 - accuracy: 0.7894 - val_loss: 0.5416 - val_accuracy: 0.7751
# Epoch 92/1000
# 128/128 - 1s - loss: 0.5109 - accuracy: 0.7903 - val_loss: 0.5383 - val_accuracy: 0.7765
# Epoch 93/1000
# 128/128 - 1s - loss: 0.5089 - accuracy: 0.7899 - val_loss: 0.5373 - val_accuracy: 0.7766
# Epoch 94/1000
# 128/128 - 1s - loss: 0.5076 - accuracy: 0.7908 - val_loss: 0.5363 - val_accuracy: 0.7767
# Epoch 95/1000
# 128/128 - 1s - loss: 0.5059 - accuracy: 0.7929 - val_loss: 0.5330 - val_accuracy: 0.7784
# Epoch 96/1000
# 128/128 - 1s - loss: 0.5075 - accuracy: 0.7910 - val_loss: 0.5303 - val_accuracy: 0.7792
# Epoch 97/1000
# 128/128 - 1s - loss: 0.5016 - accuracy: 0.7946 - val_loss: 0.5258 - val_accuracy: 0.7799
# Epoch 98/1000
# 128/128 - 1s - loss: 0.5024 - accuracy: 0.7944 - val_loss: 0.5264 - val_accuracy: 0.7800
# Epoch 99/1000
# 128/128 - 1s - loss: 0.5015 - accuracy: 0.7953 - val_loss: 0.5251 - val_accuracy: 0.7802
# Epoch 100/1000
# 128/128 - 1s - loss: 0.4976 - accuracy: 0.7968 - val_loss: 0.5259 - val_accuracy: 0.7801
# Epoch 101/1000
# 128/128 - 1s - loss: 0.4965 - accuracy: 0.7984 - val_loss: 0.5216 - val_accuracy: 0.7807
# Epoch 102/1000
# 128/128 - 1s - loss: 0.4937 - accuracy: 0.7984 - val_loss: 0.5155 - val_accuracy: 0.7829
# Epoch 103/1000
# 128/128 - 1s - loss: 0.4930 - accuracy: 0.8002 - val_loss: 0.5182 - val_accuracy: 0.7817
# Epoch 104/1000
# 128/128 - 1s - loss: 0.4914 - accuracy: 0.8004 - val_loss: 0.5180 - val_accuracy: 0.7810
# Epoch 105/1000
# 128/128 - 1s - loss: 0.4899 - accuracy: 0.8002 - val_loss: 0.5137 - val_accuracy: 0.7837
# Epoch 106/1000
# 128/128 - 1s - loss: 0.4860 - accuracy: 0.8030 - val_loss: 0.5102 - val_accuracy: 0.7854
# Epoch 107/1000
# 128/128 - 1s - loss: 0.4857 - accuracy: 0.8032 - val_loss: 0.5070 - val_accuracy: 0.7865
# Epoch 108/1000
# 128/128 - 1s - loss: 0.4853 - accuracy: 0.8040 - val_loss: 0.5058 - val_accuracy: 0.7875
# Epoch 109/1000
# 128/128 - 1s - loss: 0.4834 - accuracy: 0.8052 - val_loss: 0.5059 - val_accuracy: 0.7869
# Epoch 110/1000
# 128/128 - 1s - loss: 0.4808 - accuracy: 0.8070 - val_loss: 0.5038 - val_accuracy: 0.7882
# Epoch 111/1000
# 128/128 - 1s - loss: 0.4768 - accuracy: 0.8082 - val_loss: 0.5048 - val_accuracy: 0.7884
# Epoch 112/1000
# 128/128 - 1s - loss: 0.4768 - accuracy: 0.8088 - val_loss: 0.4978 - val_accuracy: 0.7893
# Epoch 113/1000
# 128/128 - 1s - loss: 0.4743 - accuracy: 0.8093 - val_loss: 0.4950 - val_accuracy: 0.7935
# Epoch 114/1000
# 128/128 - 1s - loss: 0.4740 - accuracy: 0.8131 - val_loss: 0.4927 - val_accuracy: 0.7928
# Epoch 115/1000
# 128/128 - 1s - loss: 0.4711 - accuracy: 0.8143 - val_loss: 0.4934 - val_accuracy: 0.7919
# Epoch 116/1000
# 128/128 - 1s - loss: 0.4696 - accuracy: 0.8134 - val_loss: 0.4934 - val_accuracy: 0.7925
# Epoch 117/1000
# 128/128 - 1s - loss: 0.4688 - accuracy: 0.8154 - val_loss: 0.4944 - val_accuracy: 0.7941
# Epoch 118/1000
# 128/128 - 1s - loss: 0.4700 - accuracy: 0.8154 - val_loss: 0.4872 - val_accuracy: 0.7958
# Epoch 119/1000
# 128/128 - 1s - loss: 0.4661 - accuracy: 0.8150 - val_loss: 0.4842 - val_accuracy: 0.7962
# Epoch 120/1000
# 128/128 - 1s - loss: 0.4649 - accuracy: 0.8171 - val_loss: 0.4839 - val_accuracy: 0.7956
# Epoch 121/1000
# 128/128 - 1s - loss: 0.4617 - accuracy: 0.8182 - val_loss: 0.4781 - val_accuracy: 0.8029
# Epoch 122/1000
# 128/128 - 1s - loss: 0.4623 - accuracy: 0.8208 - val_loss: 0.4796 - val_accuracy: 0.8006
# Epoch 123/1000
# 128/128 - 1s - loss: 0.4606 - accuracy: 0.8211 - val_loss: 0.4823 - val_accuracy: 0.7984
# Epoch 124/1000
# 128/128 - 1s - loss: 0.4613 - accuracy: 0.8206 - val_loss: 0.4746 - val_accuracy: 0.8013
# Epoch 125/1000
# 128/128 - 1s - loss: 0.4551 - accuracy: 0.8222 - val_loss: 0.4737 - val_accuracy: 0.8019
# Epoch 126/1000
# 128/128 - 1s - loss: 0.4561 - accuracy: 0.8218 - val_loss: 0.4727 - val_accuracy: 0.8061
# Epoch 127/1000
# 128/128 - 1s - loss: 0.4558 - accuracy: 0.8239 - val_loss: 0.4685 - val_accuracy: 0.8079
# Epoch 128/1000
# 128/128 - 1s - loss: 0.4547 - accuracy: 0.8231 - val_loss: 0.4692 - val_accuracy: 0.8079
# Epoch 129/1000
# 128/128 - 1s - loss: 0.4506 - accuracy: 0.8266 - val_loss: 0.4680 - val_accuracy: 0.8058
# Epoch 130/1000
# 128/128 - 1s - loss: 0.4498 - accuracy: 0.8274 - val_loss: 0.4637 - val_accuracy: 0.8146
# Epoch 131/1000
# 128/128 - 1s - loss: 0.4481 - accuracy: 0.8292 - val_loss: 0.4615 - val_accuracy: 0.8144
# Epoch 132/1000
# 128/128 - 1s - loss: 0.4492 - accuracy: 0.8277 - val_loss: 0.4598 - val_accuracy: 0.8194
# Epoch 133/1000
# 128/128 - 1s - loss: 0.4463 - accuracy: 0.8294 - val_loss: 0.4626 - val_accuracy: 0.8135
# Epoch 134/1000
# 128/128 - 1s - loss: 0.4448 - accuracy: 0.8309 - val_loss: 0.4603 - val_accuracy: 0.8120
# Epoch 135/1000
# 128/128 - 1s - loss: 0.4457 - accuracy: 0.8301 - val_loss: 0.4609 - val_accuracy: 0.8165
# Epoch 136/1000
# 128/128 - 1s - loss: 0.4404 - accuracy: 0.8333 - val_loss: 0.4607 - val_accuracy: 0.8156
# Epoch 137/1000
# 128/128 - 1s - loss: 0.4415 - accuracy: 0.8338 - val_loss: 0.4558 - val_accuracy: 0.8229
# Epoch 138/1000
# 128/128 - 1s - loss: 0.4380 - accuracy: 0.8339 - val_loss: 0.4515 - val_accuracy: 0.8246
# Epoch 139/1000
# 128/128 - 1s - loss: 0.4389 - accuracy: 0.8337 - val_loss: 0.4496 - val_accuracy: 0.8218
# Epoch 140/1000
# 128/128 - 1s - loss: 0.4381 - accuracy: 0.8342 - val_loss: 0.4451 - val_accuracy: 0.8345
# Epoch 141/1000
# 128/128 - 1s - loss: 0.4374 - accuracy: 0.8370 - val_loss: 0.4468 - val_accuracy: 0.8261
# Epoch 142/1000
# 128/128 - 1s - loss: 0.4356 - accuracy: 0.8358 - val_loss: 0.4449 - val_accuracy: 0.8320
# Epoch 143/1000
# 128/128 - 1s - loss: 0.4318 - accuracy: 0.8393 - val_loss: 0.4445 - val_accuracy: 0.8337
# Epoch 144/1000
# 128/128 - 1s - loss: 0.4348 - accuracy: 0.8370 - val_loss: 0.4427 - val_accuracy: 0.8318
# Epoch 145/1000
# 128/128 - 1s - loss: 0.4292 - accuracy: 0.8402 - val_loss: 0.4394 - val_accuracy: 0.8406
# Epoch 146/1000
# 128/128 - 1s - loss: 0.4309 - accuracy: 0.8392 - val_loss: 0.4381 - val_accuracy: 0.8439
# Epoch 147/1000
# 128/128 - 1s - loss: 0.4265 - accuracy: 0.8415 - val_loss: 0.4366 - val_accuracy: 0.8413
# Epoch 148/1000
# 128/128 - 1s - loss: 0.4263 - accuracy: 0.8445 - val_loss: 0.4318 - val_accuracy: 0.8492
# Epoch 149/1000
# 128/128 - 1s - loss: 0.4249 - accuracy: 0.8443 - val_loss: 0.4327 - val_accuracy: 0.8391
# Epoch 150/1000
# 128/128 - 1s - loss: 0.4228 - accuracy: 0.8441 - val_loss: 0.4283 - val_accuracy: 0.8420
# Epoch 151/1000
# 128/128 - 1s - loss: 0.4202 - accuracy: 0.8456 - val_loss: 0.4273 - val_accuracy: 0.8479
# Epoch 152/1000
# 128/128 - 1s - loss: 0.4190 - accuracy: 0.8460 - val_loss: 0.4268 - val_accuracy: 0.8491
# Epoch 153/1000
# 128/128 - 1s - loss: 0.4158 - accuracy: 0.8468 - val_loss: 0.4247 - val_accuracy: 0.8499
# Epoch 154/1000
# 128/128 - 1s - loss: 0.4147 - accuracy: 0.8481 - val_loss: 0.4226 - val_accuracy: 0.8561
# Epoch 155/1000
# 128/128 - 1s - loss: 0.4142 - accuracy: 0.8496 - val_loss: 0.4197 - val_accuracy: 0.8505
# Epoch 156/1000
# 128/128 - 1s - loss: 0.4128 - accuracy: 0.8497 - val_loss: 0.4152 - val_accuracy: 0.8608
# Epoch 157/1000
# 128/128 - 1s - loss: 0.4104 - accuracy: 0.8513 - val_loss: 0.4164 - val_accuracy: 0.8545
# Epoch 158/1000
# 128/128 - 1s - loss: 0.4090 - accuracy: 0.8509 - val_loss: 0.4151 - val_accuracy: 0.8555
# Epoch 159/1000
# 128/128 - 1s - loss: 0.4094 - accuracy: 0.8511 - val_loss: 0.4125 - val_accuracy: 0.8561
# Epoch 160/1000
# 128/128 - 1s - loss: 0.4042 - accuracy: 0.8538 - val_loss: 0.4102 - val_accuracy: 0.8639
# Epoch 161/1000
# 128/128 - 1s - loss: 0.4048 - accuracy: 0.8534 - val_loss: 0.4113 - val_accuracy: 0.8610
# Epoch 162/1000
# 128/128 - 1s - loss: 0.4035 - accuracy: 0.8543 - val_loss: 0.4106 - val_accuracy: 0.8595
# Epoch 163/1000
# 128/128 - 1s - loss: 0.4021 - accuracy: 0.8539 - val_loss: 0.4099 - val_accuracy: 0.8626
# Epoch 164/1000
# 128/128 - 1s - loss: 0.4026 - accuracy: 0.8550 - val_loss: 0.4048 - val_accuracy: 0.8660
# Epoch 165/1000
# 128/128 - 1s - loss: 0.3990 - accuracy: 0.8559 - val_loss: 0.4066 - val_accuracy: 0.8619
# Epoch 166/1000
# 128/128 - 1s - loss: 0.3989 - accuracy: 0.8557 - val_loss: 0.4010 - val_accuracy: 0.8691
# Epoch 167/1000
# 128/128 - 1s - loss: 0.3989 - accuracy: 0.8554 - val_loss: 0.3989 - val_accuracy: 0.8689
# Epoch 168/1000
# 128/128 - 1s - loss: 0.3974 - accuracy: 0.8579 - val_loss: 0.3977 - val_accuracy: 0.8751
# Epoch 169/1000
# 128/128 - 1s - loss: 0.3963 - accuracy: 0.8583 - val_loss: 0.3959 - val_accuracy: 0.8694
# Epoch 170/1000
# 128/128 - 1s - loss: 0.3940 - accuracy: 0.8590 - val_loss: 0.3966 - val_accuracy: 0.8658
# Epoch 171/1000
# 128/128 - 1s - loss: 0.3930 - accuracy: 0.8585 - val_loss: 0.3931 - val_accuracy: 0.8711
# Epoch 172/1000
# 128/128 - 1s - loss: 0.3917 - accuracy: 0.8589 - val_loss: 0.3905 - val_accuracy: 0.8721
# Epoch 173/1000
# 128/128 - 1s - loss: 0.3910 - accuracy: 0.8606 - val_loss: 0.3902 - val_accuracy: 0.8664
# Epoch 174/1000
# 128/128 - 1s - loss: 0.3912 - accuracy: 0.8596 - val_loss: 0.3924 - val_accuracy: 0.8698
# Epoch 175/1000
# 128/128 - 1s - loss: 0.3885 - accuracy: 0.8608 - val_loss: 0.3872 - val_accuracy: 0.8738
# Epoch 176/1000
# 128/128 - 1s - loss: 0.3885 - accuracy: 0.8610 - val_loss: 0.3855 - val_accuracy: 0.8751
# Epoch 177/1000
# 128/128 - 1s - loss: 0.3866 - accuracy: 0.8629 - val_loss: 0.3848 - val_accuracy: 0.8721
# Epoch 178/1000
# 128/128 - 1s - loss: 0.3836 - accuracy: 0.8630 - val_loss: 0.3853 - val_accuracy: 0.8745
# Epoch 179/1000
# 128/128 - 1s - loss: 0.3829 - accuracy: 0.8635 - val_loss: 0.3837 - val_accuracy: 0.8748
# Epoch 180/1000
# 128/128 - 1s - loss: 0.3812 - accuracy: 0.8646 - val_loss: 0.3840 - val_accuracy: 0.8754
# Epoch 181/1000
# 128/128 - 1s - loss: 0.3801 - accuracy: 0.8642 - val_loss: 0.3783 - val_accuracy: 0.8815
# Epoch 182/1000
# 128/128 - 1s - loss: 0.3786 - accuracy: 0.8647 - val_loss: 0.3807 - val_accuracy: 0.8795
# Epoch 183/1000
# 128/128 - 1s - loss: 0.3781 - accuracy: 0.8649 - val_loss: 0.3759 - val_accuracy: 0.8820
# Epoch 184/1000
# 128/128 - 1s - loss: 0.3776 - accuracy: 0.8650 - val_loss: 0.3746 - val_accuracy: 0.8779
# Epoch 185/1000
# 128/128 - 1s - loss: 0.3768 - accuracy: 0.8655 - val_loss: 0.3746 - val_accuracy: 0.8797
# Epoch 186/1000
# 128/128 - 1s - loss: 0.3727 - accuracy: 0.8667 - val_loss: 0.3732 - val_accuracy: 0.8812
# Epoch 187/1000
# 128/128 - 1s - loss: 0.3709 - accuracy: 0.8685 - val_loss: 0.3746 - val_accuracy: 0.8787
# Epoch 188/1000
# 128/128 - 1s - loss: 0.3700 - accuracy: 0.8687 - val_loss: 0.3712 - val_accuracy: 0.8826
# Epoch 189/1000
# 128/128 - 1s - loss: 0.3728 - accuracy: 0.8674 - val_loss: 0.3688 - val_accuracy: 0.8833
# Epoch 190/1000
# 128/128 - 1s - loss: 0.3679 - accuracy: 0.8691 - val_loss: 0.3679 - val_accuracy: 0.8838
# Epoch 191/1000
# 128/128 - 1s - loss: 0.3682 - accuracy: 0.8692 - val_loss: 0.3668 - val_accuracy: 0.8818
# Epoch 192/1000
# 128/128 - 1s - loss: 0.3645 - accuracy: 0.8706 - val_loss: 0.3638 - val_accuracy: 0.8818
# Epoch 193/1000
# 128/128 - 1s - loss: 0.3647 - accuracy: 0.8708 - val_loss: 0.3622 - val_accuracy: 0.8836
# Epoch 194/1000
# 128/128 - 1s - loss: 0.3660 - accuracy: 0.8690 - val_loss: 0.3604 - val_accuracy: 0.8867
# Epoch 195/1000
# 128/128 - 1s - loss: 0.3632 - accuracy: 0.8712 - val_loss: 0.3657 - val_accuracy: 0.8814
# Epoch 196/1000
# 128/128 - 1s - loss: 0.3635 - accuracy: 0.8709 - val_loss: 0.3576 - val_accuracy: 0.8886
# Epoch 197/1000
# 128/128 - 1s - loss: 0.3581 - accuracy: 0.8724 - val_loss: 0.3590 - val_accuracy: 0.8840
# Epoch 198/1000
# 128/128 - 1s - loss: 0.3595 - accuracy: 0.8722 - val_loss: 0.3562 - val_accuracy: 0.8846
# Epoch 199/1000
# 128/128 - 1s - loss: 0.3595 - accuracy: 0.8728 - val_loss: 0.3545 - val_accuracy: 0.8858
# Epoch 200/1000
# 128/128 - 1s - loss: 0.3582 - accuracy: 0.8741 - val_loss: 0.3538 - val_accuracy: 0.8875
# Epoch 201/1000
# 128/128 - 1s - loss: 0.3565 - accuracy: 0.8739 - val_loss: 0.3488 - val_accuracy: 0.8893
# Epoch 202/1000
# 128/128 - 1s - loss: 0.3564 - accuracy: 0.8740 - val_loss: 0.3520 - val_accuracy: 0.8889
# Epoch 203/1000
# 128/128 - 1s - loss: 0.3541 - accuracy: 0.8754 - val_loss: 0.3507 - val_accuracy: 0.8873
# Epoch 204/1000
# 128/128 - 1s - loss: 0.3513 - accuracy: 0.8753 - val_loss: 0.3486 - val_accuracy: 0.8914
# Epoch 205/1000
# 128/128 - 1s - loss: 0.3510 - accuracy: 0.8771 - val_loss: 0.3481 - val_accuracy: 0.8882
# Epoch 206/1000
# 128/128 - 1s - loss: 0.3472 - accuracy: 0.8782 - val_loss: 0.3456 - val_accuracy: 0.8901
# Epoch 207/1000
# 128/128 - 1s - loss: 0.3497 - accuracy: 0.8754 - val_loss: 0.3462 - val_accuracy: 0.8889
# Epoch 208/1000
# 128/128 - 1s - loss: 0.3455 - accuracy: 0.8783 - val_loss: 0.3404 - val_accuracy: 0.8921
# Epoch 209/1000
# 128/128 - 1s - loss: 0.3472 - accuracy: 0.8788 - val_loss: 0.3388 - val_accuracy: 0.8936
# Epoch 210/1000
# 128/128 - 1s - loss: 0.3444 - accuracy: 0.8781 - val_loss: 0.3405 - val_accuracy: 0.8948
# Epoch 211/1000
# 128/128 - 1s - loss: 0.3434 - accuracy: 0.8785 - val_loss: 0.3400 - val_accuracy: 0.8945
# Epoch 212/1000
# 128/128 - 1s - loss: 0.3417 - accuracy: 0.8801 - val_loss: 0.3353 - val_accuracy: 0.8990
# Epoch 213/1000
# 128/128 - 1s - loss: 0.3437 - accuracy: 0.8797 - val_loss: 0.3390 - val_accuracy: 0.8918
# Epoch 214/1000
# 128/128 - 1s - loss: 0.3391 - accuracy: 0.8808 - val_loss: 0.3334 - val_accuracy: 0.8968
# Epoch 215/1000
# 128/128 - 1s - loss: 0.3399 - accuracy: 0.8806 - val_loss: 0.3347 - val_accuracy: 0.8954
# Epoch 216/1000
# 128/128 - 1s - loss: 0.3371 - accuracy: 0.8809 - val_loss: 0.3309 - val_accuracy: 0.8958
# Epoch 217/1000
# 128/128 - 1s - loss: 0.3374 - accuracy: 0.8803 - val_loss: 0.3296 - val_accuracy: 0.8965
# Epoch 218/1000
# 128/128 - 1s - loss: 0.3380 - accuracy: 0.8813 - val_loss: 0.3327 - val_accuracy: 0.8957
# Epoch 219/1000
# 128/128 - 1s - loss: 0.3335 - accuracy: 0.8825 - val_loss: 0.3317 - val_accuracy: 0.8964
# Epoch 220/1000
# 128/128 - 1s - loss: 0.3327 - accuracy: 0.8832 - val_loss: 0.3295 - val_accuracy: 0.8948
# Epoch 221/1000
# 128/128 - 1s - loss: 0.3328 - accuracy: 0.8834 - val_loss: 0.3282 - val_accuracy: 0.8983
# Epoch 222/1000
# 128/128 - 1s - loss: 0.3288 - accuracy: 0.8843 - val_loss: 0.3257 - val_accuracy: 0.8989
# Epoch 223/1000
# 128/128 - 1s - loss: 0.3291 - accuracy: 0.8841 - val_loss: 0.3286 - val_accuracy: 0.8985
# Epoch 224/1000
# 128/128 - 1s - loss: 0.3292 - accuracy: 0.8860 - val_loss: 0.3232 - val_accuracy: 0.8989
# Epoch 225/1000
# 128/128 - 1s - loss: 0.3282 - accuracy: 0.8839 - val_loss: 0.3212 - val_accuracy: 0.8995
# Epoch 226/1000
# 128/128 - 1s - loss: 0.3286 - accuracy: 0.8844 - val_loss: 0.3209 - val_accuracy: 0.8993
# Epoch 227/1000
# 128/128 - 1s - loss: 0.3258 - accuracy: 0.8861 - val_loss: 0.3246 - val_accuracy: 0.8958
# Epoch 228/1000
# 128/128 - 1s - loss: 0.3247 - accuracy: 0.8853 - val_loss: 0.3207 - val_accuracy: 0.9012
# Epoch 229/1000
# 128/128 - 1s - loss: 0.3239 - accuracy: 0.8858 - val_loss: 0.3193 - val_accuracy: 0.9000
# Epoch 230/1000
# 128/128 - 1s - loss: 0.3220 - accuracy: 0.8871 - val_loss: 0.3198 - val_accuracy: 0.9013
# Epoch 231/1000
# 128/128 - 1s - loss: 0.3197 - accuracy: 0.8871 - val_loss: 0.3176 - val_accuracy: 0.9011
# Epoch 232/1000
# 128/128 - 1s - loss: 0.3241 - accuracy: 0.8842 - val_loss: 0.3171 - val_accuracy: 0.9012
# Epoch 233/1000
# 128/128 - 1s - loss: 0.3220 - accuracy: 0.8873 - val_loss: 0.3195 - val_accuracy: 0.9012
# Epoch 234/1000
# 128/128 - 1s - loss: 0.3194 - accuracy: 0.8885 - val_loss: 0.3165 - val_accuracy: 0.9000
# Epoch 235/1000
# 128/128 - 1s - loss: 0.3204 - accuracy: 0.8861 - val_loss: 0.3138 - val_accuracy: 0.9026
# Epoch 236/1000
# 128/128 - 1s - loss: 0.3162 - accuracy: 0.8889 - val_loss: 0.3136 - val_accuracy: 0.9025
# Epoch 237/1000
# 128/128 - 1s - loss: 0.3184 - accuracy: 0.8874 - val_loss: 0.3102 - val_accuracy: 0.9054
# Epoch 238/1000
# 128/128 - 1s - loss: 0.3173 - accuracy: 0.8881 - val_loss: 0.3151 - val_accuracy: 0.9001
# Epoch 239/1000
# 128/128 - 1s - loss: 0.3159 - accuracy: 0.8896 - val_loss: 0.3104 - val_accuracy: 0.9025
# Epoch 240/1000
# 128/128 - 1s - loss: 0.3138 - accuracy: 0.8905 - val_loss: 0.3083 - val_accuracy: 0.9047
# Epoch 241/1000
# 128/128 - 1s - loss: 0.3142 - accuracy: 0.8904 - val_loss: 0.3090 - val_accuracy: 0.9038
# Epoch 242/1000
# 128/128 - 1s - loss: 0.3126 - accuracy: 0.8891 - val_loss: 0.3128 - val_accuracy: 0.9021
# Epoch 243/1000
# 128/128 - 1s - loss: 0.3132 - accuracy: 0.8889 - val_loss: 0.3062 - val_accuracy: 0.9047
# Epoch 244/1000
# 128/128 - 1s - loss: 0.3096 - accuracy: 0.8911 - val_loss: 0.3084 - val_accuracy: 0.9038
# Epoch 245/1000
# 128/128 - 1s - loss: 0.3100 - accuracy: 0.8909 - val_loss: 0.3055 - val_accuracy: 0.9046
# Epoch 246/1000
# 128/128 - 1s - loss: 0.3090 - accuracy: 0.8916 - val_loss: 0.3067 - val_accuracy: 0.9071
# Epoch 247/1000
# 128/128 - 1s - loss: 0.3088 - accuracy: 0.8905 - val_loss: 0.3037 - val_accuracy: 0.9055
# Epoch 248/1000
# 128/128 - 1s - loss: 0.3077 - accuracy: 0.8912 - val_loss: 0.3080 - val_accuracy: 0.9037
# Epoch 249/1000
# 128/128 - 1s - loss: 0.3074 - accuracy: 0.8912 - val_loss: 0.3025 - val_accuracy: 0.9048
# Epoch 250/1000
# 128/128 - 1s - loss: 0.3064 - accuracy: 0.8918 - val_loss: 0.3001 - val_accuracy: 0.9078
# Epoch 251/1000
# 128/128 - 1s - loss: 0.3057 - accuracy: 0.8917 - val_loss: 0.3011 - val_accuracy: 0.9070
# Epoch 252/1000
# 128/128 - 1s - loss: 0.3072 - accuracy: 0.8916 - val_loss: 0.3039 - val_accuracy: 0.9049
# Epoch 253/1000
# 128/128 - 1s - loss: 0.3048 - accuracy: 0.8925 - val_loss: 0.2995 - val_accuracy: 0.9095
# Epoch 254/1000
# 128/128 - 1s - loss: 0.3022 - accuracy: 0.8938 - val_loss: 0.2972 - val_accuracy: 0.9093
# Epoch 255/1000
# 128/128 - 1s - loss: 0.3025 - accuracy: 0.8938 - val_loss: 0.2992 - val_accuracy: 0.9060
# Epoch 256/1000
# 128/128 - 1s - loss: 0.2986 - accuracy: 0.8954 - val_loss: 0.2956 - val_accuracy: 0.9084
# Epoch 257/1000
# 128/128 - 1s - loss: 0.2995 - accuracy: 0.8949 - val_loss: 0.2971 - val_accuracy: 0.9068
# Epoch 258/1000
# 128/128 - 1s - loss: 0.2995 - accuracy: 0.8949 - val_loss: 0.2934 - val_accuracy: 0.9086
# Epoch 259/1000
# 128/128 - 1s - loss: 0.2998 - accuracy: 0.8939 - val_loss: 0.2955 - val_accuracy: 0.9073
# Epoch 260/1000
# 128/128 - 1s - loss: 0.2967 - accuracy: 0.8963 - val_loss: 0.2924 - val_accuracy: 0.9103
# Epoch 261/1000
# 128/128 - 1s - loss: 0.2977 - accuracy: 0.8949 - val_loss: 0.2943 - val_accuracy: 0.9067
# Epoch 262/1000
# 128/128 - 1s - loss: 0.2942 - accuracy: 0.8951 - val_loss: 0.2941 - val_accuracy: 0.9072
# Epoch 263/1000
# 128/128 - 1s - loss: 0.2936 - accuracy: 0.8966 - val_loss: 0.2899 - val_accuracy: 0.9102
# Epoch 264/1000
# 128/128 - 1s - loss: 0.2909 - accuracy: 0.8977 - val_loss: 0.2880 - val_accuracy: 0.9102
# Epoch 265/1000
# 128/128 - 1s - loss: 0.2938 - accuracy: 0.8959 - val_loss: 0.2884 - val_accuracy: 0.9104
# Epoch 266/1000
# 128/128 - 1s - loss: 0.2905 - accuracy: 0.8969 - val_loss: 0.2882 - val_accuracy: 0.9076
# Epoch 267/1000
# 128/128 - 1s - loss: 0.2912 - accuracy: 0.8961 - val_loss: 0.2890 - val_accuracy: 0.9106
# Epoch 268/1000
# 128/128 - 1s - loss: 0.2912 - accuracy: 0.8973 - val_loss: 0.2910 - val_accuracy: 0.9070
# Epoch 269/1000
# 128/128 - 1s - loss: 0.2915 - accuracy: 0.8966 - val_loss: 0.2874 - val_accuracy: 0.9098
# Epoch 270/1000
# 128/128 - 1s - loss: 0.2893 - accuracy: 0.8981 - val_loss: 0.2862 - val_accuracy: 0.9105
# Epoch 271/1000
# 128/128 - 1s - loss: 0.2864 - accuracy: 0.8985 - val_loss: 0.2848 - val_accuracy: 0.9113
# Epoch 272/1000
# 128/128 - 1s - loss: 0.2880 - accuracy: 0.8982 - val_loss: 0.2876 - val_accuracy: 0.9103
# Epoch 273/1000
# 128/128 - 1s - loss: 0.2884 - accuracy: 0.8979 - val_loss: 0.2853 - val_accuracy: 0.9109
# Epoch 274/1000
# 128/128 - 1s - loss: 0.2863 - accuracy: 0.8984 - val_loss: 0.2859 - val_accuracy: 0.9112
# Epoch 275/1000
# 128/128 - 1s - loss: 0.2831 - accuracy: 0.9007 - val_loss: 0.2831 - val_accuracy: 0.9110
# Epoch 276/1000
# 128/128 - 1s - loss: 0.2868 - accuracy: 0.8995 - val_loss: 0.2845 - val_accuracy: 0.9114
# Epoch 277/1000
# 128/128 - 1s - loss: 0.2835 - accuracy: 0.8991 - val_loss: 0.2837 - val_accuracy: 0.9110
# Epoch 278/1000
# 128/128 - 1s - loss: 0.2822 - accuracy: 0.8999 - val_loss: 0.2834 - val_accuracy: 0.9111
# Epoch 279/1000
# 128/128 - 1s - loss: 0.2819 - accuracy: 0.8992 - val_loss: 0.2808 - val_accuracy: 0.9123
# Epoch 280/1000
# 128/128 - 1s - loss: 0.2816 - accuracy: 0.9002 - val_loss: 0.2799 - val_accuracy: 0.9108
# Epoch 281/1000
# 128/128 - 1s - loss: 0.2782 - accuracy: 0.9010 - val_loss: 0.2843 - val_accuracy: 0.9108
# Epoch 282/1000
# 128/128 - 1s - loss: 0.2791 - accuracy: 0.9012 - val_loss: 0.2795 - val_accuracy: 0.9119
# Epoch 283/1000
# 128/128 - 1s - loss: 0.2818 - accuracy: 0.9001 - val_loss: 0.2820 - val_accuracy: 0.9109
# Epoch 284/1000
# 128/128 - 1s - loss: 0.2793 - accuracy: 0.9012 - val_loss: 0.2777 - val_accuracy: 0.9124
# Epoch 285/1000
# 128/128 - 1s - loss: 0.2815 - accuracy: 0.9001 - val_loss: 0.2781 - val_accuracy: 0.9118
# Epoch 286/1000
# 128/128 - 1s - loss: 0.2772 - accuracy: 0.9013 - val_loss: 0.2765 - val_accuracy: 0.9127
# Epoch 287/1000
# 128/128 - 1s - loss: 0.2767 - accuracy: 0.9008 - val_loss: 0.2791 - val_accuracy: 0.9113
# Epoch 288/1000
# 128/128 - 1s - loss: 0.2772 - accuracy: 0.9012 - val_loss: 0.2783 - val_accuracy: 0.9119
# Epoch 289/1000
# 128/128 - 1s - loss: 0.2745 - accuracy: 0.9030 - val_loss: 0.2774 - val_accuracy: 0.9118
# Epoch 290/1000
# 128/128 - 1s - loss: 0.2738 - accuracy: 0.9039 - val_loss: 0.2761 - val_accuracy: 0.9118
# Epoch 291/1000
# 128/128 - 1s - loss: 0.2735 - accuracy: 0.9032 - val_loss: 0.2759 - val_accuracy: 0.9123
# Epoch 292/1000
# 128/128 - 1s - loss: 0.2723 - accuracy: 0.9027 - val_loss: 0.2760 - val_accuracy: 0.9118
# Epoch 293/1000
# 128/128 - 1s - loss: 0.2734 - accuracy: 0.9027 - val_loss: 0.2746 - val_accuracy: 0.9139
# Epoch 294/1000
# 128/128 - 1s - loss: 0.2745 - accuracy: 0.9019 - val_loss: 0.2731 - val_accuracy: 0.9135
# Epoch 295/1000
# 128/128 - 1s - loss: 0.2734 - accuracy: 0.9029 - val_loss: 0.2743 - val_accuracy: 0.9123
# Epoch 296/1000
# 128/128 - 1s - loss: 0.2744 - accuracy: 0.9025 - val_loss: 0.2729 - val_accuracy: 0.9123
# Epoch 297/1000
# 128/128 - 1s - loss: 0.2705 - accuracy: 0.9035 - val_loss: 0.2714 - val_accuracy: 0.9134
# Epoch 298/1000
# 128/128 - 1s - loss: 0.2684 - accuracy: 0.9053 - val_loss: 0.2719 - val_accuracy: 0.9134
# Epoch 299/1000
# 128/128 - 1s - loss: 0.2720 - accuracy: 0.9024 - val_loss: 0.2701 - val_accuracy: 0.9126
# Epoch 300/1000
# 128/128 - 1s - loss: 0.2701 - accuracy: 0.9033 - val_loss: 0.2695 - val_accuracy: 0.9131
# Epoch 301/1000
# 128/128 - 1s - loss: 0.2677 - accuracy: 0.9037 - val_loss: 0.2692 - val_accuracy: 0.9132
# Epoch 302/1000
# 128/128 - 1s - loss: 0.2679 - accuracy: 0.9052 - val_loss: 0.2689 - val_accuracy: 0.9132
# Epoch 303/1000
# 128/128 - 1s - loss: 0.2658 - accuracy: 0.9056 - val_loss: 0.2692 - val_accuracy: 0.9132
# Epoch 304/1000
# 128/128 - 1s - loss: 0.2663 - accuracy: 0.9056 - val_loss: 0.2674 - val_accuracy: 0.9135
# Epoch 305/1000
# 128/128 - 1s - loss: 0.2652 - accuracy: 0.9042 - val_loss: 0.2650 - val_accuracy: 0.9146
# Epoch 306/1000
# 128/128 - 1s - loss: 0.2658 - accuracy: 0.9054 - val_loss: 0.2656 - val_accuracy: 0.9137
# Epoch 307/1000
# 128/128 - 1s - loss: 0.2666 - accuracy: 0.9059 - val_loss: 0.2679 - val_accuracy: 0.9134
# Epoch 308/1000
# 128/128 - 1s - loss: 0.2656 - accuracy: 0.9055 - val_loss: 0.2671 - val_accuracy: 0.9138
# Epoch 309/1000
# 128/128 - 1s - loss: 0.2636 - accuracy: 0.9056 - val_loss: 0.2681 - val_accuracy: 0.9140
# Epoch 310/1000
# 128/128 - 1s - loss: 0.2646 - accuracy: 0.9059 - val_loss: 0.2657 - val_accuracy: 0.9142
# Epoch 311/1000
# 128/128 - 1s - loss: 0.2612 - accuracy: 0.9056 - val_loss: 0.2669 - val_accuracy: 0.9136
# Epoch 312/1000
# 128/128 - 1s - loss: 0.2624 - accuracy: 0.9071 - val_loss: 0.2650 - val_accuracy: 0.9135
# Epoch 313/1000
# 128/128 - 1s - loss: 0.2588 - accuracy: 0.9066 - val_loss: 0.2632 - val_accuracy: 0.9156
# Epoch 314/1000
# 128/128 - 1s - loss: 0.2624 - accuracy: 0.9054 - val_loss: 0.2657 - val_accuracy: 0.9140
# Epoch 315/1000
# 128/128 - 1s - loss: 0.2602 - accuracy: 0.9061 - val_loss: 0.2645 - val_accuracy: 0.9136
# Epoch 316/1000
# 128/128 - 1s - loss: 0.2598 - accuracy: 0.9070 - val_loss: 0.2619 - val_accuracy: 0.9144
# Epoch 317/1000
# 128/128 - 1s - loss: 0.2555 - accuracy: 0.9092 - val_loss: 0.2615 - val_accuracy: 0.9143
# Epoch 318/1000
# 128/128 - 1s - loss: 0.2599 - accuracy: 0.9069 - val_loss: 0.2625 - val_accuracy: 0.9149
# Epoch 319/1000
# 128/128 - 1s - loss: 0.2571 - accuracy: 0.9082 - val_loss: 0.2615 - val_accuracy: 0.9148
# Epoch 320/1000
# 128/128 - 1s - loss: 0.2590 - accuracy: 0.9076 - val_loss: 0.2639 - val_accuracy: 0.9145
# Epoch 321/1000
# 128/128 - 1s - loss: 0.2580 - accuracy: 0.9078 - val_loss: 0.2588 - val_accuracy: 0.9156
# Epoch 322/1000
# 128/128 - 1s - loss: 0.2562 - accuracy: 0.9087 - val_loss: 0.2642 - val_accuracy: 0.9131
# Epoch 323/1000
# 128/128 - 1s - loss: 0.2559 - accuracy: 0.9082 - val_loss: 0.2615 - val_accuracy: 0.9147
# Epoch 324/1000
# 128/128 - 1s - loss: 0.2552 - accuracy: 0.9083 - val_loss: 0.2610 - val_accuracy: 0.9149
# Epoch 325/1000
# 128/128 - 1s - loss: 0.2549 - accuracy: 0.9080 - val_loss: 0.2597 - val_accuracy: 0.9140
# Epoch 326/1000
# 128/128 - 1s - loss: 0.2531 - accuracy: 0.9092 - val_loss: 0.2593 - val_accuracy: 0.9150
# Epoch 327/1000
# 128/128 - 1s - loss: 0.2543 - accuracy: 0.9090 - val_loss: 0.2599 - val_accuracy: 0.9145
# Epoch 328/1000
# 128/128 - 1s - loss: 0.2509 - accuracy: 0.9088 - val_loss: 0.2582 - val_accuracy: 0.9156
# Epoch 329/1000
# 128/128 - 1s - loss: 0.2515 - accuracy: 0.9098 - val_loss: 0.2574 - val_accuracy: 0.9152
# Epoch 330/1000
# 128/128 - 1s - loss: 0.2493 - accuracy: 0.9104 - val_loss: 0.2599 - val_accuracy: 0.9145
# Epoch 331/1000
# 128/128 - 1s - loss: 0.2519 - accuracy: 0.9101 - val_loss: 0.2574 - val_accuracy: 0.9153
# Epoch 332/1000
# 128/128 - 1s - loss: 0.2498 - accuracy: 0.9099 - val_loss: 0.2598 - val_accuracy: 0.9144
# Epoch 333/1000
# 128/128 - 1s - loss: 0.2504 - accuracy: 0.9098 - val_loss: 0.2567 - val_accuracy: 0.9154
# Epoch 334/1000
# 128/128 - 1s - loss: 0.2499 - accuracy: 0.9095 - val_loss: 0.2581 - val_accuracy: 0.9150
# Epoch 335/1000
# 128/128 - 1s - loss: 0.2487 - accuracy: 0.9103 - val_loss: 0.2546 - val_accuracy: 0.9160
# Epoch 336/1000
# 128/128 - 1s - loss: 0.2492 - accuracy: 0.9105 - val_loss: 0.2536 - val_accuracy: 0.9162
# Epoch 337/1000
# 128/128 - 1s - loss: 0.2468 - accuracy: 0.9110 - val_loss: 0.2559 - val_accuracy: 0.9154
# Epoch 338/1000
# 128/128 - 1s - loss: 0.2475 - accuracy: 0.9115 - val_loss: 0.2555 - val_accuracy: 0.9147
# Epoch 339/1000
# 128/128 - 1s - loss: 0.2442 - accuracy: 0.9121 - val_loss: 0.2545 - val_accuracy: 0.9153
# Epoch 340/1000
# 128/128 - 1s - loss: 0.2451 - accuracy: 0.9115 - val_loss: 0.2522 - val_accuracy: 0.9153
# Epoch 341/1000
# 128/128 - 1s - loss: 0.2469 - accuracy: 0.9116 - val_loss: 0.2556 - val_accuracy: 0.9157
# Epoch 342/1000
# 128/128 - 1s - loss: 0.2468 - accuracy: 0.9114 - val_loss: 0.2534 - val_accuracy: 0.9159
# Epoch 343/1000
# 128/128 - 1s - loss: 0.2458 - accuracy: 0.9113 - val_loss: 0.2526 - val_accuracy: 0.9157
# Epoch 344/1000
# 128/128 - 1s - loss: 0.2427 - accuracy: 0.9125 - val_loss: 0.2545 - val_accuracy: 0.9158
# Epoch 345/1000
# 128/128 - 1s - loss: 0.2452 - accuracy: 0.9116 - val_loss: 0.2541 - val_accuracy: 0.9165
# Epoch 346/1000
# 128/128 - 1s - loss: 0.2473 - accuracy: 0.9104 - val_loss: 0.2522 - val_accuracy: 0.9162
# Epoch 347/1000
# 128/128 - 1s - loss: 0.2431 - accuracy: 0.9126 - val_loss: 0.2542 - val_accuracy: 0.9160
# Epoch 348/1000
# 128/128 - 1s - loss: 0.2440 - accuracy: 0.9126 - val_loss: 0.2531 - val_accuracy: 0.9162
# Epoch 349/1000
# 128/128 - 1s - loss: 0.2427 - accuracy: 0.9124 - val_loss: 0.2525 - val_accuracy: 0.9163
# Epoch 350/1000
# 128/128 - 1s - loss: 0.2423 - accuracy: 0.9134 - val_loss: 0.2517 - val_accuracy: 0.9159
# Epoch 351/1000
# 128/128 - 1s - loss: 0.2438 - accuracy: 0.9127 - val_loss: 0.2537 - val_accuracy: 0.9153
# Epoch 352/1000
# 128/128 - 1s - loss: 0.2450 - accuracy: 0.9122 - val_loss: 0.2529 - val_accuracy: 0.9153
# Epoch 353/1000
# 128/128 - 1s - loss: 0.2433 - accuracy: 0.9129 - val_loss: 0.2515 - val_accuracy: 0.9163
# Epoch 354/1000
# 128/128 - 1s - loss: 0.2408 - accuracy: 0.9132 - val_loss: 0.2519 - val_accuracy: 0.9163
# Epoch 355/1000
# 128/128 - 1s - loss: 0.2401 - accuracy: 0.9136 - val_loss: 0.2517 - val_accuracy: 0.9161
# Epoch 356/1000
# 128/128 - 1s - loss: 0.2411 - accuracy: 0.9133 - val_loss: 0.2507 - val_accuracy: 0.9165
# Epoch 357/1000
# 128/128 - 1s - loss: 0.2405 - accuracy: 0.9130 - val_loss: 0.2520 - val_accuracy: 0.9155
# Epoch 358/1000
# 128/128 - 1s - loss: 0.2405 - accuracy: 0.9120 - val_loss: 0.2509 - val_accuracy: 0.9167
# Epoch 359/1000
# 128/128 - 1s - loss: 0.2392 - accuracy: 0.9141 - val_loss: 0.2526 - val_accuracy: 0.9160
# Epoch 360/1000
# 128/128 - 1s - loss: 0.2380 - accuracy: 0.9136 - val_loss: 0.2507 - val_accuracy: 0.9164
# Epoch 361/1000
# 128/128 - 1s - loss: 0.2375 - accuracy: 0.9143 - val_loss: 0.2512 - val_accuracy: 0.9160
# Epoch 362/1000
# 128/128 - 1s - loss: 0.2383 - accuracy: 0.9137 - val_loss: 0.2509 - val_accuracy: 0.9155
# Epoch 363/1000
# 128/128 - 1s - loss: 0.2384 - accuracy: 0.9129 - val_loss: 0.2497 - val_accuracy: 0.9162
# Epoch 364/1000
# 128/128 - 1s - loss: 0.2401 - accuracy: 0.9129 - val_loss: 0.2492 - val_accuracy: 0.9156
# Epoch 365/1000
# 128/128 - 1s - loss: 0.2363 - accuracy: 0.9146 - val_loss: 0.2496 - val_accuracy: 0.9165
# Epoch 366/1000
# 128/128 - 1s - loss: 0.2363 - accuracy: 0.9147 - val_loss: 0.2502 - val_accuracy: 0.9166
# Epoch 367/1000
# 128/128 - 1s - loss: 0.2386 - accuracy: 0.9149 - val_loss: 0.2492 - val_accuracy: 0.9157
# Epoch 368/1000
# 128/128 - 1s - loss: 0.2372 - accuracy: 0.9140 - val_loss: 0.2495 - val_accuracy: 0.9161
# Epoch 369/1000
# 128/128 - 1s - loss: 0.2380 - accuracy: 0.9133 - val_loss: 0.2485 - val_accuracy: 0.9170
# Epoch 370/1000
# 128/128 - 1s - loss: 0.2370 - accuracy: 0.9138 - val_loss: 0.2489 - val_accuracy: 0.9167
# Epoch 371/1000
# 128/128 - 1s - loss: 0.2358 - accuracy: 0.9155 - val_loss: 0.2482 - val_accuracy: 0.9165
# Epoch 372/1000
# 128/128 - 1s - loss: 0.2349 - accuracy: 0.9147 - val_loss: 0.2458 - val_accuracy: 0.9170
# Epoch 373/1000
# 128/128 - 1s - loss: 0.2325 - accuracy: 0.9153 - val_loss: 0.2480 - val_accuracy: 0.9164
# Epoch 374/1000
# 128/128 - 1s - loss: 0.2361 - accuracy: 0.9153 - val_loss: 0.2470 - val_accuracy: 0.9167
# Epoch 375/1000
# 128/128 - 1s - loss: 0.2334 - accuracy: 0.9158 - val_loss: 0.2463 - val_accuracy: 0.9175
# Epoch 376/1000
# 128/128 - 1s - loss: 0.2360 - accuracy: 0.9145 - val_loss: 0.2477 - val_accuracy: 0.9176
# Epoch 377/1000
# 128/128 - 1s - loss: 0.2338 - accuracy: 0.9152 - val_loss: 0.2465 - val_accuracy: 0.9171
# Epoch 378/1000
# 128/128 - 1s - loss: 0.2334 - accuracy: 0.9153 - val_loss: 0.2463 - val_accuracy: 0.9170
# Epoch 379/1000
# 128/128 - 1s - loss: 0.2335 - accuracy: 0.9161 - val_loss: 0.2445 - val_accuracy: 0.9169
# Epoch 380/1000
# 128/128 - 1s - loss: 0.2331 - accuracy: 0.9148 - val_loss: 0.2450 - val_accuracy: 0.9168
# Epoch 381/1000
# 128/128 - 1s - loss: 0.2351 - accuracy: 0.9140 - val_loss: 0.2435 - val_accuracy: 0.9174
# Epoch 382/1000
# 128/128 - 1s - loss: 0.2332 - accuracy: 0.9151 - val_loss: 0.2454 - val_accuracy: 0.9168
# Epoch 383/1000
# 128/128 - 1s - loss: 0.2302 - accuracy: 0.9163 - val_loss: 0.2445 - val_accuracy: 0.9173
# Epoch 384/1000
# 128/128 - 1s - loss: 0.2323 - accuracy: 0.9157 - val_loss: 0.2437 - val_accuracy: 0.9175
# Epoch 385/1000
# 128/128 - 1s - loss: 0.2301 - accuracy: 0.9162 - val_loss: 0.2457 - val_accuracy: 0.9179
# Epoch 386/1000
# 128/128 - 1s - loss: 0.2300 - accuracy: 0.9168 - val_loss: 0.2426 - val_accuracy: 0.9171
# Epoch 387/1000
# 128/128 - 1s - loss: 0.2297 - accuracy: 0.9168 - val_loss: 0.2441 - val_accuracy: 0.9171
# Epoch 388/1000
# 128/128 - 1s - loss: 0.2307 - accuracy: 0.9154 - val_loss: 0.2405 - val_accuracy: 0.9169
# Epoch 389/1000
# 128/128 - 1s - loss: 0.2294 - accuracy: 0.9164 - val_loss: 0.2425 - val_accuracy: 0.9163
# Epoch 390/1000
# 128/128 - 1s - loss: 0.2291 - accuracy: 0.9159 - val_loss: 0.2425 - val_accuracy: 0.9173
# Epoch 391/1000
# 128/128 - 1s - loss: 0.2290 - accuracy: 0.9165 - val_loss: 0.2408 - val_accuracy: 0.9182
# Epoch 392/1000
# 128/128 - 1s - loss: 0.2305 - accuracy: 0.9156 - val_loss: 0.2440 - val_accuracy: 0.9175
# Epoch 393/1000
# 128/128 - 1s - loss: 0.2277 - accuracy: 0.9170 - val_loss: 0.2442 - val_accuracy: 0.9172
# Epoch 394/1000
# 128/128 - 1s - loss: 0.2314 - accuracy: 0.9155 - val_loss: 0.2406 - val_accuracy: 0.9181
# Epoch 395/1000
# 128/128 - 1s - loss: 0.2281 - accuracy: 0.9176 - val_loss: 0.2413 - val_accuracy: 0.9172
# Epoch 396/1000
# 128/128 - 1s - loss: 0.2281 - accuracy: 0.9175 - val_loss: 0.2426 - val_accuracy: 0.9173
# Epoch 397/1000
# 128/128 - 1s - loss: 0.2271 - accuracy: 0.9165 - val_loss: 0.2424 - val_accuracy: 0.9174
# Epoch 398/1000
# 128/128 - 1s - loss: 0.2286 - accuracy: 0.9182 - val_loss: 0.2407 - val_accuracy: 0.9178
# 32/32 - 8s - loss: 0.1966 - accuracy: 0.9367
# test_loss: 0.1966034322977066 - test_acc: 0.9366632103919983

# %%
# y_pred = model.predict(x_test)
y_pred = model.predict(test_x)
print(y_pred.shape)

y_pred_onehot = np.argmax(y_pred, axis=1)
print(y_pred[200] ,"===> onehot: ", y_pred_onehot[200])
# Out:
# (16357, 5)
# [0.     0.     0.9927 0.0069 0.0004] ===> onehot:  2

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='lower left')

plt.show()

# %%
y_test_argmax = np.argmax(test_y ,axis=1) 
y_pred_argmax = np.argmax(y_pred ,axis=1)
print(y_test_argmax.shape, y_pred_argmax.shape)

def action_frames(y_pred_argmax, ratio_display = False):
    action_label =  {"sit": 0, "sit-stand": 1,  "walk": 2, "turn": 3, "stand-sit": 4}
    action_cnt =  {"total_frames": 0,"sit": 0, "sit-stand": 0,  "walk": 0, "turn": 0, "stand-sit": 0}

    for i in range(len(y_pred_argmax)):
        action_cnt["total_frames"] +=1
        if y_pred_argmax[i] == action_label["sit"]:
            action_cnt["sit"] +=1
            
        elif y_pred_argmax[i] == action_label["sit-stand"]:
            action_cnt["sit-stand"] +=1
            
        elif y_pred_argmax[i] == action_label["walk"]:
            action_cnt["walk"] +=1
            
        elif y_pred_argmax[i] == action_label["turn"]:
            action_cnt["turn"] +=1
            
        elif y_pred_argmax[i] == action_label["stand-sit"]:
            action_cnt["stand-sit"] +=1
        
    if ratio_display:     
        print("[ Action Ratio ]")
        print("\t [ 0 - Sit] ratio of sit: ",  action_cnt["sit"]/action_cnt["total_frames"] )
        print("\t [ 1 - sit-stand] ratio of sit-stand: ",  action_cnt["sit-stand"]/action_cnt["total_frames"])
        print("\t [ 2 - walk] ratio of walk: ",  action_cnt["walk"]/action_cnt["total_frames"])
        print("\t [ 3 - turn] ratio of turn: ",  action_cnt["turn"]/action_cnt["total_frames"])
        print("\t [ 4 - stand-sit] ratio of stand-sit: ",  action_cnt["stand-sit"]/action_cnt["total_frames"])
    return action_cnt
    
y_pred_frames = action_frames(y_pred_argmax, ratio_display= True)
y_test_frames = action_frames(y_test_argmax,  ratio_display= True)   

print("--->  # of Each Action Frames  \n\t y_pred: {0}, \n\t y_test: {1}".format(y_pred_frames, y_test_frames))
# Out:
# (16357,) (16357,)
# [ Action Ratio ]
# 	 [ 0 - Sit] ratio of sit:  0.19043834443968943
# 	 [ 1 - sit-stand] ratio of sit-stand:  0.04731919056061625
# 	 [ 2 - walk] ratio of walk:  0.5667298404352876
# 	 [ 3 - turn] ratio of turn:  0.13333740906034114
# 	 [ 4 - stand-sit] ratio of stand-sit:  0.06217521550406554
# [ Action Ratio ]
# 	 [ 0 - Sit] ratio of sit:  0.18242954086935256
# 	 [ 1 - sit-stand] ratio of sit-stand:  0.057406614904933664
# 	 [ 2 - walk] ratio of walk:  0.5396466344684233
# 	 [ 3 - turn] ratio of turn:  0.13926759185669743
# 	 [ 4 - stand-sit] ratio of stand-sit:  0.08124961790059301
# --->  # of Each Action Frames
# 	 y_pred: {'total_frames': 16357, 'sit': 3115, 'sit-stand': 774, 'walk': 9270, 'turn': 2181, 'stand-sit': 1017},
# 	 y_test: {'total_frames': 16357, 'sit': 2984, 'sit-stand': 939, 'walk': 8827, 'turn': 2278, 'stand-sit': 1329}

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import cohen_kappa_score
import seaborn as sns


kappa = cohen_kappa_score(y_test_argmax, y_pred_argmax)
print('Cohens kappa: %f' % kappa)

print(classification_report(y_test_argmax, y_pred_argmax))

conf_matrix = confusion_matrix(y_test_argmax, y_pred_argmax)
print("\n---> Confusion Matrix \n" ,conf_matrix) # sit, sit-stand, walking, turning, stand-sit

plt.figure(figsize = (15,7) )
sns.heatmap(conf_matrix, annot=True)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Cohens kappa: 0.899956
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      2984
#            1       0.93      0.77      0.84       939
#            2       0.93      0.98      0.96      8827
#            3       0.92      0.88      0.90      2278
#            4       0.97      0.74      0.84      1329
#
#     accuracy                           0.94     16357
#    macro avg       0.94      0.87      0.90     16357
# weighted avg       0.94      0.94      0.93     16357
#
#
# ---> Confusion Matrix
#  [[2950   14    0    0   20]
#  [ 108  723  108    0    0]
#  [   0   37 8657  120   13]
#  [   0    0  271 2007    0]
#  [  57    0  234   54  984]]

# %% [markdown]
# ### ------------- Prev. TCN Code

# %%
import os
import numpy as np 
from sklearn.model_selection import KFold  # 라벨 x_data, y_data 분포를 유지 (함께 fold)
import tensorflow as tf 
from IPython.display import clear_output

np.random.seed(7)
np.set_printoptions(precision=4, suppress=True)  # 과학적 표기 대신 소숫점 자리 4자리까지 표현

rootDir = "/DockerProjects/Dataset/TUG/trainSet"
expertFolder = "/" + "2021_01_24_saveResults_최윤정"  # --- 변경 할 부분
viewFolder = "/" + "0_sideView"

print(" [Home Dir.] Current path", os.getcwd())  

datasetDir = rootDir + expertFolder + viewFolder
os.chdir(datasetDir) ; print(" Current workaing path [dataset] ", os.getcwd())  # -- Dataset 있는 곳으로 경로 변경

# %% [markdown]
# Key
#     https://github.com/ashishpatel26/tcn-keras-Examples
#
# sub
#       https://www.programmersought.com/article/13674618779/

# %%
def trainData_split(datasetDir,train_ratio = 0.6, valid_ratio=0.2, shuffle = False,  Kfold_num = 5):      
    expDates = next(os.walk(datasetDir))[1]   #['2020_11_03', '2020_11_20_v1', '2020_11_20_v2', '2020_11_23', '2020_12_09', '2020_12_30']
    
    subject_number = 0
    subjects_list = []
    
    for dateFolder in expDates:
        dateDir = os.path.join(datasetDir, dateFolder)   # D:/바탕화면/Dataset/TUG/trainSet/2021_01_24_saveResults_최윤정/0_sideView\2020_11_03
        tmpSubjects = next(os.walk(dateDir))[1]
        subjects_list.append(tmpSubjects)  
        subject_number += len(tmpSubjects)

    # ------ 2D -> 1D [[sub1, sub2], [sub3, sub4]] -> [sub1, sub2, sub3, sub4]
    subjects = []
    for eachSub in subjects_list:
        subjects += eachSub
    print(" [before shuffle] 1D sub list: " , subjects)

    if shuffle:
        np.random.shuffle(subjects)
        print(" [After shuffle] 1D sub list: " , subjects)

#     # --- K-fold cross validation   
    if Kfold_num is not 0:
        Fold_results =[]
        print(" [K-Fold] K = ", Kfold_num)
        kfold = KFold(n_splits=  Kfold_num)
        for trainIdx, testIdx in kfold.split(subjects):
            Fold_results.append([trainIdx, testIdx])        
        train_Fold= []
        test_Fold = []
        
        for i in range(Kfold_num):
            tmp_train = []
            tmp_test = []
            for subIdx in range(len(subjects)): 
                if subIdx in Fold_results[i][0]:  # 
                    tmp_train.append(subjects[subIdx])
                    
                if subIdx in Fold_results[i][1]:  # -- K-fold test
                    tmp_test.append(subjects[subIdx])
          
            train_Fold.append(tmp_train)
            test_Fold.append(tmp_test)
            print("\t [process]", i, "-fold:", train_Fold[i], "\n\t\t\t   ,", test_Fold[i])
        print("\n [results]  trainSet: ", len(train_Fold[0]) , " 명 , testSet: ", len(test_Fold[0]), " 명" )
        return train_Fold, test_Fold

        
    else:
                # ---- Split train/test subjects (for arbitrary split)
        trainSub_number = np.round( (len(subjects)*train_ratio), 0).astype(int)
        validSub_number = np.round( (len(subjects)*valid_ratio), 0).astype(int)
        testSub_number = subject_number - trainSub_number - validSub_number
        
        print("--------- no fold ----")
        train_subjects = subjects[ :trainSub_number]
        valid_subjects = subjects[ trainSub_number : (trainSub_number+validSub_number)]
        test_subjects = subjects[ (trainSub_number+validSub_number): ]
        print("[results] \n\t Train: " ,train_subjects, "\n\t Valid: ", valid_subjects, "\n\t Test: ", test_subjects)
        print("\n\t--> # of train  : " + str(trainSub_number) +" 명 ,  # of valid : "+ str(validSub_number) + " 명 ,  # of test :" + str(testSub_number) + "명")
        return train_subjects, valid_subjects, test_subjects 


def getPelvisData(csvFile):
    rawData = np.loadtxt(csvFile, delimiter=",")
    timestamp = rawData[:,0]
    pelvis_x = rawData[:,1]
    pelvis_y = rawData[:,2]
    pelvis_z = rawData[:,3]
    actionList = rawData[:,4:9]
    return timestamp, pelvis_x, pelvis_y, pelvis_z, actionList

def create_dataset(train_subjects, valid_subjects, test_subjects):
    train_x = np.zeros((0, numFeature))
    train_y = np.zeros((0, numActions))
    
    valid_x = np.zeros((0, numFeature))
    valid_y = np.zeros((0, numActions))
    
    test_x = np.zeros((0, numFeature))
    test_y = np.zeros((0, numActions))    
    
    for dirpath, foldername, files in os.walk(datasetDir):
        for filename in files:
            if "lpf_" in filename:
                subname = dirpath.split("/")[-2] 
                csvFile = os.path.join(dirpath, filename)
                timestamp, pelvis_x, pelvis_y, pelvis_z, actionList = getPelvisData(csvFile) 
                
                pelvisData = np.array([pelvis_x, pelvis_y, pelvis_z]).T
                actionData = np.array(actionList)
                #dataset = tf.data.Dataset.from_tensor_slices( (pelvisData.astype('float32'), actionData.astype('float32')) ) 
                dataset = np.zeros( (len(pelvisData), dataset_columns) ) 
                
                dataset[:, :-(numActions)] = pelvisData      # time , pelvis  넣음  (317,4) -- raw data 
                dataset[:, -(numActions): ] = actionData     # (335, 5) one hot encoding 수행한 actionsList
                
                if Kfold_num==0:
                    if subname in train_subjects:
                        train_x = np.append(train_x, pelvisData, axis = 0 )
                        train_y = np.append(train_y, actionData, axis = 0 )

                    elif subname in valid_subjects:
                        valid_x = np.append(valid_x, pelvisData, axis = 0 )
                        valid_y = np.append(valid_y, actionData, axis = 0 )

                    elif subname in test_subjects:
                        test_x = np.append(test_x, pelvisData, axis = 0 )
                        test_y = np.append(test_y, actionData, axis = 0 )    
                else:
                    if subname in train_subjects:
                        train_x = np.append(train_x, pelvisData, axis = 0 )
                        train_y = np.append(train_y, actionData, axis = 0 )
                    elif subname in test_subjects:
                        test_x = np.append(test_x, pelvisData, axis = 0 )
                        test_y = np.append(test_y, actionData, axis = 0 )   

    return train_x, train_y, valid_x, valid_y, test_x, test_y

# %%
# ---------------  1. subject 별로 dataset 분할 (K-fold 정함) ------------------------------------------------------#

train_ratio = 0.6
valid_ratio = 0.2

Kfold_num = 0 # if kfold_num = 0 (arbitrary train/test set will be used)s
arbitrary_dataset = True

numFeature = 3
numActions = 5
dataset_columns = numFeature + numActions

if Kfold_num == 0:
    if arbitrary_dataset:

#         normal_subjects = ['bys_tug', 'cbd_tug', 'cyj_tug', 'kw', 'kyh', 'lhs', 'NHJ_60', 'nhs', 'pjh', 'pss', 'rjh', 'yjh', 'bys', 'cbd', 'cyj', 'cyj2', 'jdh', 'jek', 'kch', 'ryu'] 
#         patients_subjects = ['JDW_tug']
#         copy_patients_subjects = ['BYS_TUG', 'CYJ_TUG', 'PHE_TUG', 'YSJ_TUG'] 


#         train_subjects = ['bys_tug', 'cbd_tug', 'cyj_tug', 'kw', 'kyh', 'nhs', 'pjh', 'pss', 'rjh', 'yjh', 'bys', 'cbd', 'cyj','BYS_TUG', 'CYJ_TUG'] 
#         valid_subjects = ['cyj2', 'jdh', 'jek', 'PHE_TUG','lhs' ] 
#         test_subjects =  ['kch', 'ryu', 'JDW_tug', 'YSJ_TUG','NHJ_60']

        train_subjects = ['bys_tug', 'cbd_tug', 'cyj_tug', 'kw', 'kyh', 'nhs', 'pjh', 'pss', 'rjh', 'yjh', 'bys', 'cbd', 'cyj', ] 
        valid_subjects = ['cyj2', 'jdh', 'jek', 'lhs' ] 
        test_subjects =  ['kch', 'ryu', 'NHJ_60']
        
        
    else:
        train_subjects, valid_subjects, test_subjects = trainData_split(datasetDir, train_ratio = train_ratio, valid_ratio=valid_ratio, shuffle = False, Kfold_num = Kfold_num)
        
    train_x, train_y, valid_x, valid_y, test_x, test_y = create_dataset(train_subjects, valid_subjects, test_subjects )
    print("\n [Train] X - {0} , Y - {1} \t [Valid] X - {2}, Y - {3} \t [Test] X - {4} , Y - {5}".format(train_x.shape, train_y.shape, valid_x.shape, valid_y.shape, test_x.shape, test_y.shape))
    
else: 
    train_fold, test_fold = trainData_split(datasetDir, shuffle = False, Kfold_num = Kfold_num) 
    print("\n\n -------------------- K-Fold Dataset ------------------------ ")
    folds_dataset = []
    for i in range(Kfold_num):
        train_x, train_y, test_x, test_y = create_dataset(train_fold[i])
        print(" \t Train (X,Y): {0} , {1} \t Test (X,Y): {2} , {3}".format(train_x.shape, train_y.shape, test_x.shape, test_y.shape))
        folds.append((train_x, train_y, test_x, test_y)) # --- 수정 필요할듯
    print(np.array(folds[0][0]).shape)
# Out:
#  [Train] X - (48453, 3) , Y - (48453, 5) 	 [Valid] X - (16672, 3), Y - (16672, 5) 	 [Test] X - (11403, 3) , Y - (11403, 5)

# %%
from sklearn.preprocessing import MinMaxScaler
# import tqdm

lookback_window = 3



def sliding_window(data_x, data_y, lookback_window=15):
    x = []
    y = []
    enc = MinMaxScaler(feature_range = (0, 1))
    enc_y = enc.fit_transform(data_y)
    for i in range(lookback_window, len(data_x)):
        x.append(data_x[i - lookback_window:i])
        y.append(data_y[i])
        
    x = np.array(x)
    y = np.array(y)
    
    x = x.reshape(-1, lookback_window, 3, 1)
#     y = y.reshape(-1, 5, 1)
    return x, y, enc


x_train, y_train, enc_train = sliding_window(train_x, train_y,  lookback_window=lookback_window) # (57207, 15, 3)
x_valid, y_valid, enc_valid = sliding_window(valid_x, valid_y,  lookback_window=lookback_window)
x_test, y_test, enc_test = sliding_window(test_x, test_y, lookback_window=lookback_window)
print("x_train: ", x_train.shape," , y_train: ", y_train.shape)
print("x_valid: ",x_valid.shape, " , y_valid: ",y_valid.shape)
print("x_test: ",x_test.shape, "  , y_test: ",y_test.shape)
# Out:
# x_train:  (48450, 3, 3, 1)  , y_train:  (48450, 5)
# x_valid:  (16669, 3, 3, 1)  , y_valid:  (16669, 5)
# x_test:  (11400, 3, 3, 1)   , y_test:  (11400, 5)

# %% [markdown]
# ### Model Build

# %%
from keras.layers import Conv1D, Input, Activation, Flatten, Dense, Conv2D
from keras.layers import BatchNormalization, add , Dropout
from keras.models import Model
from keras.optimizers import Adam

from keras.callbacks import ModelCheckpoint, EarlyStopping

from tcn import TCN

# %%
MODEL_SAVE_FOLDER_PATH = rootDir + "/"+ expertFolder +"/model_TCN/"

print(MODEL_SAVE_FOLDER_PATH)
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)
    
model_path = MODEL_SAVE_FOLDER_PATH + "WinSize- "+ str(lookback_window) +"TUG-" + "{epoch:02d} ---- {val_loss: .4f}.hdf5"

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor="val_loss", verbose=1, save_best_only=True)
cb_early_stopping = EarlyStopping(monitor="val_loss", patience=15)
# Out:
# /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/

# %%
 #Residual block :: https://roadcom.tistory.com/95
def ResBlock(x,filters,kernel_size,dilation_rate):
    r=Conv2D(filters,kernel_size=kernel_size,padding='same',dilation_rate=dilation_rate,activation='relu')(x) #first convolution
    r=Conv2D(filters,kernel_size=kernel_size,padding='same',dilation_rate=dilation_rate)(r) #Second convolution
    if x.shape[-1]==filters:
        # Shortcut 의 channel 과 main path 의 channel 이 일치할 경우 단순 add 연산만 진행하는 블록 = identity block
        shortcut = x  # identity block 
    else: 
        # Shortcut 의 channel 과 main path 의 channel 이 다를 경우 shortcut path 를 적절히 변환
        # 즉, projection 을 통해 channel 을 맞춰주는 작업이(projection shortcut) 추가되기에 이를 convolution block 이라함
        shortcut=Conv2D(filters,kernel_size=kernel_size,padding='same')(x) 
    o=add([r,shortcut])
    o=Activation('relu')(o) 
    return o
 
 #Sequence Model
def TCN(train_x,train_y, valid_x, valid_y, test_x,test_y,class_weight):
    kernel_size = (3,3)
    input_shape =  (lookback_window, 3, 1) # (3, 8, 1) = (feature, sliding_window, 1)
    
    inputs=Input(shape=input_shape)
    
    x=ResBlock(x = inputs,filters=32,kernel_size=kernel_size,dilation_rate=1)
    x = Dropout(0.2) (x)
    x=ResBlock(x,filters=32,kernel_size=kernel_size,dilation_rate=2)
    x = Dropout(0.4)(x)
    x=ResBlock(x,filters=16,kernel_size=kernel_size,dilation_rate=4)
    
    x=Flatten()(x)
    x=Dense(5, activation='softmax')(x)
    model=Model(inputs=inputs,outputs=x)
         
    model.summary()
        
    model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
    hist = model.fit(train_x,train_y,batch_size= 500, epochs=100,verbose=2, validation_data= (valid_x, valid_y),  callbacks=[cb_checkpoint, cb_early_stopping], class_weight=class_weight)

    eval_result = model.evaluate(test_x,test_y,batch_size= 500,verbose=2)
#     eval_result = model.evaluate(valid_x,valid_y,batch_size=200,verbose=2)
    
    return model, eval_result, hist

# %%
 # (feature, sliding_window, 1) ...TCN,,,  
class_weight = {0:0.21, 1:0.06, 2:0.5, 3:0.14, 4:0.09}
model, eval_result, hist = TCN(x_train,y_train, x_valid, y_valid, x_test, y_test, class_weight)
print('test_loss:',eval_result[0],'- test_acc:',eval_result[1])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 3, 3, 1)]    0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 3, 3, 32)     320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 3, 3, 32)     9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 3, 3, 32)     320         input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 3, 3, 32)     0           conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 3, 3, 32)     0           add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 3, 3, 32)     0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 3, 3, 32)     9248        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 3, 3, 32)     9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 3, 3, 32)     0           conv2d_4[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 3, 3, 32)     0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 3, 3, 32)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 3, 3, 16)     4624        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 3, 3, 16)     2320        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 3, 3, 16)     4624        dropout_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 3, 3, 16)     0           conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 3, 3, 16)     0           add_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 144)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 5)            725         flatten[0][0]
# ==================================================================================================
# Total params: 40,677
# Trainable params: 40,677
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 97/97 - 66s - loss: 0.1916 - accuracy: 0.6437 - val_loss: 0.7374 - val_accuracy: 0.7197
#
# Epoch 00001: val_loss improved from inf to 0.73740, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-01 ----  0.7374.hdf5
# Epoch 2/100
# 97/97 - 0s - loss: 0.0935 - accuracy: 0.7525 - val_loss: 0.7010 - val_accuracy: 0.7460
#
# Epoch 00002: val_loss improved from 0.73740 to 0.70102, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-02 ----  0.7010.hdf5
# Epoch 3/100
# 97/97 - 1s - loss: 0.0869 - accuracy: 0.7627 - val_loss: 0.6338 - val_accuracy: 0.7530
#
# Epoch 00003: val_loss improved from 0.70102 to 0.63376, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-03 ----  0.6338.hdf5
# Epoch 4/100
# 97/97 - 0s - loss: 0.0822 - accuracy: 0.7666 - val_loss: 0.5807 - val_accuracy: 0.7664
#
# Epoch 00004: val_loss improved from 0.63376 to 0.58072, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-04 ----  0.5807.hdf5
# Epoch 5/100
# 97/97 - 0s - loss: 0.0724 - accuracy: 0.7878 - val_loss: 0.4782 - val_accuracy: 0.7842
#
# Epoch 00005: val_loss improved from 0.58072 to 0.47824, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-05 ----  0.4782.hdf5
# Epoch 6/100
# 97/97 - 0s - loss: 0.0616 - accuracy: 0.8187 - val_loss: 0.3467 - val_accuracy: 0.8475
#
# Epoch 00006: val_loss improved from 0.47824 to 0.34674, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-06 ----  0.3467.hdf5
# Epoch 7/100
# 97/97 - 0s - loss: 0.0423 - accuracy: 0.8676 - val_loss: 0.4351 - val_accuracy: 0.8192
#
# Epoch 00007: val_loss did not improve from 0.34674
# Epoch 8/100
# 97/97 - 0s - loss: 0.0371 - accuracy: 0.8800 - val_loss: 0.3179 - val_accuracy: 0.8722
#
# Epoch 00008: val_loss improved from 0.34674 to 0.31793, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-08 ----  0.3179.hdf5
# Epoch 9/100
# 97/97 - 0s - loss: 0.0347 - accuracy: 0.8879 - val_loss: 0.2686 - val_accuracy: 0.8864
#
# Epoch 00009: val_loss improved from 0.31793 to 0.26861, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-09 ----  0.2686.hdf5
# Epoch 10/100
# 97/97 - 0s - loss: 0.0336 - accuracy: 0.8950 - val_loss: 0.4717 - val_accuracy: 0.8546
#
# Epoch 00010: val_loss did not improve from 0.26861
# Epoch 11/100
# 97/97 - 0s - loss: 0.0319 - accuracy: 0.9054 - val_loss: 0.2741 - val_accuracy: 0.9151
#
# Epoch 00011: val_loss did not improve from 0.26861
# Epoch 12/100
# 97/97 - 0s - loss: 0.0286 - accuracy: 0.9195 - val_loss: 0.1966 - val_accuracy: 0.9335
#
# Epoch 00012: val_loss improved from 0.26861 to 0.19665, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-12 ----  0.1966.hdf5
# Epoch 13/100
# 97/97 - 0s - loss: 0.0278 - accuracy: 0.9239 - val_loss: 0.1744 - val_accuracy: 0.9373
#
# Epoch 00013: val_loss improved from 0.19665 to 0.17439, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-13 ----  0.1744.hdf5
# Epoch 14/100
# 97/97 - 0s - loss: 0.0266 - accuracy: 0.9283 - val_loss: 0.2648 - val_accuracy: 0.9137
#
# Epoch 00014: val_loss did not improve from 0.17439
# Epoch 15/100
# 97/97 - 0s - loss: 0.0265 - accuracy: 0.9289 - val_loss: 0.1794 - val_accuracy: 0.9353
#
# Epoch 00015: val_loss did not improve from 0.17439
# Epoch 16/100
# 97/97 - 0s - loss: 0.0245 - accuracy: 0.9346 - val_loss: 0.1891 - val_accuracy: 0.9261
#
# Epoch 00016: val_loss did not improve from 0.17439
# Epoch 17/100
# 97/97 - 0s - loss: 0.0250 - accuracy: 0.9314 - val_loss: 0.2400 - val_accuracy: 0.9137
#
# Epoch 00017: val_loss did not improve from 0.17439
# Epoch 18/100
# 97/97 - 0s - loss: 0.0244 - accuracy: 0.9336 - val_loss: 0.1937 - val_accuracy: 0.9242
#
# Epoch 00018: val_loss did not improve from 0.17439
# Epoch 19/100
# 97/97 - 0s - loss: 0.0235 - accuracy: 0.9346 - val_loss: 0.2130 - val_accuracy: 0.9176
#
# Epoch 00019: val_loss did not improve from 0.17439
# Epoch 20/100
# 97/97 - 0s - loss: 0.0231 - accuracy: 0.9360 - val_loss: 0.1980 - val_accuracy: 0.9251
#
# Epoch 00020: val_loss did not improve from 0.17439
# Epoch 21/100
# 97/97 - 0s - loss: 0.0242 - accuracy: 0.9327 - val_loss: 0.2642 - val_accuracy: 0.9105
#
# Epoch 00021: val_loss did not improve from 0.17439
# Epoch 22/100
# 97/97 - 0s - loss: 0.0238 - accuracy: 0.9349 - val_loss: 0.1810 - val_accuracy: 0.9271
#
# Epoch 00022: val_loss did not improve from 0.17439
# Epoch 23/100
# 97/97 - 0s - loss: 0.0235 - accuracy: 0.9347 - val_loss: 0.2074 - val_accuracy: 0.9215
#
# Epoch 00023: val_loss did not improve from 0.17439
# Epoch 24/100
# 97/97 - 0s - loss: 0.0233 - accuracy: 0.9351 - val_loss: 0.1616 - val_accuracy: 0.9321
#
# Epoch 00024: val_loss improved from 0.17439 to 0.16159, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-24 ----  0.1616.hdf5
# Epoch 25/100
# 97/97 - 0s - loss: 0.0230 - accuracy: 0.9354 - val_loss: 0.1585 - val_accuracy: 0.9342
#
# Epoch 00025: val_loss improved from 0.16159 to 0.15852, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-25 ----  0.1585.hdf5
# Epoch 26/100
# 97/97 - 1s - loss: 0.0224 - accuracy: 0.9363 - val_loss: 0.1631 - val_accuracy: 0.9342
#
# Epoch 00026: val_loss did not improve from 0.15852
# Epoch 27/100
# 97/97 - 0s - loss: 0.0227 - accuracy: 0.9361 - val_loss: 0.1533 - val_accuracy: 0.9328
#
# Epoch 00027: val_loss improved from 0.15852 to 0.15331, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-27 ----  0.1533.hdf5
# Epoch 28/100
# 97/97 - 0s - loss: 0.0225 - accuracy: 0.9351 - val_loss: 0.1532 - val_accuracy: 0.9371
#
# Epoch 00028: val_loss improved from 0.15331 to 0.15317, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-28 ----  0.1532.hdf5
# Epoch 29/100
# 97/97 - 0s - loss: 0.0230 - accuracy: 0.9347 - val_loss: 0.1674 - val_accuracy: 0.9300
#
# Epoch 00029: val_loss did not improve from 0.15317
# Epoch 30/100
# 97/97 - 0s - loss: 0.0227 - accuracy: 0.9366 - val_loss: 0.1802 - val_accuracy: 0.9287
#
# Epoch 00030: val_loss did not improve from 0.15317
# Epoch 31/100
# 97/97 - 0s - loss: 0.0226 - accuracy: 0.9360 - val_loss: 0.2288 - val_accuracy: 0.9166
#
# Epoch 00031: val_loss did not improve from 0.15317
# Epoch 32/100
# 97/97 - 0s - loss: 0.0220 - accuracy: 0.9373 - val_loss: 0.1510 - val_accuracy: 0.9367
#
# Epoch 00032: val_loss improved from 0.15317 to 0.15102, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-32 ----  0.1510.hdf5
# Epoch 33/100
# 97/97 - 0s - loss: 0.0219 - accuracy: 0.9374 - val_loss: 0.1720 - val_accuracy: 0.9274
#
# Epoch 00033: val_loss did not improve from 0.15102
# Epoch 34/100
# 97/97 - 0s - loss: 0.0220 - accuracy: 0.9371 - val_loss: 0.1578 - val_accuracy: 0.9323
#
# Epoch 00034: val_loss did not improve from 0.15102
# Epoch 35/100
# 97/97 - 0s - loss: 0.0221 - accuracy: 0.9368 - val_loss: 0.1591 - val_accuracy: 0.9310
#
# Epoch 00035: val_loss did not improve from 0.15102
# Epoch 36/100
# 97/97 - 0s - loss: 0.0226 - accuracy: 0.9349 - val_loss: 0.1847 - val_accuracy: 0.9211
#
# Epoch 00036: val_loss did not improve from 0.15102
# Epoch 37/100
# 97/97 - 0s - loss: 0.0226 - accuracy: 0.9362 - val_loss: 0.2043 - val_accuracy: 0.9206
#
# Epoch 00037: val_loss did not improve from 0.15102
# Epoch 38/100
# 97/97 - 0s - loss: 0.0218 - accuracy: 0.9365 - val_loss: 0.1484 - val_accuracy: 0.9347
#
# Epoch 00038: val_loss improved from 0.15102 to 0.14838, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-38 ----  0.1484.hdf5
# Epoch 39/100
# 97/97 - 0s - loss: 0.0228 - accuracy: 0.9339 - val_loss: 0.1891 - val_accuracy: 0.9242
#
# Epoch 00039: val_loss did not improve from 0.14838
# Epoch 40/100
# 97/97 - 0s - loss: 0.0215 - accuracy: 0.9368 - val_loss: 0.1459 - val_accuracy: 0.9387
#
# Epoch 00040: val_loss improved from 0.14838 to 0.14586, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-40 ----  0.1459.hdf5
# Epoch 41/100
# 97/97 - 0s - loss: 0.0216 - accuracy: 0.9366 - val_loss: 0.1700 - val_accuracy: 0.9324
#
# Epoch 00041: val_loss did not improve from 0.14586
# Epoch 42/100
# 97/97 - 0s - loss: 0.0222 - accuracy: 0.9353 - val_loss: 0.1829 - val_accuracy: 0.9217
#
# Epoch 00042: val_loss did not improve from 0.14586
# Epoch 43/100
# 97/97 - 0s - loss: 0.0217 - accuracy: 0.9367 - val_loss: 0.2099 - val_accuracy: 0.9162
#
# Epoch 00043: val_loss did not improve from 0.14586
# Epoch 44/100
# 97/97 - 1s - loss: 0.0216 - accuracy: 0.9374 - val_loss: 0.2211 - val_accuracy: 0.9148
#
# Epoch 00044: val_loss did not improve from 0.14586
# Epoch 45/100
# 97/97 - 0s - loss: 0.0218 - accuracy: 0.9362 - val_loss: 0.2114 - val_accuracy: 0.9181
#
# Epoch 00045: val_loss did not improve from 0.14586
# Epoch 46/100
# 97/97 - 0s - loss: 0.0218 - accuracy: 0.9361 - val_loss: 0.1618 - val_accuracy: 0.9324
#
# Epoch 00046: val_loss did not improve from 0.14586
# Epoch 47/100
# 97/97 - 0s - loss: 0.0219 - accuracy: 0.9367 - val_loss: 0.1548 - val_accuracy: 0.9356
#
# Epoch 00047: val_loss did not improve from 0.14586
# Epoch 48/100
# 97/97 - 0s - loss: 0.0221 - accuracy: 0.9353 - val_loss: 0.1587 - val_accuracy: 0.9301
#
# Epoch 00048: val_loss did not improve from 0.14586
# Epoch 49/100
# 97/97 - 0s - loss: 0.0216 - accuracy: 0.9367 - val_loss: 0.1964 - val_accuracy: 0.9218
#
# Epoch 00049: val_loss did not improve from 0.14586
# Epoch 50/100
# 97/97 - 0s - loss: 0.0219 - accuracy: 0.9367 - val_loss: 0.1661 - val_accuracy: 0.9273
#
# Epoch 00050: val_loss did not improve from 0.14586
# Epoch 51/100
# 97/97 - 0s - loss: 0.0221 - accuracy: 0.9351 - val_loss: 0.1668 - val_accuracy: 0.9314
#
# Epoch 00051: val_loss did not improve from 0.14586
# Epoch 52/100
# 97/97 - 0s - loss: 0.0215 - accuracy: 0.9372 - val_loss: 0.1841 - val_accuracy: 0.9264
#
# Epoch 00052: val_loss did not improve from 0.14586
# Epoch 53/100
# 97/97 - 0s - loss: 0.0217 - accuracy: 0.9346 - val_loss: 0.1385 - val_accuracy: 0.9385
#
# Epoch 00053: val_loss improved from 0.14586 to 0.13849, saving model to /DockerProjects/Dataset/TUG/trainSet//2021_01_24_saveResults_최윤정/model_TCN/WinSize- 3TUG-53 ----  0.1385.hdf5
# Epoch 54/100
# 97/97 - 0s - loss: 0.0218 - accuracy: 0.9363 - val_loss: 0.1402 - val_accuracy: 0.9386
#
# Epoch 00054: val_loss did not improve from 0.13849
# Epoch 55/100
# 97/97 - 0s - loss: 0.0214 - accuracy: 0.9381 - val_loss: 0.1757 - val_accuracy: 0.9248
#
# Epoch 00055: val_loss did not improve from 0.13849
# Epoch 56/100
# 97/97 - 0s - loss: 0.0216 - accuracy: 0.9368 - val_loss: 0.1567 - val_accuracy: 0.9377
#
# Epoch 00056: val_loss did not improve from 0.13849
# Epoch 57/100
# 97/97 - 0s - loss: 0.0212 - accuracy: 0.9376 - val_loss: 0.1713 - val_accuracy: 0.9297
#
# Epoch 00057: val_loss did not improve from 0.13849
# Epoch 58/100
# 97/97 - 0s - loss: 0.0208 - accuracy: 0.9383 - val_loss: 0.1617 - val_accuracy: 0.9329
#
# Epoch 00058: val_loss did not improve from 0.13849
# Epoch 59/100
# 97/97 - 0s - loss: 0.0222 - accuracy: 0.9365 - val_loss: 0.2150 - val_accuracy: 0.9206
#
# Epoch 00059: val_loss did not improve from 0.13849
# Epoch 60/100
# 97/97 - 0s - loss: 0.0222 - accuracy: 0.9347 - val_loss: 0.1540 - val_accuracy: 0.9374
#
# Epoch 00060: val_loss did not improve from 0.13849
# Epoch 61/100
# 97/97 - 0s - loss: 0.0220 - accuracy: 0.9363 - val_loss: 0.1891 - val_accuracy: 0.9243
#
# Epoch 00061: val_loss did not improve from 0.13849
# Epoch 62/100
# 97/97 - 0s - loss: 0.0211 - accuracy: 0.9371 - val_loss: 0.1714 - val_accuracy: 0.9276
#
# Epoch 00062: val_loss did not improve from 0.13849
# Epoch 63/100
# 97/97 - 0s - loss: 0.0209 - accuracy: 0.9381 - val_loss: 0.1653 - val_accuracy: 0.9290
#
# Epoch 00063: val_loss did not improve from 0.13849
# Epoch 64/100
# 97/97 - 0s - loss: 0.0210 - accuracy: 0.9375 - val_loss: 0.1678 - val_accuracy: 0.9310
#
# Epoch 00064: val_loss did not improve from 0.13849
# Epoch 65/100
# 97/97 - 0s - loss: 0.0213 - accuracy: 0.9370 - val_loss: 0.1474 - val_accuracy: 0.9373
#
# Epoch 00065: val_loss did not improve from 0.13849
# Epoch 66/100
# 97/97 - 0s - loss: 0.0229 - accuracy: 0.9351 - val_loss: 0.1588 - val_accuracy: 0.9375
#
# Epoch 00066: val_loss did not improve from 0.13849
# Epoch 67/100
# 97/97 - 1s - loss: 0.0214 - accuracy: 0.9370 - val_loss: 0.1701 - val_accuracy: 0.9259
#
# Epoch 00067: val_loss did not improve from 0.13849
# Epoch 68/100
# 97/97 - 0s - loss: 0.0212 - accuracy: 0.9368 - val_loss: 0.1399 - val_accuracy: 0.9425
#
# Epoch 00068: val_loss did not improve from 0.13849
# 23/23 - 11s - loss: 0.1658 - accuracy: 0.9353
# test_loss: 0.16582755744457245 - test_acc: 0.9352631568908691

# %%
# y_pred = model.predict(x_test)
y_pred = model.predict(x_test)
print(y_pred.shape)

y_pred_onehot = np.argmax(y_pred, axis=1)
print(y_pred[200] ,"===> onehot: ", y_pred_onehot[200])
# Out:
# (11400, 5)
# [0.     0.     0.0002 0.9998 0.    ] ===> onehot:  3

# %% [markdown]
# ### 현재 결론: 환자/모방환자 data 를 train set에 포함 시 acc 90% , data balance가 맞지 않으면 85% 정도..
# ### 추가로 환자 data 더 넣어볼 것

# %%
# print(hist.history['loss'])
# print(hist.history['accuracy'])
# print(hist.history['val_loss'])
# print(hist.history['val_accuracy'])

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='lower left')

plt.show()

# %% [markdown]
# ### Confusion Matrix, Precision, Recall, F1 score

# %%
y_test_argmax = np.argmax(y_test ,axis=1) 
y_pred_argmax = np.argmax(y_pred ,axis=1)
print(y_test_argmax.shape, y_pred_argmax.shape)

def action_frames(y_pred_argmax, ratio_display = False):
    action_label =  {"sit": 0, "sit-stand": 1,  "walk": 2, "turn": 3, "stand-sit": 4}
    action_cnt =  {"total_frames": 0,"sit": 0, "sit-stand": 0,  "walk": 0, "turn": 0, "stand-sit": 0}

    for i in range(len(y_pred_argmax)):
        action_cnt["total_frames"] +=1
        if y_pred_argmax[i] == action_label["sit"]:
            action_cnt["sit"] +=1
            
        elif y_pred_argmax[i] == action_label["sit-stand"]:
            action_cnt["sit-stand"] +=1
            
        elif y_pred_argmax[i] == action_label["walk"]:
            action_cnt["walk"] +=1
            
        elif y_pred_argmax[i] == action_label["turn"]:
            action_cnt["turn"] +=1
            
        elif y_pred_argmax[i] == action_label["stand-sit"]:
            action_cnt["stand-sit"] +=1
        
    if ratio_display:     
        print("[ Action Ratio ]")
        print("\t [ 0 - Sit] ratio of sit: ",  action_cnt["sit"]/action_cnt["total_frames"] )
        print("\t [ 1 - sit-stand] ratio of sit-stand: ",  action_cnt["sit-stand"]/action_cnt["total_frames"])
        print("\t [ 2 - walk] ratio of walk: ",  action_cnt["walk"]/action_cnt["total_frames"])
        print("\t [ 3 - turn] ratio of turn: ",  action_cnt["turn"]/action_cnt["total_frames"])
        print("\t [ 4 - stand-sit] ratio of stand-sit: ",  action_cnt["stand-sit"]/action_cnt["total_frames"])


    
    return action_cnt
    
y_pred_frames = action_frames(y_pred_argmax, ratio_display= True)
y_test_frames = action_frames(y_test_argmax,  ratio_display= True)   

print("--->  # of Each Action Frames  \n\t y_pred: {0}, \n\t y_test: {1}".format(y_pred_frames, y_test_frames))
# Out:
# (11400,) (11400,)
# [ Action Ratio ]
# 	 [ 0 - Sit] ratio of sit:  0.24929824561403507
# 	 [ 1 - sit-stand] ratio of sit-stand:  0.05008771929824561
# 	 [ 2 - walk] ratio of walk:  0.48929824561403507
# 	 [ 3 - turn] ratio of turn:  0.1299122807017544
# 	 [ 4 - stand-sit] ratio of stand-sit:  0.08140350877192983
# [ Action Ratio ]
# 	 [ 0 - Sit] ratio of sit:  0.23640350877192984
# 	 [ 1 - sit-stand] ratio of sit-stand:  0.0669298245614035
# 	 [ 2 - walk] ratio of walk:  0.4637719298245614
# 	 [ 3 - turn] ratio of turn:  0.13736842105263158
# 	 [ 4 - stand-sit] ratio of stand-sit:  0.09552631578947368
# --->  # of Each Action Frames
# 	 y_pred: {'total_frames': 11400, 'sit': 2842, 'sit-stand': 571, 'walk': 5578, 'turn': 1481, 'stand-sit': 928},
# 	 y_test: {'total_frames': 11400, 'sit': 2695, 'sit-stand': 763, 'walk': 5287, 'turn': 1566, 'stand-sit': 1089}

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import cohen_kappa_score
import seaborn as sns


kappa = cohen_kappa_score(y_test_argmax, y_pred_argmax)
print('Cohens kappa: %f' % kappa)

print(classification_report(y_test_argmax, y_pred_argmax))

conf_matrix = confusion_matrix(y_test_argmax, y_pred_argmax)
print("\n---> Confusion Matrix \n" ,conf_matrix) # sit, sit-stand, walking, turning, stand-sit

plt.figure(figsize = (15,7) )
sns.heatmap(conf_matrix, annot=True)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Cohens kappa: 0.905517
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      2695
#            1       0.97      0.73      0.83       763
#            2       0.93      0.98      0.95      5287
#            3       0.94      0.89      0.91      1566
#            4       0.95      0.81      0.88      1089
#
#     accuracy                           0.94     11400
#    macro avg       0.95      0.88      0.91     11400
# weighted avg       0.94      0.94      0.93     11400
#
#
# ---> Confusion Matrix
#  [[2667   13    0    0   15]
#  [ 127  554   82    0    0]
#  [   0    4 5165   88   30]
#  [   0    0  173 1393    0]
#  [  48    0  158    0  883]]

# %% [markdown]
# import matplotlib.pyplot as plt
#
# print("Testing Accuracy: {}%".format(100*accuracy))
#
# print("")
# print("Precision: {}%".format(100*metrics.precision_score(y_test, predictions, average="weighted")))
# print("Recall: {}%".format(100*metrics.recall_score(y_test, predictions, average="weighted")))
# print("f1_score: {}%".format(100*metrics.f1_score(y_test, predictions, average="weighted")))
#
# print("")
# print("Confusion Matrix:")
# confusion_matrix = metrics.confusion_matrix(y_test, predictions)
# print(confusion_matrix)
# normalised_confusion_matrix = np.array(confusion_matrix, dtype=np.float32)/np.sum(confusion_matrix)*100
#
# print("")
# print("Confusion matrix (normalised to % of total test data):")
# print(normalised_confusion_matrix)
# print("Note: training and testing data is not equally distributed amongst classes, ")
# print("so it is normal that more than a 6th of the data is correctly classifier in the last category.")
#
# # Plot Results:
# width = 12
# height = 12
# plt.figure(figsize=(width, height))
# plt.imshow(
#     normalised_confusion_matrix,
#     interpolation='nearest',
#     cmap=plt.cm.rainbow
# )
# plt.title("Confusion matrix \n(normalised to % of total test data)")
# plt.colorbar()
# tick_marks = np.arange(n_classes)
# plt.xticks(tick_marks, LABELS, rotation=90)
# plt.yticks(tick_marks, LABELS)
# plt.tight_layout()
# plt.ylabel('True label')
# plt.xlabel('Predicted label')
# plt.show()

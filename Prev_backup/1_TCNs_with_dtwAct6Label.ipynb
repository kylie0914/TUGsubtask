# %% [markdown]
# ### Get Pelvis data - LPF + Norm (save Figure + csv)
# ### Get oneHot encoded Label
# ### Interpolation (Univariate Interpolation)

# %%
import os
import numpy as np 
import matplotlib.pyplot as plt
from IPython.display import clear_output

from scipy.signal import butter, lfilter, filtfilt  
from scipy.interpolate import UnivariateSpline  # missing value -> np.nan -> to zero -> 

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold  # 라벨 x_data, y_data 분포를 유지 (함께 fold)
import tensorflow as tf 

np.random.seed(7)
np.set_printoptions(precision=4, suppress=True)  # 과학적 표기 대신 소숫점 자리 4자리까지 표현

rootDir = "/DockerProjects/Dataset/TUG/trainSet" + "/LSTMpaper"
expertFolder = "/" + "saveResults_최윤정"  # --- 변경 할 부분
# expertFolder = "/" + "saveResults_김윤환"  # --- 변경 할 부분
viewFolder = "/" + "0_sideView"

print(" [Home Dir.] Current path", os.getcwd())  

datasetDir = rootDir + expertFolder + viewFolder
os.chdir(datasetDir) ; print(" Current workaing path [dataset] ", os.getcwd())  # -- Dataset 있는 곳으로 경로 변경

# %% [markdown]
# ### Train/Test Subject Split

# %%
def get_subjectList(datasetDir, shuffle = False):      
    expDates = next(os.walk(datasetDir))[1]   #['2020_11_03', '2020_11_20_v1', '2020_11_20_v2', '2020_11_23', '2020_12_09', '2020_12_30']
    subject_number = 0
    subjects_list = []
    
    for dateFolder in expDates:
        dateDir = os.path.join(datasetDir, dateFolder)   # D:/바탕화면/Dataset/TUG/trainSet/2021_01_24_saveResults_최윤정/0_sideView\2020_11_03
        tmpSubjects = next(os.walk(dateDir))[1]
        
        subjects_list.append(tmpSubjects)  


    # ------ 2D -> 1D [[sub1, sub2], [sub3, sub4]] -> [sub1, sub2, sub3, sub4]
    subjects = []
    for eachSub in subjects_list:
        for sub in eachSub:
            if ".ipynb_checkpoints" == sub:
                continue
            else:
                subjects.append(sub)
                subject_number +=1

    if shuffle:
        np.random.shuffle(subjects)
        
    print(" 1D sub list: " , subjects, len(subjects))
    return subjects, subject_number

def fold_trainNames(subList, Kfold_num = 5):
    assert (Kfold_num is not 0), print("check kfold_num. should not be zero")
    Fold_results =[]
    kfold = KFold(n_splits=  Kfold_num)
    
    for trainIdx, testIdx in kfold.split(subList):
        Fold_results.append([trainIdx, testIdx])      
        
    train_Fold= []
    test_Fold = []
        
    for i in range(Kfold_num):    # bind fold pair
        tmp_train = []
        tmp_test = []
        for subIdx in range(len(subList)): 
            if subIdx in Fold_results[i][0]:  # -- K-fold train
                tmp_train.append(subList[subIdx])
               
            if subIdx in Fold_results[i][1]:  # -- K-fold test
                tmp_test.append(subList[subIdx])
          
        train_Fold.append(tmp_train)
        test_Fold.append(tmp_test)
        print("\t [process]", i, "-fold:", train_Fold[i], "\n\t\t\t   ,", test_Fold[i])
    print("\n [results]  trainSet: ", len(train_Fold[0]) , " 명 , testSet: ", len(test_Fold[0]), " 명" )
    
    return train_Fold, test_Fold

# %%
train_ratio = 0.6
valid_ratio = 0.2

arbitrarySplit = False #True
Kfold = False
Kfold_num = 5 # if kfold_num = 0 (arbitrary train/test set will be used)s


numFeature = 4 # time + numPelvis = 4
numPelvis = 3 
numActions = 6
dataset_columns = numFeature + numActions

subList, numOfsubjects = get_subjectList(datasetDir, shuffle = True) ; print("\n")

if arbitrarySplit is not True:
    if Kfold:
        print(" K-fold : ", Kfold_num)
        trainFold, testFold = fold_trainNames(subList = subList, Kfold_num = Kfold_num)

        selected_foldNum = 0 

        train_subjects = trainFold[selected_foldNum]
        test_subjects = testFold[selected_foldNum]
        print("  [No Arbitrary , Fold] \t ------>  Selected Fold num: %d \n   Train Subjects: %s\n   Test Subjects: %s"%(selected_foldNum, train_subjects, test_subjects))
    else:

        trainSub_number = np.round( (numOfsubjects*train_ratio), 0).astype(int)
        validSub_number = np.round( (numOfsubjects*valid_ratio), 0).astype(int)
        
        print(numOfsubjects, trainSub_number, validSub_number)
        testSub_number = numOfsubjects - trainSub_number - validSub_number

        train_subjects = subList[ :trainSub_number]
        valid_subjects = subList[ trainSub_number : (trainSub_number+validSub_number)]
        test_subjects = subList[ (trainSub_number + validSub_number): ]
        print("  [No Arbitrary , No Fold] \t [results] \n\t Train: " ,train_subjects, "\n\t Valid: ", valid_subjects, "\n\t Test: ", test_subjects)
        print("\n\t--> # of train  : " + str(trainSub_number) +" 명 ,  # of valid : "+ str(validSub_number) + " 명 ,  # of test :" + str(testSub_number) + "명")

else:

#     normal_subjects = ['bys_tug', 'cbd_tug', 'cyj_tug', 'kw', 'kyh', 'lhs', 'NHJ_60', 'nhs', 'pjh', 'pss', 'rjh', 'yjh', 'bys', 'cbd', 'cyj', 'cyj2', 'jdh', 'jek', 'kch', 'ryu'] 
#     patients_subjects = ['JDW_tug']
#     copy_patients_subjects = ['BYS_TUG', 'CYJ_TUG', 'PHE_TUG', 'YSJ_TUG'] 

#     train_subjects = ['bys_tug', 'cbd_tug', 'cyj_tug', 'pss', 'yjh', 'lhs', 'kyh', 'nhs', 'kw', 'NHJ_60', 'pjh', 'rjh', 'ryu', 'PHE_TUG', 'YSJ_TUG'] 
#     valid_subjects = ['ryu', 'cyh','jdh', 'cbd', 'CYJ_TUG'] 
#     test_subjects =  ['JDW_tug', 'BYS_TUG', 'kch', 'bys', 'jek', 'cyj', 'cyj2' ]
    
    
#     train_subjects = ['bys_tug', 'cbd_tug', 'cyj_tug', 'kw', 'kyh', 'nhs', 'pjh', 'pss', 'rjh', 'yjh', 'bys', 'cbd', 'cyj'] 
#     valid_subjects = ['cyj2', 'jdh', 'jek', 'lhs' ] 
#     test_subjects =  ['kch', 'ryu', 'NHJ_60']
    
    train_subjects = ['PHE_TUG', 'kw', 'CYJ_TUG', 'BYS_TUG', 'KYS_TUG', 'RJD_TUG', 'SRK_TUG', 'bys_tug', 'cbd_tug', 'cyj_tug', 'rjh', 'cbd', 'kch', 'bys', 'jek', 'cyj', 'cyj2'] 
    valid_subjects = ['pss', 'yjh', 'lhs', 'kyh', 'nhs', 'YSJ_TUG'] 
    test_subjects =  ['NHJ_60', 'pjh', 'jdh', 'ryu', 'cyh', 'JDW_tug']

#     train_subjects = ['bys']
#     test_subjects = train_subjects
#     valid_subjects = train_subjects
    
    print("  [Arbitrary , No-Fold] \t [results] \n\t Train: " ,train_subjects, "\n\t Valid: ", valid_subjects, "\n\t Test: ", test_subjects)
# Out:
#  1D sub list:  ['cbd_tug', 'lhs', 'cyj_tug', 'cyj2', 'jek', 'KYS_TUG', 'rjh', 'bys_tug', 'cyj', 'kyh', 'kch', 'jdh', 'ryu', 'pjh', 'cbd', 'NHJ_60', 'kw', 'cyh', 'nhs', 'bys', 'pss', 'yjh', 'JDW_tug'] 23
#
#
# 23 14 5
#   [No Arbitrary , No Fold] 	 [results]
# 	 Train:  ['cbd_tug', 'lhs', 'cyj_tug', 'cyj2', 'jek', 'KYS_TUG', 'rjh', 'bys_tug', 'cyj', 'kyh', 'kch', 'jdh', 'ryu', 'pjh']
# 	 Valid:  ['cbd', 'NHJ_60', 'kw', 'cyh', 'nhs']
# 	 Test:  ['bys', 'pss', 'yjh', 'JDW_tug']
#
# 	--> # of train  : 14 명 ,  # of valid : 5 명 ,  # of test :4명

# %%
def get_rawData(csvFile):
    
    interCheck = False
    # Some csv file has " " (blank) --- read as string then convert to float
    csv_data_ = np.loadtxt(csvFile, delimiter=',', dtype=str, skiprows=2, usecols=(0,1,2,3)) 
    frameNum = csv_data_[:,0].astype(np.int)  # int로 type conversion
    max_frame = len(csv_data_[:,0])
    
    rawPelvis_x = np.array(frameNum).astype(np.float32)
    rawPelvis_y = np.array(frameNum).astype(np.float32)
    rawPelvis_z = np.array(frameNum).astype(np.float32)
    

    #--- Interpolating 
    for i, v in enumerate(csv_data_[:, 1]):
        if v == " ": # if it has " " (blank)  --> change to  nan for interpolating 
            interCheck = True
            csv_data_[i,1] = np.nan
            csv_data_[i,2] = np.nan
            csv_data_[i,3] = np.nan
        rawPelvis_x[i] = csv_data_[i, 1].astype(np.float32)
        rawPelvis_y[i] = csv_data_[i, 2].astype(np.float32)
        rawPelvis_z[i] = csv_data_[i, 3].astype(np.float32)
  
    if interCheck: 
        w_x = np.isnan(rawPelvis_x) 
        rawPelvis_x[w_x] = 0
        Fx = UnivariateSpline(frameNum,rawPelvis_x,w=~w_x)
        newPelvis_x = Fx(frameNum)

        w_y = np.isnan(rawPelvis_y) 
        rawPelvis_y[w_y] = 0
        Fy = UnivariateSpline(frameNum,rawPelvis_y,w=~w_y)
        newPelvis_y = Fy(frameNum)

        w_z = np.isnan(rawPelvis_z) 
        rawPelvis_z[w_z] = 0
        Fz = UnivariateSpline(frameNum,rawPelvis_z,w=~w_z)
        newPelvis_z = Fz(frameNum)

        # 그린다.
#         plt.figure(figsize=(16, 5))
#         plt.subplot(131)
#         plt.plot(frameNum, newPelvis_x, '-')
#         plt.subplot(132)
#         plt.plot(frameNum, newPelvis_y, '-')
#         plt.subplot(133)
#         plt.plot(frameNum, newPelvis_z, '-')
    else:
        newPelvis_x = rawPelvis_x
        newPelvis_y = rawPelvis_y
        newPelvis_z = rawPelvis_z
        
    
    
    timeData = np.loadtxt(csvFile, delimiter=',', skiprows=2, dtype=np.float32, usecols=[97, 98, 99, 100]) #  # skiprows=2 (header + first data.. 가끔 첫 줄 data 이상함)
    timestamp_diff_msec = np.array([rawPelvis_x])
    for i in range(max_frame):
        before_time_msec = timeData[i-1, 0] * 60 * 60 * 1000 + timeData[i-1, 1] * 60 * 1000 +  timeData[i-1, 2] * 1000 + timeData[i-1, 3] 
        current_time_msec = timeData[i, 0] * 60 * 60 * 1000 + timeData[i, 1] * 60 * 1000 + timeData[i, 2] * 1000 + timeData[i, 3]
        if i is 0:
            timestamp_diff_msec[0, i] = 0
        else:
            timestamp_diff_msec[0, i] = int(current_time_msec - before_time_msec)
                            
        time_sum_msec = 0
        eachTimestamp_sec = np.array(frameNum, dtype=float) # sec (?,1)
        for timeIdx in range(timestamp_diff_msec.shape[1]):
            time_sum_msec = int(time_sum_msec + timestamp_diff_msec[0, timeIdx])
            eachTimestamp_sec[timeIdx] = time_sum_msec / 1000  
  
    return frameNum, eachTimestamp_sec, newPelvis_x, newPelvis_y, newPelvis_z

    
def get_normData(pelvis_x, pelvis_y, pelvis_z, normMethod = 'min_max'):    
    if normMethod == "min_max":
        normPelvis_x = (pelvis_x -np.min(pelvis_x)) / ( np.max(pelvis_x) - np.min(pelvis_x))
        normPelvis_y = (pelvis_y -np.min(pelvis_y)) / ( np.max(pelvis_y) - np.min(pelvis_y))
        normPelvis_z = (pelvis_z -np.min(pelvis_z)) / ( np.max(pelvis_z) - np.min(pelvis_z))
        
    elif normMethod == "z_score":
        normPelvis_x = (pelvis_x -np.mean(pelvis_x)) / np.std(pelvis_x)
        normPelvis_y = (pelvis_y -np.mean(pelvis_y)) / np.std(pelvis_y)
        normPelvis_z = (pelvis_z -np.mean(pelvis_z)) / np.std(pelvis_z)
        
    return normPelvis_x, normPelvis_y, normPelvis_z

def get_LPFData(pelvis_x, pelvis_y, pelvis_z, cutoff_freq = 0.5, order=1):
    sampling_freq = 30
    number_of_samples = len(pelvis_y)
    normalized_cutoff_freq = 2 * cutoff_freq / sampling_freq
    numerator_coeffs, denominator_coeffs = butter(order, normalized_cutoff_freq)
    Filtered_x = filtfilt(numerator_coeffs, denominator_coeffs, pelvis_x)  # Phase shift 없음
    Filtered_y = filtfilt(numerator_coeffs, denominator_coeffs, pelvis_y)
    Filtered_z = filtfilt(numerator_coeffs, denominator_coeffs, pelvis_z)
    return Filtered_x, Filtered_y, Filtered_z


def getLPF_PelvisData(csvFile):
    rawData = np.loadtxt(csvFile, delimiter=",")
    timestamp = rawData[:,0]
    pelvis_x = rawData[:,1]
    pelvis_y = rawData[:,2]
    pelvis_z = rawData[:,3]
    actionList = rawData[:,4:]
    return timestamp, pelvis_x, pelvis_y, pelvis_z, actionList

  
def pltSkeleton(timeSec, pelvis_x, pelvis_y, pelvis_z, saveDir, saveFile,  actLabel, addFolder="raw", actSplit=False, save=True):
    fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(8, 7))
    title = addFolder + "_" + saveFile
    ax[0].set_title(title)
    ax[0].set_ylabel('Side axis(X) of Pelvis [mm]')
    ax[1].set_ylabel('Vertical axis(Y) of Pelvis [mm]')
    ax[2].set_ylabel('Depth Axis of Pelvis [mm]')
    ax[2].set_xlabel('Time [Sec]')
    ax[0].plot(timeSec, pelvis_x, "r--", lw=1, label="pelvis_x")
    ax[1].plot(timeSec, pelvis_y, "g--", lw=1, label="pelvis_y")
    ax[2].plot(timeSec, pelvis_z, "b--", lw=1, label="pelvis_z")
    
    if actSplit:
        for i in range(3):
            if i ==0:
                ax[i].axvline(x=timeSec[actLabel[0]], color='r', linestyle="--", linewidth=3, label="start move")
                ax[i].axvline(x=timeSec[actLabel[1]], color='r', linestyle=":", linewidth=3, label="start walk")
                
                ax[i].axvline(x=timeSec[actLabel[2]], color='k', linestyle="--", linewidth=3, label="start turn")
                ax[i].axvline(x=timeSec[actLabel[3]], color='k', linestyle=":", linewidth=3, label="end turn")
                
                ax[i].axvline(x=timeSec[actLabel[4]], color='g', linestyle="--", linewidth=3, label="start sit")
                ax[i].axvline(x=timeSec[actLabel[5]], color='g', linestyle=":", linewidth=3, label="end sit")
            else:
                ax[i].axvline(x=timeSec[actLabel[0]], color='r', linestyle="--", linewidth=3)
                ax[i].axvline(x=timeSec[actLabel[1]], color='k', linestyle="--", linewidth=3)
                ax[i].axvline(x=timeSec[actLabel[2]], color='g', linestyle="--", linewidth=3)

                ax[i].axvline(x=timeSec[actLabel[3]], color='r', linestyle=":", linewidth=3)
                ax[i].axvline(x=timeSec[actLabel[4]], color='k', linestyle=":", linewidth=3)
                ax[i].axvline(x=timeSec[actLabel[5]], color='g', linestyle=":", linewidth=3)

    fig.legend()
    plt.show()
    
    if save:
        if  os.path.isfile(saveDir+"/"+title):
            os.remove(saveDir+"/"+title)
        fig.savefig(saveDir+"/"+title)
    plt.close()

# %%
def get_actFrameNumber(csvFile): 
    actFrame = []
    with open(csvFile, 'r', encoding='utf-8') as readCSV:
        data = readCSV.read()
        lines = data.split("\n") # lines[0] = header, [1] = act label data
        tmpLabel = lines[1].split(",")
       
        for i in range(len(tmpLabel)):           
            actFrame.append( int(tmpLabel[i].split("_")[1].split(".")[0]) ) 
        return actFrame   
    
def sliding_window(timestamp, data_x, data_y, lookback_window=3):
    time = []
    x = []
    y = []
    enc = MinMaxScaler(feature_range = (0, 1))
    enc_y = enc.fit_transform(data_y)
    for i in range(lookback_window, len(data_x)+1):
        time.append(timestamp[i-1])
        x.append(data_x[i - lookback_window:i])
        y.append(data_y[i-1])
  
    x = np.array(x)
    x = x.reshape(-1, lookback_window, numPelvis, 1)
    
    y = np.array(y)
    time = np.array(time)
   
    return time, x, y, enc

#------------------ Origin... sit, sit-to-stand, walk, turn, stand-to-sit (5action)
# def convert_act2oneHot(actFrame, frameNum):
#     actionList = []
#     for timeIdx in range(len(frameNum)):
#         if (timeIdx < actFrame[0]):  # frame Num < move start fram (sit)
#             actionList.append(np.array([1, 0, 0, 0, 0],dtype=np.int))
#                     # moveStartIdx ~ startWalk 까지 (sit-to-stand)
#         elif (timeIdx >= actFrame[0]) and (timeIdx < actFrame[1]):
#             actionList.append(np.array([0, 1, 0, 0, 0],dtype=np.int))
#                     # startWalk ~ turnStartIdx 까지 (walk)
#         elif (timeIdx >= actFrame[1]) and (timeIdx < actFrame[2]):
#             actionList.append(np.array([0, 0, 1, 0, 0],dtype=np.int))
#                     # turnStartIdx ~ turnEndIdx 까지 (turn)
#         elif (timeIdx >= actFrame[2]) and (timeIdx < actFrame[3]):
#             actionList.append(np.array([0, 0, 0, 1, 0],dtype=np.int))
#                     # turnEndIdx ~ startSitIdx 까지 (walk)
#         elif (timeIdx >= actFrame[3]) and (timeIdx < actFrame[4]):
#             actionList.append(np.array([0, 0, 1, 0, 0],dtype=np.int))
#                     # startSitIdx ~ moveEndIdx 까지 (stand-to-sit)
#         elif (timeIdx >= actFrame[4]) and (timeIdx < actFrame[5]):
#             actionList.append(np.array([0, 0, 0, 0, 1],dtype=np.int))
            
#         elif (timeIdx >= actFrame[5]):
#             actionList.append(np.array([1, 0, 0, 0, 0],dtype=np.int))
        
            
#         else:
#             AssertionError("Check getLabel_forEveryTrial func. in utils_labeling_all")
#         oneTrial_actionList = np.array(actionList)
#     return np.array(oneTrial_actionList)


# #------------------ dtw 용... Sit, Sit-to-stand, Walk, Turn, WalkBack, Sit-back ( 6 action)  split ... Acc = 80 %
# def convert_act2oneHot(actFrame, frameNum):
#     actionList = []
#     for timeIdx in range(len(frameNum)):
#         if (timeIdx < actFrame[0]):  # frame Num < move start fram (sit)
#             actionList.append(np.array([1, 0, 0, 0, 0, 0],dtype=np.int))
#                     # moveStartIdx ~ startWalk 까지 (sit-stand)
#         elif (timeIdx >= actFrame[0]) and (timeIdx < actFrame[1]):
#             actionList.append(np.array([0, 1, 0, 0, 0, 0],dtype=np.int))
#                     # startWalk ~ turnStartIdx 까지 (walk)
#         elif (timeIdx >= actFrame[1]) and (timeIdx < actFrame[2]):
#             actionList.append(np.array([0, 0, 1, 0, 0, 0],dtype=np.int))
#                     # turnStartIdx ~ turnEndIdx 까지 (turn)
#         elif (timeIdx >= actFrame[2]) and (timeIdx < actFrame[3]):
#             actionList.append(np.array([0, 0, 0, 1, 0, 0],dtype=np.int))
#                     # turnEndIdx ~ startSitIdx 까지 (walk-back)
#         elif (timeIdx >= actFrame[3]) and (timeIdx < actFrame[4]):
#             actionList.append(np.array([0, 0, 0, 0, 1, 0],dtype=np.int))
#                     # startSitIdx ~ moveEndIdx 까지 (Sit-back)
#         elif (timeIdx >= actFrame[4]):
#             actionList.append(np.array([0, 0, 0, 0, 0, 1],dtype=np.int))
            
            
#         else:
#             AssertionError("Check getLabel_forEveryTrial func. in utils_labeling_all")
#         oneTrial_actionList = np.array(actionList)
#     return np.array(oneTrial_actionList)

# %%
def readLPF_createDataset(train_subjects, test_subjects, lookback_window = 8):
    train_x = np.zeros((0, lookback_window,numPelvis , 1)) 
    train_y = np.zeros((0, numActions))
    
    valid_x = np.zeros((0, lookback_window, numPelvis, 1))
    valid_y = np.zeros((0, numActions))
    
    test_x = np.zeros((0, lookback_window, numPelvis,1 ))
    test_y = np.zeros((0, numActions)) 
    
    total_Trials = 0
    for dirpath, foldername, files in sorted(os.walk(datasetDir)):
        actPath = None
        pelvisPath= None
        actFrame = []
        if ".ipynb_checkpoints" in dirpath:
            continue
        else:
            for filename in sorted(files):
                if ".csv" in filename:
                    if "DTWact6_lpf" in filename:     # Act6_, Act5_lpf , labeled_ (Origin93) , DTWact6
                        pelvisPath = dirpath    
                        subname = dirpath.split("/")[-2] 
                        pelvis_csv = os.path.join(dirpath, filename)

                        timstamp_ms, lpfPelvis_x, lpfPelvis_y, lpfPelvis_z, oneHot_actionList  = getLPF_PelvisData(pelvis_csv)  # raw                 
     
                        
                        total_Trials +=1   

                            
                        pelvisData = np.array([lpfPelvis_x, lpfPelvis_y, lpfPelvis_z]).T  # (335,3) 
                        actionData = np.array(oneHot_actionList)    # # (335, 5)
                            
                        blockTime, blockPelvis, blockLable, enc = sliding_window(timstamp_ms, data_x = pelvisData, data_y = actionData, lookback_window=lookback_window) # pelvis - (327, 8, 3)
#                         print(dirpath, "\t", blockLable.shape)
                        if Kfold is not True:
                            if subname in train_subjects:
                                train_x = np.append(train_x, blockPelvis, axis = 0 )
                                train_y = np.append(train_y, blockLable, axis = 0 )

                            elif subname in valid_subjects:
                                valid_x = np.append(valid_x, blockPelvis, axis = 0 )
                                valid_y = np.append(valid_y, blockLable, axis = 0 )

                            elif subname in test_subjects:
                                test_x = np.append(test_x, blockPelvis, axis = 0 )
                                test_y = np.append(test_y, blockLable, axis = 0 )    
                        else:
                            if subname in train_subjects:
                                train_x = np.append(train_x, blockPelvis, axis = 0 )
                                train_y = np.append(train_y, blockLable, axis = 0 )
                            elif subname in test_subjects:
                                test_x = np.append(test_x, blockPelvis, axis = 0 )
                                test_y = np.append(test_y, blockLable, axis = 0 )  

    return total_Trials, train_x, train_y, valid_x, valid_y, test_x, test_y



def readRaw_createDataset(train_subjects, test_subjects, lookback_window = 8):
    train_x = np.zeros((0, lookback_window, numPelvis , 1)) 
    train_y = np.zeros((0, numActions))
    
    valid_x = np.zeros((0, lookback_window, numPelvis, 1))
    valid_y = np.zeros((0, numActions))
    
    test_x = np.zeros((0, lookback_window, numPelvis,1 ))
    test_y = np.zeros((0, numActions)) 
    
    total_Trials = 0
    for dirpath, foldername, files in sorted(os.walk(datasetDir)):
#         clear_output(wait=True)
        actPath = None
        pelvisPath= None
        actFrame = []
        if ".ipynb_checkpoints" in dirpath:
            continue
        else:
            for filename in sorted(files):
                if ".csv" in filename:
                    if "label_" in filename:
                        labelPath = dirpath
                        label_csv = os.path.join(labelPath,filename)
                        actFrame = get_actFrameNumber( label_csv)

                    if "skeleton_" in filename:          
                        pelvisPath = dirpath    
                        subname = dirpath.split("/")[-2] 
                        pelvis_csv = os.path.join(dirpath, filename)

                        frameNum, timstamp_ms, pelvis_x, pelvis_y, pelvis_z  = get_rawData(pelvis_csv)  # raw                 
                        normPelvis_x, normPelvis_y, normPelvis_z = get_normData(pelvis_x, pelvis_y, pelvis_z, normMethod = 'min_max') # norm         
                        lpfPelvis_x, lpfPelvis_y, lpfPelvis_z = get_LPFData(normPelvis_x, normPelvis_y, normPelvis_z, cutoff_freq=0.5, order=1)  # lpf 
                    
                        total_Trials +=1   
                        
                        if labelPath == pelvisPath:  
                            oneHot_actionList = convert_act2oneHot(actFrame, frameNum)
                            
                            pelvisData = np.array([lpfPelvis_x, lpfPelvis_y, lpfPelvis_z]).T  # (335,3) 
                            actionData = np.array(oneHot_actionList)    # # (335, 5)
                            
                            blockTime, blockPelvis, blockLable, enc = sliding_window(timstamp_ms, data_x = pelvisData, data_y = actionData, lookback_window=lookback_window) # pelvis - (327, 8, 3)
                            
                            
                            if Kfold is not True:
                                if subname in train_subjects:
                                    train_x = np.append(train_x, blockPelvis, axis = 0 )
                                    train_y = np.append(train_y, blockLable, axis = 0 )

                                elif subname in valid_subjects:
                                    valid_x = np.append(valid_x, blockPelvis, axis = 0 )
                                    valid_y = np.append(valid_y, blockLable, axis = 0 )

                                elif subname in test_subjects:
                                    test_x = np.append(test_x, blockPelvis, axis = 0 )
                                    test_y = np.append(test_y, blockLable, axis = 0 )    
                            else:
                                if subname in train_subjects:
                                    train_x = np.append(train_x, blockPelvis, axis = 0 )
                                    train_y = np.append(train_y, blockLable, axis = 0 )
                                elif subname in test_subjects:
                                    test_x = np.append(test_x, blockPelvis, axis = 0 )
                                    test_y = np.append(test_y, blockLable, axis = 0 )  

    return total_Trials, train_x, train_y, valid_x, valid_y, test_x, test_y


# lookback_window = 8

# %%
lookback_window = 8

# total_Trials, train_x, train_y, valid_x, valid_y, test_x, test_y =  readRaw_createDataset(train_subjects, test_subjects, lookback_window = lookback_window)
total_Trials, train_x, train_y, valid_x, valid_y, test_x, test_y =  readLPF_createDataset(train_subjects, test_subjects, lookback_window = lookback_window)
print("train_x: ", train_x.shape," , train_y: ", train_y.shape)
print("valid_x: ",valid_x.shape, " , valid_y: ",valid_y.shape)
print("test_x: ",test_x.shape, "  , test_y: ",test_y.shape)
# Out:
# train_x:  (47707, 8, 3, 1)  , train_y:  (47707, 6)
# valid_x:  (19946, 8, 3, 1)  , valid_y:  (19946, 6)
# test_x:  (12850, 8, 3, 1)   , test_y:  (12850, 6)

# %% [markdown]
# ### Model Build

# %%
from keras.layers import Conv1D, Input, Activation, Flatten, Dense, Conv2D
from keras.layers import BatchNormalization, add , Dropout
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tcn import TCN

# %%
MODEL_SAVE_FOLDER_PATH ="/DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results" + expertFolder + "/DTWact6/"

print(MODEL_SAVE_FOLDER_PATH)
if not os.path.exists(MODEL_SAVE_FOLDER_PATH):
    os.mkdir(MODEL_SAVE_FOLDER_PATH)
    
model_path = MODEL_SAVE_FOLDER_PATH + "LookBack- "+ str(lookback_window) +"TUG-" + "{epoch:04d} ---- {val_loss: .4f}.hdf5"

cb_checkpoint = ModelCheckpoint(filepath=model_path, monitor="val_loss", verbose=1, save_best_only=True)
cb_early_stopping = EarlyStopping(monitor="val_loss", patience=10)
# Out:
# /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/

# %%
 #Residual block :: https://roadcom.tistory.com/95
def ResBlock(x,filters,kernel_size,dilation_rate):
    r=Conv2D(filters,kernel_size=kernel_size,padding='same',dilation_rate=dilation_rate,activation='relu')(x) #first convolution
    r=Conv2D(filters,kernel_size=kernel_size,padding='same',dilation_rate=dilation_rate)(r) #Second convolution
    if x.shape[-1]==filters:
        # Shortcut 의 channel 과 main path 의 channel 이 일치할 경우 단순 add 연산만 진행하는 블록 = identity block
        shortcut = x  # identity block 
    else: 
        # Shortcut 의 channel 과 main path 의 channel 이 다를 경우 shortcut path 를 적절히 변환
        # 즉, projection 을 통해 channel 을 맞춰주는 작업이(projection shortcut) 추가되기에 이를 convolution block 이라함
        shortcut=Conv2D(filters,kernel_size=kernel_size,padding='same')(x) 
    o=add([r,shortcut])
    o=Activation('relu')(o) 
    return o
 
 #Sequence Model
def TCN(optimizer='adam'):
    kernel_size = (3,3)
    input_shape =  (lookback_window, 3, 1) # (8,3, 1) = (feature, sliding_window, 1)
    
    inputs=Input(shape=input_shape)
    
    x=ResBlock(x = inputs,filters=32,kernel_size=kernel_size,dilation_rate=1)
    x = Dropout(0.2) (x)
    x=ResBlock(x,filters=32,kernel_size=kernel_size,dilation_rate=2)
    x = Dropout(0.4)(x)
    x=ResBlock(x,filters=16,kernel_size=kernel_size,dilation_rate=4)
    
    x=Flatten()(x)
    x=Dense(numActions, activation='softmax')(x)
    model=Model(inputs=inputs,outputs=x)
         
    model.summary()
        
    model.compile(optimizer=optimizer,loss='categorical_crossentropy', metrics=['accuracy'])
 
    return model

# %%
# (feature, sliding_window, 1) ...TCN,,,  
# class_weight = {0:0.303, 1:1.0, 2: 0.144, 3:0.487, 4: 0.7}
# class_weight = {0: 3.1 , 1: 4.32, 2: 1.14, 3: 1.68 , 4: 1.74, 5: 1.0}
batch_size = 512
epochs = 1000
learning_rate = 0.00001


optimizer = tf.optimizers.Adam(learning_rate)

model = TCN(optimizer)
# hist = model.fit(train_x,train_y, batch_size= batch_size, epochs=epochs,verbose=2, validation_data= (valid_x, valid_y),  callbacks=[cb_checkpoint, cb_early_stopping], class_weight=class_weight)
hist = model.fit(train_x,train_y, batch_size= batch_size, epochs=epochs,verbose=2, validation_data= (valid_x, valid_y),  callbacks=[cb_checkpoint, cb_early_stopping])
eval_result = model.evaluate(test_x, test_y,batch_size= batch_size,verbose=2)

print('test_loss:',eval_result[0],'- test_acc:',eval_result[1])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8, 3, 1)]    0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 8, 3, 32)     320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 3, 32)     9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 3, 32)     320         input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8, 3, 32)     0           conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 8, 3, 32)     0           add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 8, 3, 32)     0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 3, 32)     9248        dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 3, 32)     9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 3, 32)     0           conv2d_4[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8, 3, 32)     0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 3, 32)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 3, 16)     4624        dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 3, 16)     2320        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 3, 16)     4624        dropout_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 3, 16)     0           conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 8, 3, 16)     0           add_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 384)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 6)            2310        flatten[0][0]
# ==================================================================================================
# Total params: 42,262
# Trainable params: 42,262
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/1000
# 94/94 - 80s - loss: 1.8047 - accuracy: 0.1537 - val_loss: 1.7708 - val_accuracy: 0.2123
#
# Epoch 00001: val_loss improved from inf to 1.77080, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0001 ----  1.7708.hdf5
# Epoch 2/1000
# 94/94 - 1s - loss: 1.7648 - accuracy: 0.2092 - val_loss: 1.7318 - val_accuracy: 0.3422
#
# Epoch 00002: val_loss improved from 1.77080 to 1.73181, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0002 ----  1.7318.hdf5
# Epoch 3/1000
# 94/94 - 1s - loss: 1.7270 - accuracy: 0.2975 - val_loss: 1.6893 - val_accuracy: 0.5181
#
# Epoch 00003: val_loss improved from 1.73181 to 1.68931, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0003 ----  1.6893.hdf5
# Epoch 4/1000
# 94/94 - 1s - loss: 1.6848 - accuracy: 0.4013 - val_loss: 1.6380 - val_accuracy: 0.4796
#
# Epoch 00004: val_loss improved from 1.68931 to 1.63801, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0004 ----  1.6380.hdf5
# Epoch 5/1000
# 94/94 - 1s - loss: 1.6356 - accuracy: 0.4518 - val_loss: 1.5766 - val_accuracy: 0.4789
#
# Epoch 00005: val_loss improved from 1.63801 to 1.57663, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0005 ----  1.5766.hdf5
# Epoch 6/1000
# 94/94 - 1s - loss: 1.5757 - accuracy: 0.4587 - val_loss: 1.5045 - val_accuracy: 0.4830
#
# Epoch 00006: val_loss improved from 1.57663 to 1.50450, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0006 ----  1.5045.hdf5
# Epoch 7/1000
# 94/94 - 1s - loss: 1.5109 - accuracy: 0.4580 - val_loss: 1.4282 - val_accuracy: 0.4937
#
# Epoch 00007: val_loss improved from 1.50450 to 1.42818, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0007 ----  1.4282.hdf5
# Epoch 8/1000
# 94/94 - 1s - loss: 1.4439 - accuracy: 0.4622 - val_loss: 1.3548 - val_accuracy: 0.4971
#
# Epoch 00008: val_loss improved from 1.42818 to 1.35476, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0008 ----  1.3548.hdf5
# Epoch 9/1000
# 94/94 - 1s - loss: 1.3813 - accuracy: 0.4640 - val_loss: 1.2876 - val_accuracy: 0.4982
#
# Epoch 00009: val_loss improved from 1.35476 to 1.28758, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0009 ----  1.2876.hdf5
# Epoch 10/1000
# 94/94 - 1s - loss: 1.3225 - accuracy: 0.4728 - val_loss: 1.2253 - val_accuracy: 0.4999
#
# Epoch 00010: val_loss improved from 1.28758 to 1.22529, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0010 ----  1.2253.hdf5
# Epoch 11/1000
# 94/94 - 1s - loss: 1.2676 - accuracy: 0.4970 - val_loss: 1.1664 - val_accuracy: 0.5343
#
# Epoch 00011: val_loss improved from 1.22529 to 1.16638, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0011 ----  1.1664.hdf5
# Epoch 12/1000
# 94/94 - 1s - loss: 1.2172 - accuracy: 0.5268 - val_loss: 1.1121 - val_accuracy: 0.5722
#
# Epoch 00012: val_loss improved from 1.16638 to 1.11213, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0012 ----  1.1121.hdf5
# Epoch 13/1000
# 94/94 - 1s - loss: 1.1651 - accuracy: 0.5577 - val_loss: 1.0603 - val_accuracy: 0.5968
#
# Epoch 00013: val_loss improved from 1.11213 to 1.06033, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0013 ----  1.0603.hdf5
# Epoch 14/1000
# 94/94 - 1s - loss: 1.1201 - accuracy: 0.5796 - val_loss: 1.0117 - val_accuracy: 0.6204
#
# Epoch 00014: val_loss improved from 1.06033 to 1.01175, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0014 ----  1.0117.hdf5
# Epoch 15/1000
# 94/94 - 1s - loss: 1.0779 - accuracy: 0.5935 - val_loss: 0.9686 - val_accuracy: 0.6368
#
# Epoch 00015: val_loss improved from 1.01175 to 0.96855, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0015 ----  0.9686.hdf5
# Epoch 16/1000
# 94/94 - 1s - loss: 1.0392 - accuracy: 0.6017 - val_loss: 0.9273 - val_accuracy: 0.6453
#
# Epoch 00016: val_loss improved from 0.96855 to 0.92727, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0016 ----  0.9273.hdf5
# Epoch 17/1000
# 94/94 - 1s - loss: 1.0013 - accuracy: 0.6093 - val_loss: 0.8892 - val_accuracy: 0.6466
#
# Epoch 00017: val_loss improved from 0.92727 to 0.88921, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0017 ----  0.8892.hdf5
# Epoch 18/1000
# 94/94 - 1s - loss: 0.9711 - accuracy: 0.6180 - val_loss: 0.8572 - val_accuracy: 0.6495
#
# Epoch 00018: val_loss improved from 0.88921 to 0.85724, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0018 ----  0.8572.hdf5
# Epoch 19/1000
# 94/94 - 1s - loss: 0.9409 - accuracy: 0.6241 - val_loss: 0.8284 - val_accuracy: 0.6559
#
# Epoch 00019: val_loss improved from 0.85724 to 0.82837, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0019 ----  0.8284.hdf5
# Epoch 20/1000
# 94/94 - 1s - loss: 0.9155 - accuracy: 0.6313 - val_loss: 0.8032 - val_accuracy: 0.6667
#
# Epoch 00020: val_loss improved from 0.82837 to 0.80319, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0020 ----  0.8032.hdf5
# Epoch 21/1000
# 94/94 - 1s - loss: 0.8892 - accuracy: 0.6428 - val_loss: 0.7763 - val_accuracy: 0.6821
#
# Epoch 00021: val_loss improved from 0.80319 to 0.77629, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0021 ----  0.7763.hdf5
# Epoch 22/1000
# 94/94 - 1s - loss: 0.8695 - accuracy: 0.6521 - val_loss: 0.7545 - val_accuracy: 0.6912
#
# Epoch 00022: val_loss improved from 0.77629 to 0.75449, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0022 ----  0.7545.hdf5
# Epoch 23/1000
# 94/94 - 1s - loss: 0.8497 - accuracy: 0.6621 - val_loss: 0.7305 - val_accuracy: 0.7062
#
# Epoch 00023: val_loss improved from 0.75449 to 0.73052, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0023 ----  0.7305.hdf5
# Epoch 24/1000
# 94/94 - 1s - loss: 0.8243 - accuracy: 0.6741 - val_loss: 0.7053 - val_accuracy: 0.7140
#
# Epoch 00024: val_loss improved from 0.73052 to 0.70528, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0024 ----  0.7053.hdf5
# Epoch 25/1000
# 94/94 - 1s - loss: 0.8002 - accuracy: 0.6881 - val_loss: 0.6788 - val_accuracy: 0.7288
#
# Epoch 00025: val_loss improved from 0.70528 to 0.67881, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0025 ----  0.6788.hdf5
# Epoch 26/1000
# 94/94 - 1s - loss: 0.7763 - accuracy: 0.6974 - val_loss: 0.6547 - val_accuracy: 0.7398
#
# Epoch 00026: val_loss improved from 0.67881 to 0.65470, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0026 ----  0.6547.hdf5
# Epoch 27/1000
# 94/94 - 1s - loss: 0.7547 - accuracy: 0.7078 - val_loss: 0.6329 - val_accuracy: 0.7489
#
# Epoch 00027: val_loss improved from 0.65470 to 0.63290, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0027 ----  0.6329.hdf5
# Epoch 28/1000
# 94/94 - 1s - loss: 0.7341 - accuracy: 0.7147 - val_loss: 0.6135 - val_accuracy: 0.7600
#
# Epoch 00028: val_loss improved from 0.63290 to 0.61349, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0028 ----  0.6135.hdf5
# Epoch 29/1000
# 94/94 - 1s - loss: 0.7159 - accuracy: 0.7201 - val_loss: 0.5952 - val_accuracy: 0.7693
#
# Epoch 00029: val_loss improved from 0.61349 to 0.59522, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0029 ----  0.5952.hdf5
# Epoch 30/1000
# 94/94 - 1s - loss: 0.6992 - accuracy: 0.7256 - val_loss: 0.5812 - val_accuracy: 0.7722
#
# Epoch 00030: val_loss improved from 0.59522 to 0.58117, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0030 ----  0.5812.hdf5
# Epoch 31/1000
# 94/94 - 1s - loss: 0.6815 - accuracy: 0.7278 - val_loss: 0.5680 - val_accuracy: 0.7748
#
# Epoch 00031: val_loss improved from 0.58117 to 0.56802, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0031 ----  0.5680.hdf5
# Epoch 32/1000
# 94/94 - 1s - loss: 0.6690 - accuracy: 0.7322 - val_loss: 0.5568 - val_accuracy: 0.7790
#
# Epoch 00032: val_loss improved from 0.56802 to 0.55676, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0032 ----  0.5568.hdf5
# Epoch 33/1000
# 94/94 - 1s - loss: 0.6588 - accuracy: 0.7337 - val_loss: 0.5466 - val_accuracy: 0.7811
#
# Epoch 00033: val_loss improved from 0.55676 to 0.54655, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0033 ----  0.5466.hdf5
# Epoch 34/1000
# 94/94 - 1s - loss: 0.6481 - accuracy: 0.7383 - val_loss: 0.5381 - val_accuracy: 0.7819
#
# Epoch 00034: val_loss improved from 0.54655 to 0.53808, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0034 ----  0.5381.hdf5
# Epoch 35/1000
# 94/94 - 1s - loss: 0.6397 - accuracy: 0.7373 - val_loss: 0.5331 - val_accuracy: 0.7824
#
# Epoch 00035: val_loss improved from 0.53808 to 0.53309, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0035 ----  0.5331.hdf5
# Epoch 36/1000
# 94/94 - 1s - loss: 0.6335 - accuracy: 0.7431 - val_loss: 0.5277 - val_accuracy: 0.7816
#
# Epoch 00036: val_loss improved from 0.53309 to 0.52768, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0036 ----  0.5277.hdf5
# Epoch 37/1000
# 94/94 - 1s - loss: 0.6253 - accuracy: 0.7419 - val_loss: 0.5222 - val_accuracy: 0.7835
#
# Epoch 00037: val_loss improved from 0.52768 to 0.52222, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0037 ----  0.5222.hdf5
# Epoch 38/1000
# 94/94 - 1s - loss: 0.6176 - accuracy: 0.7444 - val_loss: 0.5189 - val_accuracy: 0.7834
#
# Epoch 00038: val_loss improved from 0.52222 to 0.51891, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0038 ----  0.5189.hdf5
# Epoch 39/1000
# 94/94 - 1s - loss: 0.6145 - accuracy: 0.7440 - val_loss: 0.5146 - val_accuracy: 0.7839
#
# Epoch 00039: val_loss improved from 0.51891 to 0.51464, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0039 ----  0.5146.hdf5
# Epoch 40/1000
# 94/94 - 1s - loss: 0.6104 - accuracy: 0.7435 - val_loss: 0.5104 - val_accuracy: 0.7840
#
# Epoch 00040: val_loss improved from 0.51464 to 0.51036, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0040 ----  0.5104.hdf5
# Epoch 41/1000
# 94/94 - 1s - loss: 0.6034 - accuracy: 0.7468 - val_loss: 0.5076 - val_accuracy: 0.7830
#
# Epoch 00041: val_loss improved from 0.51036 to 0.50756, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0041 ----  0.5076.hdf5
# Epoch 42/1000
# 94/94 - 1s - loss: 0.5997 - accuracy: 0.7471 - val_loss: 0.5052 - val_accuracy: 0.7839
#
# Epoch 00042: val_loss improved from 0.50756 to 0.50522, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0042 ----  0.5052.hdf5
# Epoch 43/1000
# 94/94 - 1s - loss: 0.5980 - accuracy: 0.7468 - val_loss: 0.5020 - val_accuracy: 0.7854
#
# Epoch 00043: val_loss improved from 0.50522 to 0.50197, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0043 ----  0.5020.hdf5
# Epoch 44/1000
# 94/94 - 1s - loss: 0.5928 - accuracy: 0.7484 - val_loss: 0.5001 - val_accuracy: 0.7848
#
# Epoch 00044: val_loss improved from 0.50197 to 0.50007, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0044 ----  0.5001.hdf5
# Epoch 45/1000
# 94/94 - 1s - loss: 0.5882 - accuracy: 0.7500 - val_loss: 0.4977 - val_accuracy: 0.7851
#
# Epoch 00045: val_loss improved from 0.50007 to 0.49767, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0045 ----  0.4977.hdf5
# Epoch 46/1000
# 94/94 - 1s - loss: 0.5840 - accuracy: 0.7496 - val_loss: 0.4942 - val_accuracy: 0.7863
#
# Epoch 00046: val_loss improved from 0.49767 to 0.49425, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0046 ----  0.4942.hdf5
# Epoch 47/1000
# 94/94 - 1s - loss: 0.5806 - accuracy: 0.7509 - val_loss: 0.4939 - val_accuracy: 0.7860
#
# Epoch 00047: val_loss improved from 0.49425 to 0.49386, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0047 ----  0.4939.hdf5
# Epoch 48/1000
# 94/94 - 1s - loss: 0.5771 - accuracy: 0.7527 - val_loss: 0.4923 - val_accuracy: 0.7854
#
# Epoch 00048: val_loss improved from 0.49386 to 0.49228, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0048 ----  0.4923.hdf5
# Epoch 49/1000
# 94/94 - 1s - loss: 0.5766 - accuracy: 0.7524 - val_loss: 0.4896 - val_accuracy: 0.7860
#
# Epoch 00049: val_loss improved from 0.49228 to 0.48961, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0049 ----  0.4896.hdf5
# Epoch 50/1000
# 94/94 - 1s - loss: 0.5728 - accuracy: 0.7531 - val_loss: 0.4883 - val_accuracy: 0.7853
#
# Epoch 00050: val_loss improved from 0.48961 to 0.48835, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0050 ----  0.4883.hdf5
# Epoch 51/1000
# 94/94 - 1s - loss: 0.5701 - accuracy: 0.7527 - val_loss: 0.4883 - val_accuracy: 0.7853
#
# Epoch 00051: val_loss improved from 0.48835 to 0.48831, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0051 ----  0.4883.hdf5
# Epoch 52/1000
# 94/94 - 1s - loss: 0.5661 - accuracy: 0.7553 - val_loss: 0.4842 - val_accuracy: 0.7863
#
# Epoch 00052: val_loss improved from 0.48831 to 0.48424, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0052 ----  0.4842.hdf5
# Epoch 53/1000
# 94/94 - 1s - loss: 0.5631 - accuracy: 0.7565 - val_loss: 0.4846 - val_accuracy: 0.7854
#
# Epoch 00053: val_loss did not improve from 0.48424
# Epoch 54/1000
# 94/94 - 1s - loss: 0.5620 - accuracy: 0.7552 - val_loss: 0.4830 - val_accuracy: 0.7859
#
# Epoch 00054: val_loss improved from 0.48424 to 0.48300, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0054 ----  0.4830.hdf5
# Epoch 55/1000
# 94/94 - 1s - loss: 0.5610 - accuracy: 0.7559 - val_loss: 0.4820 - val_accuracy: 0.7851
#
# Epoch 00055: val_loss improved from 0.48300 to 0.48198, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0055 ----  0.4820.hdf5
# Epoch 56/1000
# 94/94 - 1s - loss: 0.5592 - accuracy: 0.7549 - val_loss: 0.4799 - val_accuracy: 0.7865
#
# Epoch 00056: val_loss improved from 0.48198 to 0.47994, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0056 ----  0.4799.hdf5
# Epoch 57/1000
# 94/94 - 1s - loss: 0.5568 - accuracy: 0.7556 - val_loss: 0.4803 - val_accuracy: 0.7858
#
# Epoch 00057: val_loss did not improve from 0.47994
# Epoch 58/1000
# 94/94 - 1s - loss: 0.5542 - accuracy: 0.7572 - val_loss: 0.4781 - val_accuracy: 0.7859
#
# Epoch 00058: val_loss improved from 0.47994 to 0.47814, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0058 ----  0.4781.hdf5
# Epoch 59/1000
# 94/94 - 1s - loss: 0.5527 - accuracy: 0.7553 - val_loss: 0.4773 - val_accuracy: 0.7860
#
# Epoch 00059: val_loss improved from 0.47814 to 0.47729, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0059 ----  0.4773.hdf5
# Epoch 60/1000
# 94/94 - 1s - loss: 0.5504 - accuracy: 0.7582 - val_loss: 0.4753 - val_accuracy: 0.7867
#
# Epoch 00060: val_loss improved from 0.47729 to 0.47526, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0060 ----  0.4753.hdf5
# Epoch 61/1000
# 94/94 - 1s - loss: 0.5490 - accuracy: 0.7574 - val_loss: 0.4753 - val_accuracy: 0.7870
#
# Epoch 00061: val_loss did not improve from 0.47526
# Epoch 62/1000
# 94/94 - 1s - loss: 0.5454 - accuracy: 0.7595 - val_loss: 0.4726 - val_accuracy: 0.7875
#
# Epoch 00062: val_loss improved from 0.47526 to 0.47261, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0062 ----  0.4726.hdf5
# Epoch 63/1000
# 94/94 - 1s - loss: 0.5443 - accuracy: 0.7597 - val_loss: 0.4730 - val_accuracy: 0.7857
#
# Epoch 00063: val_loss did not improve from 0.47261
# Epoch 64/1000
# 94/94 - 1s - loss: 0.5412 - accuracy: 0.7591 - val_loss: 0.4724 - val_accuracy: 0.7854
#
# Epoch 00064: val_loss improved from 0.47261 to 0.47242, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0064 ----  0.4724.hdf5
# Epoch 65/1000
# 94/94 - 1s - loss: 0.5389 - accuracy: 0.7612 - val_loss: 0.4685 - val_accuracy: 0.7879
#
# Epoch 00065: val_loss improved from 0.47242 to 0.46853, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0065 ----  0.4685.hdf5
# Epoch 66/1000
# 94/94 - 1s - loss: 0.5406 - accuracy: 0.7611 - val_loss: 0.4692 - val_accuracy: 0.7863
#
# Epoch 00066: val_loss did not improve from 0.46853
# Epoch 67/1000
# 94/94 - 1s - loss: 0.5363 - accuracy: 0.7624 - val_loss: 0.4676 - val_accuracy: 0.7864
#
# Epoch 00067: val_loss improved from 0.46853 to 0.46757, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0067 ----  0.4676.hdf5
# Epoch 68/1000
# 94/94 - 1s - loss: 0.5349 - accuracy: 0.7633 - val_loss: 0.4690 - val_accuracy: 0.7862
#
# Epoch 00068: val_loss did not improve from 0.46757
# Epoch 69/1000
# 94/94 - 1s - loss: 0.5340 - accuracy: 0.7609 - val_loss: 0.4665 - val_accuracy: 0.7857
#
# Epoch 00069: val_loss improved from 0.46757 to 0.46650, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0069 ----  0.4665.hdf5
# Epoch 70/1000
# 94/94 - 1s - loss: 0.5324 - accuracy: 0.7638 - val_loss: 0.4654 - val_accuracy: 0.7892
#
# Epoch 00070: val_loss improved from 0.46650 to 0.46542, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0070 ----  0.4654.hdf5
# Epoch 71/1000
# 94/94 - 1s - loss: 0.5315 - accuracy: 0.7623 - val_loss: 0.4645 - val_accuracy: 0.7892
#
# Epoch 00071: val_loss improved from 0.46542 to 0.46451, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0071 ----  0.4645.hdf5
# Epoch 72/1000
# 94/94 - 1s - loss: 0.5285 - accuracy: 0.7649 - val_loss: 0.4624 - val_accuracy: 0.7919
#
# Epoch 00072: val_loss improved from 0.46451 to 0.46241, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0072 ----  0.4624.hdf5
# Epoch 73/1000
# 94/94 - 1s - loss: 0.5263 - accuracy: 0.7661 - val_loss: 0.4629 - val_accuracy: 0.7926
#
# Epoch 00073: val_loss did not improve from 0.46241
# Epoch 74/1000
# 94/94 - 1s - loss: 0.5244 - accuracy: 0.7647 - val_loss: 0.4610 - val_accuracy: 0.7938
#
# Epoch 00074: val_loss improved from 0.46241 to 0.46103, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0074 ----  0.4610.hdf5
# Epoch 75/1000
# 94/94 - 1s - loss: 0.5241 - accuracy: 0.7661 - val_loss: 0.4623 - val_accuracy: 0.7923
#
# Epoch 00075: val_loss did not improve from 0.46103
# Epoch 76/1000
# 94/94 - 1s - loss: 0.5236 - accuracy: 0.7662 - val_loss: 0.4623 - val_accuracy: 0.7935
#
# Epoch 00076: val_loss did not improve from 0.46103
# Epoch 77/1000
# 94/94 - 1s - loss: 0.5200 - accuracy: 0.7697 - val_loss: 0.4604 - val_accuracy: 0.7975
#
# Epoch 00077: val_loss improved from 0.46103 to 0.46041, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0077 ----  0.4604.hdf5
# Epoch 78/1000
# 94/94 - 1s - loss: 0.5196 - accuracy: 0.7670 - val_loss: 0.4597 - val_accuracy: 0.7950
#
# Epoch 00078: val_loss improved from 0.46041 to 0.45966, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0078 ----  0.4597.hdf5
# Epoch 79/1000
# 94/94 - 1s - loss: 0.5175 - accuracy: 0.7693 - val_loss: 0.4570 - val_accuracy: 0.7999
#
# Epoch 00079: val_loss improved from 0.45966 to 0.45696, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0079 ----  0.4570.hdf5
# Epoch 80/1000
# 94/94 - 1s - loss: 0.5172 - accuracy: 0.7698 - val_loss: 0.4566 - val_accuracy: 0.8022
#
# Epoch 00080: val_loss improved from 0.45696 to 0.45662, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0080 ----  0.4566.hdf5
# Epoch 81/1000
# 94/94 - 1s - loss: 0.5164 - accuracy: 0.7682 - val_loss: 0.4578 - val_accuracy: 0.7993
#
# Epoch 00081: val_loss did not improve from 0.45662
# Epoch 82/1000
# 94/94 - 1s - loss: 0.5136 - accuracy: 0.7709 - val_loss: 0.4565 - val_accuracy: 0.8004
#
# Epoch 00082: val_loss improved from 0.45662 to 0.45646, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0082 ----  0.4565.hdf5
# Epoch 83/1000
# 94/94 - 1s - loss: 0.5129 - accuracy: 0.7725 - val_loss: 0.4548 - val_accuracy: 0.8073
#
# Epoch 00083: val_loss improved from 0.45646 to 0.45484, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0083 ----  0.4548.hdf5
# Epoch 84/1000
# 94/94 - 1s - loss: 0.5116 - accuracy: 0.7719 - val_loss: 0.4532 - val_accuracy: 0.8068
#
# Epoch 00084: val_loss improved from 0.45484 to 0.45318, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0084 ----  0.4532.hdf5
# Epoch 85/1000
# 94/94 - 1s - loss: 0.5098 - accuracy: 0.7731 - val_loss: 0.4538 - val_accuracy: 0.8060
#
# Epoch 00085: val_loss did not improve from 0.45318
# Epoch 86/1000
# 94/94 - 1s - loss: 0.5092 - accuracy: 0.7732 - val_loss: 0.4517 - val_accuracy: 0.8109
#
# Epoch 00086: val_loss improved from 0.45318 to 0.45175, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0086 ----  0.4517.hdf5
# Epoch 87/1000
# 94/94 - 1s - loss: 0.5066 - accuracy: 0.7741 - val_loss: 0.4518 - val_accuracy: 0.8047
#
# Epoch 00087: val_loss did not improve from 0.45175
# Epoch 88/1000
# 94/94 - 1s - loss: 0.5075 - accuracy: 0.7743 - val_loss: 0.4504 - val_accuracy: 0.8087
#
# Epoch 00088: val_loss improved from 0.45175 to 0.45040, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0088 ----  0.4504.hdf5
# Epoch 89/1000
# 94/94 - 1s - loss: 0.5064 - accuracy: 0.7761 - val_loss: 0.4511 - val_accuracy: 0.8065
#
# Epoch 00089: val_loss did not improve from 0.45040
# Epoch 90/1000
# 94/94 - 1s - loss: 0.5029 - accuracy: 0.7781 - val_loss: 0.4494 - val_accuracy: 0.8089
#
# Epoch 00090: val_loss improved from 0.45040 to 0.44942, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0090 ----  0.4494.hdf5
# Epoch 91/1000
# 94/94 - 1s - loss: 0.5030 - accuracy: 0.7780 - val_loss: 0.4480 - val_accuracy: 0.8116
#
# Epoch 00091: val_loss improved from 0.44942 to 0.44803, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0091 ----  0.4480.hdf5
# Epoch 92/1000
# 94/94 - 1s - loss: 0.5025 - accuracy: 0.7778 - val_loss: 0.4495 - val_accuracy: 0.8097
#
# Epoch 00092: val_loss did not improve from 0.44803
# Epoch 93/1000
# 94/94 - 1s - loss: 0.4994 - accuracy: 0.7785 - val_loss: 0.4460 - val_accuracy: 0.8087
#
# Epoch 00093: val_loss improved from 0.44803 to 0.44604, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0093 ----  0.4460.hdf5
# Epoch 94/1000
# 94/94 - 1s - loss: 0.4997 - accuracy: 0.7811 - val_loss: 0.4469 - val_accuracy: 0.8085
#
# Epoch 00094: val_loss did not improve from 0.44604
# Epoch 95/1000
# 94/94 - 1s - loss: 0.4971 - accuracy: 0.7825 - val_loss: 0.4443 - val_accuracy: 0.8106
#
# Epoch 00095: val_loss improved from 0.44604 to 0.44429, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0095 ----  0.4443.hdf5
# Epoch 96/1000
# 94/94 - 1s - loss: 0.4984 - accuracy: 0.7815 - val_loss: 0.4433 - val_accuracy: 0.8130
#
# Epoch 00096: val_loss improved from 0.44429 to 0.44327, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0096 ----  0.4433.hdf5
# Epoch 97/1000
# 94/94 - 1s - loss: 0.4972 - accuracy: 0.7819 - val_loss: 0.4440 - val_accuracy: 0.8109
#
# Epoch 00097: val_loss did not improve from 0.44327
# Epoch 98/1000
# 94/94 - 1s - loss: 0.4937 - accuracy: 0.7839 - val_loss: 0.4436 - val_accuracy: 0.8114
#
# Epoch 00098: val_loss did not improve from 0.44327
# Epoch 99/1000
# 94/94 - 1s - loss: 0.4932 - accuracy: 0.7820 - val_loss: 0.4424 - val_accuracy: 0.8103
#
# Epoch 00099: val_loss improved from 0.44327 to 0.44243, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0099 ----  0.4424.hdf5
# Epoch 100/1000
# 94/94 - 1s - loss: 0.4920 - accuracy: 0.7828 - val_loss: 0.4422 - val_accuracy: 0.8099
#
# Epoch 00100: val_loss improved from 0.44243 to 0.44222, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0100 ----  0.4422.hdf5
# Epoch 101/1000
# 94/94 - 1s - loss: 0.4913 - accuracy: 0.7846 - val_loss: 0.4393 - val_accuracy: 0.8146
#
# Epoch 00101: val_loss improved from 0.44222 to 0.43934, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0101 ----  0.4393.hdf5
# Epoch 102/1000
# 94/94 - 1s - loss: 0.4900 - accuracy: 0.7872 - val_loss: 0.4404 - val_accuracy: 0.8107
#
# Epoch 00102: val_loss did not improve from 0.43934
# Epoch 103/1000
# 94/94 - 1s - loss: 0.4913 - accuracy: 0.7856 - val_loss: 0.4398 - val_accuracy: 0.8106
#
# Epoch 00103: val_loss did not improve from 0.43934
# Epoch 104/1000
# 94/94 - 1s - loss: 0.4868 - accuracy: 0.7866 - val_loss: 0.4397 - val_accuracy: 0.8125
#
# Epoch 00104: val_loss did not improve from 0.43934
# Epoch 105/1000
# 94/94 - 1s - loss: 0.4880 - accuracy: 0.7893 - val_loss: 0.4373 - val_accuracy: 0.8135
#
# Epoch 00105: val_loss improved from 0.43934 to 0.43733, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0105 ----  0.4373.hdf5
# Epoch 106/1000
# 94/94 - 1s - loss: 0.4860 - accuracy: 0.7865 - val_loss: 0.4376 - val_accuracy: 0.8137
#
# Epoch 00106: val_loss did not improve from 0.43733
# Epoch 107/1000
# 94/94 - 1s - loss: 0.4843 - accuracy: 0.7876 - val_loss: 0.4367 - val_accuracy: 0.8136
#
# Epoch 00107: val_loss improved from 0.43733 to 0.43673, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0107 ----  0.4367.hdf5
# Epoch 108/1000
# 94/94 - 1s - loss: 0.4840 - accuracy: 0.7882 - val_loss: 0.4355 - val_accuracy: 0.8132
#
# Epoch 00108: val_loss improved from 0.43673 to 0.43555, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0108 ----  0.4355.hdf5
# Epoch 109/1000
# 94/94 - 1s - loss: 0.4822 - accuracy: 0.7891 - val_loss: 0.4353 - val_accuracy: 0.8150
#
# Epoch 00109: val_loss improved from 0.43555 to 0.43526, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0109 ----  0.4353.hdf5
# Epoch 110/1000
# 94/94 - 1s - loss: 0.4827 - accuracy: 0.7887 - val_loss: 0.4354 - val_accuracy: 0.8153
#
# Epoch 00110: val_loss did not improve from 0.43526
# Epoch 111/1000
# 94/94 - 1s - loss: 0.4812 - accuracy: 0.7897 - val_loss: 0.4339 - val_accuracy: 0.8137
#
# Epoch 00111: val_loss improved from 0.43526 to 0.43391, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0111 ----  0.4339.hdf5
# Epoch 112/1000
# 94/94 - 1s - loss: 0.4777 - accuracy: 0.7925 - val_loss: 0.4326 - val_accuracy: 0.8158
#
# Epoch 00112: val_loss improved from 0.43391 to 0.43263, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0112 ----  0.4326.hdf5
# Epoch 113/1000
# 94/94 - 1s - loss: 0.4795 - accuracy: 0.7915 - val_loss: 0.4341 - val_accuracy: 0.8128
#
# Epoch 00113: val_loss did not improve from 0.43263
# Epoch 114/1000
# 94/94 - 1s - loss: 0.4764 - accuracy: 0.7932 - val_loss: 0.4322 - val_accuracy: 0.8142
#
# Epoch 00114: val_loss improved from 0.43263 to 0.43217, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0114 ----  0.4322.hdf5
# Epoch 115/1000
# 94/94 - 1s - loss: 0.4768 - accuracy: 0.7924 - val_loss: 0.4317 - val_accuracy: 0.8130
#
# Epoch 00115: val_loss improved from 0.43217 to 0.43169, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0115 ----  0.4317.hdf5
# Epoch 116/1000
# 94/94 - 1s - loss: 0.4786 - accuracy: 0.7906 - val_loss: 0.4303 - val_accuracy: 0.8144
#
# Epoch 00116: val_loss improved from 0.43169 to 0.43029, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0116 ----  0.4303.hdf5
# Epoch 117/1000
# 94/94 - 1s - loss: 0.4734 - accuracy: 0.7953 - val_loss: 0.4302 - val_accuracy: 0.8185
#
# Epoch 00117: val_loss improved from 0.43029 to 0.43025, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0117 ----  0.4302.hdf5
# Epoch 118/1000
# 94/94 - 1s - loss: 0.4720 - accuracy: 0.7947 - val_loss: 0.4297 - val_accuracy: 0.8142
#
# Epoch 00118: val_loss improved from 0.43025 to 0.42974, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0118 ----  0.4297.hdf5
# Epoch 119/1000
# 94/94 - 1s - loss: 0.4728 - accuracy: 0.7937 - val_loss: 0.4283 - val_accuracy: 0.8152
#
# Epoch 00119: val_loss improved from 0.42974 to 0.42828, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0119 ----  0.4283.hdf5
# Epoch 120/1000
# 94/94 - 1s - loss: 0.4738 - accuracy: 0.7930 - val_loss: 0.4265 - val_accuracy: 0.8194
#
# Epoch 00120: val_loss improved from 0.42828 to 0.42648, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0120 ----  0.4265.hdf5
# Epoch 121/1000
# 94/94 - 1s - loss: 0.4704 - accuracy: 0.7956 - val_loss: 0.4275 - val_accuracy: 0.8155
#
# Epoch 00121: val_loss did not improve from 0.42648
# Epoch 122/1000
# 94/94 - 1s - loss: 0.4697 - accuracy: 0.7948 - val_loss: 0.4276 - val_accuracy: 0.8158
#
# Epoch 00122: val_loss did not improve from 0.42648
# Epoch 123/1000
# 94/94 - 1s - loss: 0.4689 - accuracy: 0.7947 - val_loss: 0.4253 - val_accuracy: 0.8171
#
# Epoch 00123: val_loss improved from 0.42648 to 0.42526, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0123 ----  0.4253.hdf5
# Epoch 124/1000
# 94/94 - 1s - loss: 0.4681 - accuracy: 0.7949 - val_loss: 0.4252 - val_accuracy: 0.8224
#
# Epoch 00124: val_loss improved from 0.42526 to 0.42522, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0124 ----  0.4252.hdf5
# Epoch 125/1000
# 94/94 - 1s - loss: 0.4654 - accuracy: 0.7988 - val_loss: 0.4233 - val_accuracy: 0.8172
#
# Epoch 00125: val_loss improved from 0.42522 to 0.42327, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0125 ----  0.4233.hdf5
# Epoch 126/1000
# 94/94 - 1s - loss: 0.4678 - accuracy: 0.7976 - val_loss: 0.4244 - val_accuracy: 0.8145
#
# Epoch 00126: val_loss did not improve from 0.42327
# Epoch 127/1000
# 94/94 - 1s - loss: 0.4671 - accuracy: 0.7977 - val_loss: 0.4235 - val_accuracy: 0.8165
#
# Epoch 00127: val_loss did not improve from 0.42327
# Epoch 128/1000
# 94/94 - 1s - loss: 0.4637 - accuracy: 0.7977 - val_loss: 0.4229 - val_accuracy: 0.8166
#
# Epoch 00128: val_loss improved from 0.42327 to 0.42293, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0128 ----  0.4229.hdf5
# Epoch 129/1000
# 94/94 - 1s - loss: 0.4646 - accuracy: 0.7959 - val_loss: 0.4230 - val_accuracy: 0.8187
#
# Epoch 00129: val_loss did not improve from 0.42293
# Epoch 130/1000
# 94/94 - 1s - loss: 0.4621 - accuracy: 0.7973 - val_loss: 0.4212 - val_accuracy: 0.8173
#
# Epoch 00130: val_loss improved from 0.42293 to 0.42119, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0130 ----  0.4212.hdf5
# Epoch 131/1000
# 94/94 - 1s - loss: 0.4605 - accuracy: 0.8004 - val_loss: 0.4206 - val_accuracy: 0.8183
#
# Epoch 00131: val_loss improved from 0.42119 to 0.42063, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0131 ----  0.4206.hdf5
# Epoch 132/1000
# 94/94 - 1s - loss: 0.4593 - accuracy: 0.8019 - val_loss: 0.4204 - val_accuracy: 0.8172
#
# Epoch 00132: val_loss improved from 0.42063 to 0.42035, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0132 ----  0.4204.hdf5
# Epoch 133/1000
# 94/94 - 1s - loss: 0.4604 - accuracy: 0.7986 - val_loss: 0.4191 - val_accuracy: 0.8197
#
# Epoch 00133: val_loss improved from 0.42035 to 0.41913, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0133 ----  0.4191.hdf5
# Epoch 134/1000
# 94/94 - 1s - loss: 0.4571 - accuracy: 0.8008 - val_loss: 0.4195 - val_accuracy: 0.8171
#
# Epoch 00134: val_loss did not improve from 0.41913
# Epoch 135/1000
# 94/94 - 1s - loss: 0.4576 - accuracy: 0.7998 - val_loss: 0.4180 - val_accuracy: 0.8197
#
# Epoch 00135: val_loss improved from 0.41913 to 0.41803, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0135 ----  0.4180.hdf5
# Epoch 136/1000
# 94/94 - 1s - loss: 0.4566 - accuracy: 0.7996 - val_loss: 0.4163 - val_accuracy: 0.8186
#
# Epoch 00136: val_loss improved from 0.41803 to 0.41633, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0136 ----  0.4163.hdf5
# Epoch 137/1000
# 94/94 - 1s - loss: 0.4594 - accuracy: 0.7995 - val_loss: 0.4171 - val_accuracy: 0.8194
#
# Epoch 00137: val_loss did not improve from 0.41633
# Epoch 138/1000
# 94/94 - 1s - loss: 0.4550 - accuracy: 0.8002 - val_loss: 0.4156 - val_accuracy: 0.8194
#
# Epoch 00138: val_loss improved from 0.41633 to 0.41562, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0138 ----  0.4156.hdf5
# Epoch 139/1000
# 94/94 - 1s - loss: 0.4558 - accuracy: 0.7994 - val_loss: 0.4156 - val_accuracy: 0.8199
#
# Epoch 00139: val_loss improved from 0.41562 to 0.41562, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0139 ----  0.4156.hdf5
# Epoch 140/1000
# 94/94 - 1s - loss: 0.4533 - accuracy: 0.8026 - val_loss: 0.4150 - val_accuracy: 0.8207
#
# Epoch 00140: val_loss improved from 0.41562 to 0.41499, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0140 ----  0.4150.hdf5
# Epoch 141/1000
# 94/94 - 1s - loss: 0.4536 - accuracy: 0.8023 - val_loss: 0.4147 - val_accuracy: 0.8209
#
# Epoch 00141: val_loss improved from 0.41499 to 0.41468, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0141 ----  0.4147.hdf5
# Epoch 142/1000
# 94/94 - 1s - loss: 0.4509 - accuracy: 0.8025 - val_loss: 0.4135 - val_accuracy: 0.8207
#
# Epoch 00142: val_loss improved from 0.41468 to 0.41348, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0142 ----  0.4135.hdf5
# Epoch 143/1000
# 94/94 - 1s - loss: 0.4530 - accuracy: 0.8024 - val_loss: 0.4143 - val_accuracy: 0.8189
#
# Epoch 00143: val_loss did not improve from 0.41348
# Epoch 144/1000
# 94/94 - 1s - loss: 0.4509 - accuracy: 0.8032 - val_loss: 0.4124 - val_accuracy: 0.8197
#
# Epoch 00144: val_loss improved from 0.41348 to 0.41243, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0144 ----  0.4124.hdf5
# Epoch 145/1000
# 94/94 - 1s - loss: 0.4511 - accuracy: 0.8039 - val_loss: 0.4121 - val_accuracy: 0.8223
#
# Epoch 00145: val_loss improved from 0.41243 to 0.41212, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0145 ----  0.4121.hdf5
# Epoch 146/1000
# 94/94 - 1s - loss: 0.4486 - accuracy: 0.8046 - val_loss: 0.4132 - val_accuracy: 0.8155
#
# Epoch 00146: val_loss did not improve from 0.41212
# Epoch 147/1000
# 94/94 - 1s - loss: 0.4477 - accuracy: 0.8036 - val_loss: 0.4094 - val_accuracy: 0.8253
#
# Epoch 00147: val_loss improved from 0.41212 to 0.40944, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0147 ----  0.4094.hdf5
# Epoch 148/1000
# 94/94 - 1s - loss: 0.4482 - accuracy: 0.8026 - val_loss: 0.4107 - val_accuracy: 0.8190
#
# Epoch 00148: val_loss did not improve from 0.40944
# Epoch 149/1000
# 94/94 - 1s - loss: 0.4441 - accuracy: 0.8063 - val_loss: 0.4121 - val_accuracy: 0.8135
#
# Epoch 00149: val_loss did not improve from 0.40944
# Epoch 150/1000
# 94/94 - 1s - loss: 0.4460 - accuracy: 0.8062 - val_loss: 0.4099 - val_accuracy: 0.8173
#
# Epoch 00150: val_loss did not improve from 0.40944
# Epoch 151/1000
# 94/94 - 1s - loss: 0.4458 - accuracy: 0.8042 - val_loss: 0.4081 - val_accuracy: 0.8210
#
# Epoch 00151: val_loss improved from 0.40944 to 0.40814, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0151 ----  0.4081.hdf5
# Epoch 152/1000
# 94/94 - 1s - loss: 0.4431 - accuracy: 0.8055 - val_loss: 0.4085 - val_accuracy: 0.8211
#
# Epoch 00152: val_loss did not improve from 0.40814
# Epoch 153/1000
# 94/94 - 1s - loss: 0.4449 - accuracy: 0.8031 - val_loss: 0.4067 - val_accuracy: 0.8237
#
# Epoch 00153: val_loss improved from 0.40814 to 0.40666, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0153 ----  0.4067.hdf5
# Epoch 154/1000
# 94/94 - 1s - loss: 0.4420 - accuracy: 0.8092 - val_loss: 0.4053 - val_accuracy: 0.8230
#
# Epoch 00154: val_loss improved from 0.40666 to 0.40530, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0154 ----  0.4053.hdf5
# Epoch 155/1000
# 94/94 - 1s - loss: 0.4410 - accuracy: 0.8058 - val_loss: 0.4088 - val_accuracy: 0.8189
#
# Epoch 00155: val_loss did not improve from 0.40530
# Epoch 156/1000
# 94/94 - 1s - loss: 0.4397 - accuracy: 0.8076 - val_loss: 0.4073 - val_accuracy: 0.8184
#
# Epoch 00156: val_loss did not improve from 0.40530
# Epoch 157/1000
# 94/94 - 1s - loss: 0.4394 - accuracy: 0.8062 - val_loss: 0.4065 - val_accuracy: 0.8184
#
# Epoch 00157: val_loss did not improve from 0.40530
# Epoch 158/1000
# 94/94 - 1s - loss: 0.4412 - accuracy: 0.8077 - val_loss: 0.4072 - val_accuracy: 0.8207
#
# Epoch 00158: val_loss did not improve from 0.40530
# Epoch 159/1000
# 94/94 - 1s - loss: 0.4406 - accuracy: 0.8070 - val_loss: 0.4044 - val_accuracy: 0.8181
#
# Epoch 00159: val_loss improved from 0.40530 to 0.40437, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0159 ----  0.4044.hdf5
# Epoch 160/1000
# 94/94 - 1s - loss: 0.4393 - accuracy: 0.8073 - val_loss: 0.4032 - val_accuracy: 0.8232
#
# Epoch 00160: val_loss improved from 0.40437 to 0.40319, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0160 ----  0.4032.hdf5
# Epoch 161/1000
# 94/94 - 1s - loss: 0.4349 - accuracy: 0.8107 - val_loss: 0.4036 - val_accuracy: 0.8247
#
# Epoch 00161: val_loss did not improve from 0.40319
# Epoch 162/1000
# 94/94 - 1s - loss: 0.4375 - accuracy: 0.8066 - val_loss: 0.4033 - val_accuracy: 0.8235
#
# Epoch 00162: val_loss did not improve from 0.40319
# Epoch 163/1000
# 94/94 - 1s - loss: 0.4355 - accuracy: 0.8091 - val_loss: 0.4028 - val_accuracy: 0.8225
#
# Epoch 00163: val_loss improved from 0.40319 to 0.40277, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0163 ----  0.4028.hdf5
# Epoch 164/1000
# 94/94 - 1s - loss: 0.4340 - accuracy: 0.8083 - val_loss: 0.4026 - val_accuracy: 0.8152
#
# Epoch 00164: val_loss improved from 0.40277 to 0.40260, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0164 ----  0.4026.hdf5
# Epoch 165/1000
# 94/94 - 1s - loss: 0.4346 - accuracy: 0.8078 - val_loss: 0.4025 - val_accuracy: 0.8190
#
# Epoch 00165: val_loss improved from 0.40260 to 0.40254, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0165 ----  0.4025.hdf5
# Epoch 166/1000
# 94/94 - 1s - loss: 0.4344 - accuracy: 0.8096 - val_loss: 0.4031 - val_accuracy: 0.8231
#
# Epoch 00166: val_loss did not improve from 0.40254
# Epoch 167/1000
# 94/94 - 1s - loss: 0.4341 - accuracy: 0.8083 - val_loss: 0.4018 - val_accuracy: 0.8215
#
# Epoch 00167: val_loss improved from 0.40254 to 0.40185, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0167 ----  0.4018.hdf5
# Epoch 168/1000
# 94/94 - 1s - loss: 0.4305 - accuracy: 0.8109 - val_loss: 0.4001 - val_accuracy: 0.8270
#
# Epoch 00168: val_loss improved from 0.40185 to 0.40009, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0168 ----  0.4001.hdf5
# Epoch 169/1000
# 94/94 - 1s - loss: 0.4324 - accuracy: 0.8096 - val_loss: 0.4000 - val_accuracy: 0.8211
#
# Epoch 00169: val_loss improved from 0.40009 to 0.39998, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0169 ----  0.4000.hdf5
# Epoch 170/1000
# 94/94 - 1s - loss: 0.4321 - accuracy: 0.8090 - val_loss: 0.4020 - val_accuracy: 0.8208
#
# Epoch 00170: val_loss did not improve from 0.39998
# Epoch 171/1000
# 94/94 - 1s - loss: 0.4300 - accuracy: 0.8117 - val_loss: 0.4024 - val_accuracy: 0.8162
#
# Epoch 00171: val_loss did not improve from 0.39998
# Epoch 172/1000
# 94/94 - 1s - loss: 0.4316 - accuracy: 0.8087 - val_loss: 0.4001 - val_accuracy: 0.8212
#
# Epoch 00172: val_loss did not improve from 0.39998
# Epoch 173/1000
# 94/94 - 1s - loss: 0.4278 - accuracy: 0.8125 - val_loss: 0.3997 - val_accuracy: 0.8202
#
# Epoch 00173: val_loss improved from 0.39998 to 0.39969, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0173 ----  0.3997.hdf5
# Epoch 174/1000
# 94/94 - 1s - loss: 0.4299 - accuracy: 0.8118 - val_loss: 0.4010 - val_accuracy: 0.8219
#
# Epoch 00174: val_loss did not improve from 0.39969
# Epoch 175/1000
# 94/94 - 1s - loss: 0.4281 - accuracy: 0.8099 - val_loss: 0.3976 - val_accuracy: 0.8225
#
# Epoch 00175: val_loss improved from 0.39969 to 0.39763, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0175 ----  0.3976.hdf5
# Epoch 176/1000
# 94/94 - 1s - loss: 0.4287 - accuracy: 0.8110 - val_loss: 0.3990 - val_accuracy: 0.8205
#
# Epoch 00176: val_loss did not improve from 0.39763
# Epoch 177/1000
# 94/94 - 1s - loss: 0.4278 - accuracy: 0.8109 - val_loss: 0.3978 - val_accuracy: 0.8234
#
# Epoch 00177: val_loss did not improve from 0.39763
# Epoch 178/1000
# 94/94 - 1s - loss: 0.4255 - accuracy: 0.8133 - val_loss: 0.4005 - val_accuracy: 0.8152
#
# Epoch 00178: val_loss did not improve from 0.39763
# Epoch 179/1000
# 94/94 - 1s - loss: 0.4242 - accuracy: 0.8118 - val_loss: 0.3971 - val_accuracy: 0.8247
#
# Epoch 00179: val_loss improved from 0.39763 to 0.39707, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0179 ----  0.3971.hdf5
# Epoch 180/1000
# 94/94 - 1s - loss: 0.4225 - accuracy: 0.8121 - val_loss: 0.3980 - val_accuracy: 0.8195
#
# Epoch 00180: val_loss did not improve from 0.39707
# Epoch 181/1000
# 94/94 - 1s - loss: 0.4236 - accuracy: 0.8145 - val_loss: 0.3965 - val_accuracy: 0.8254
#
# Epoch 00181: val_loss improved from 0.39707 to 0.39647, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0181 ----  0.3965.hdf5
# Epoch 182/1000
# 94/94 - 1s - loss: 0.4249 - accuracy: 0.8135 - val_loss: 0.3980 - val_accuracy: 0.8150
#
# Epoch 00182: val_loss did not improve from 0.39647
# Epoch 183/1000
# 94/94 - 1s - loss: 0.4224 - accuracy: 0.8128 - val_loss: 0.3963 - val_accuracy: 0.8240
#
# Epoch 00183: val_loss improved from 0.39647 to 0.39626, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0183 ----  0.3963.hdf5
# Epoch 184/1000
# 94/94 - 1s - loss: 0.4241 - accuracy: 0.8115 - val_loss: 0.3967 - val_accuracy: 0.8248
#
# Epoch 00184: val_loss did not improve from 0.39626
# Epoch 185/1000
# 94/94 - 1s - loss: 0.4223 - accuracy: 0.8132 - val_loss: 0.3961 - val_accuracy: 0.8234
#
# Epoch 00185: val_loss improved from 0.39626 to 0.39611, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0185 ----  0.3961.hdf5
# Epoch 186/1000
# 94/94 - 1s - loss: 0.4206 - accuracy: 0.8147 - val_loss: 0.3954 - val_accuracy: 0.8207
#
# Epoch 00186: val_loss improved from 0.39611 to 0.39542, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0186 ----  0.3954.hdf5
# Epoch 187/1000
# 94/94 - 1s - loss: 0.4190 - accuracy: 0.8146 - val_loss: 0.3949 - val_accuracy: 0.8253
#
# Epoch 00187: val_loss improved from 0.39542 to 0.39494, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0187 ----  0.3949.hdf5
# Epoch 188/1000
# 94/94 - 1s - loss: 0.4194 - accuracy: 0.8147 - val_loss: 0.3950 - val_accuracy: 0.8249
#
# Epoch 00188: val_loss did not improve from 0.39494
# Epoch 189/1000
# 94/94 - 1s - loss: 0.4210 - accuracy: 0.8117 - val_loss: 0.3935 - val_accuracy: 0.8262
#
# Epoch 00189: val_loss improved from 0.39494 to 0.39353, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0189 ----  0.3935.hdf5
# Epoch 190/1000
# 94/94 - 1s - loss: 0.4170 - accuracy: 0.8147 - val_loss: 0.3937 - val_accuracy: 0.8253
#
# Epoch 00190: val_loss did not improve from 0.39353
# Epoch 191/1000
# 94/94 - 1s - loss: 0.4174 - accuracy: 0.8146 - val_loss: 0.3930 - val_accuracy: 0.8222
#
# Epoch 00191: val_loss improved from 0.39353 to 0.39296, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0191 ----  0.3930.hdf5
# Epoch 192/1000
# 94/94 - 1s - loss: 0.4153 - accuracy: 0.8136 - val_loss: 0.3932 - val_accuracy: 0.8237
#
# Epoch 00192: val_loss did not improve from 0.39296
# Epoch 193/1000
# 94/94 - 1s - loss: 0.4166 - accuracy: 0.8144 - val_loss: 0.3947 - val_accuracy: 0.8253
#
# Epoch 00193: val_loss did not improve from 0.39296
# Epoch 194/1000
# 94/94 - 1s - loss: 0.4186 - accuracy: 0.8124 - val_loss: 0.3947 - val_accuracy: 0.8213
#
# Epoch 00194: val_loss did not improve from 0.39296
# Epoch 195/1000
# 94/94 - 1s - loss: 0.4158 - accuracy: 0.8152 - val_loss: 0.3955 - val_accuracy: 0.8227
#
# Epoch 00195: val_loss did not improve from 0.39296
# Epoch 196/1000
# 94/94 - 1s - loss: 0.4158 - accuracy: 0.8155 - val_loss: 0.3947 - val_accuracy: 0.8252
#
# Epoch 00196: val_loss did not improve from 0.39296
# Epoch 197/1000
# 94/94 - 1s - loss: 0.4167 - accuracy: 0.8139 - val_loss: 0.3922 - val_accuracy: 0.8302
#
# Epoch 00197: val_loss improved from 0.39296 to 0.39221, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0197 ----  0.3922.hdf5
# Epoch 198/1000
# 94/94 - 1s - loss: 0.4130 - accuracy: 0.8164 - val_loss: 0.3920 - val_accuracy: 0.8266
#
# Epoch 00198: val_loss improved from 0.39221 to 0.39197, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0198 ----  0.3920.hdf5
# Epoch 199/1000
# 94/94 - 1s - loss: 0.4157 - accuracy: 0.8161 - val_loss: 0.3916 - val_accuracy: 0.8270
#
# Epoch 00199: val_loss improved from 0.39197 to 0.39161, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0199 ----  0.3916.hdf5
# Epoch 200/1000
# 94/94 - 1s - loss: 0.4154 - accuracy: 0.8149 - val_loss: 0.3925 - val_accuracy: 0.8265
#
# Epoch 00200: val_loss did not improve from 0.39161
# Epoch 201/1000
# 94/94 - 1s - loss: 0.4153 - accuracy: 0.8151 - val_loss: 0.3935 - val_accuracy: 0.8247
#
# Epoch 00201: val_loss did not improve from 0.39161
# Epoch 202/1000
# 94/94 - 1s - loss: 0.4126 - accuracy: 0.8148 - val_loss: 0.3916 - val_accuracy: 0.8264
#
# Epoch 00202: val_loss improved from 0.39161 to 0.39156, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0202 ----  0.3916.hdf5
# Epoch 203/1000
# 94/94 - 1s - loss: 0.4118 - accuracy: 0.8155 - val_loss: 0.3937 - val_accuracy: 0.8221
#
# Epoch 00203: val_loss did not improve from 0.39156
# Epoch 204/1000
# 94/94 - 1s - loss: 0.4115 - accuracy: 0.8157 - val_loss: 0.3915 - val_accuracy: 0.8262
#
# Epoch 00204: val_loss improved from 0.39156 to 0.39154, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0204 ----  0.3915.hdf5
# Epoch 205/1000
# 94/94 - 1s - loss: 0.4137 - accuracy: 0.8146 - val_loss: 0.3932 - val_accuracy: 0.8254
#
# Epoch 00205: val_loss did not improve from 0.39154
# Epoch 206/1000
# 94/94 - 1s - loss: 0.4114 - accuracy: 0.8167 - val_loss: 0.3923 - val_accuracy: 0.8226
#
# Epoch 00206: val_loss did not improve from 0.39154
# Epoch 207/1000
# 94/94 - 1s - loss: 0.4107 - accuracy: 0.8151 - val_loss: 0.3922 - val_accuracy: 0.8260
#
# Epoch 00207: val_loss did not improve from 0.39154
# Epoch 208/1000
# 94/94 - 1s - loss: 0.4076 - accuracy: 0.8186 - val_loss: 0.3916 - val_accuracy: 0.8263
#
# Epoch 00208: val_loss did not improve from 0.39154
# Epoch 209/1000
# 94/94 - 1s - loss: 0.4099 - accuracy: 0.8156 - val_loss: 0.3914 - val_accuracy: 0.8261
#
# Epoch 00209: val_loss improved from 0.39154 to 0.39137, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0209 ----  0.3914.hdf5
# Epoch 210/1000
# 94/94 - 1s - loss: 0.4081 - accuracy: 0.8174 - val_loss: 0.3919 - val_accuracy: 0.8270
#
# Epoch 00210: val_loss did not improve from 0.39137
# Epoch 211/1000
# 94/94 - 1s - loss: 0.4081 - accuracy: 0.8186 - val_loss: 0.3916 - val_accuracy: 0.8276
#
# Epoch 00211: val_loss did not improve from 0.39137
# Epoch 212/1000
# 94/94 - 1s - loss: 0.4068 - accuracy: 0.8182 - val_loss: 0.3906 - val_accuracy: 0.8261
#
# Epoch 00212: val_loss improved from 0.39137 to 0.39056, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0212 ----  0.3906.hdf5
# Epoch 213/1000
# 94/94 - 1s - loss: 0.4071 - accuracy: 0.8170 - val_loss: 0.3896 - val_accuracy: 0.8268
#
# Epoch 00213: val_loss improved from 0.39056 to 0.38956, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0213 ----  0.3896.hdf5
# Epoch 214/1000
# 94/94 - 1s - loss: 0.4086 - accuracy: 0.8165 - val_loss: 0.3903 - val_accuracy: 0.8273
#
# Epoch 00214: val_loss did not improve from 0.38956
# Epoch 215/1000
# 94/94 - 1s - loss: 0.4071 - accuracy: 0.8179 - val_loss: 0.3912 - val_accuracy: 0.8270
#
# Epoch 00215: val_loss did not improve from 0.38956
# Epoch 216/1000
# 94/94 - 1s - loss: 0.4078 - accuracy: 0.8159 - val_loss: 0.3915 - val_accuracy: 0.8289
#
# Epoch 00216: val_loss did not improve from 0.38956
# Epoch 217/1000
# 94/94 - 1s - loss: 0.4052 - accuracy: 0.8182 - val_loss: 0.3919 - val_accuracy: 0.8267
#
# Epoch 00217: val_loss did not improve from 0.38956
# Epoch 218/1000
# 94/94 - 1s - loss: 0.4057 - accuracy: 0.8185 - val_loss: 0.3897 - val_accuracy: 0.8286
#
# Epoch 00218: val_loss did not improve from 0.38956
# Epoch 219/1000
# 94/94 - 1s - loss: 0.4041 - accuracy: 0.8174 - val_loss: 0.3891 - val_accuracy: 0.8261
#
# Epoch 00219: val_loss improved from 0.38956 to 0.38910, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0219 ----  0.3891.hdf5
# Epoch 220/1000
# 94/94 - 1s - loss: 0.4058 - accuracy: 0.8176 - val_loss: 0.3886 - val_accuracy: 0.8283
#
# Epoch 00220: val_loss improved from 0.38910 to 0.38862, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0220 ----  0.3886.hdf5
# Epoch 221/1000
# 94/94 - 1s - loss: 0.4047 - accuracy: 0.8170 - val_loss: 0.3892 - val_accuracy: 0.8268
#
# Epoch 00221: val_loss did not improve from 0.38862
# Epoch 222/1000
# 94/94 - 1s - loss: 0.4052 - accuracy: 0.8183 - val_loss: 0.3881 - val_accuracy: 0.8301
#
# Epoch 00222: val_loss improved from 0.38862 to 0.38810, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0222 ----  0.3881.hdf5
# Epoch 223/1000
# 94/94 - 1s - loss: 0.4034 - accuracy: 0.8191 - val_loss: 0.3891 - val_accuracy: 0.8299
#
# Epoch 00223: val_loss did not improve from 0.38810
# Epoch 224/1000
# 94/94 - 1s - loss: 0.4021 - accuracy: 0.8181 - val_loss: 0.3896 - val_accuracy: 0.8273
#
# Epoch 00224: val_loss did not improve from 0.38810
# Epoch 225/1000
# 94/94 - 1s - loss: 0.4002 - accuracy: 0.8194 - val_loss: 0.3898 - val_accuracy: 0.8274
#
# Epoch 00225: val_loss did not improve from 0.38810
# Epoch 226/1000
# 94/94 - 1s - loss: 0.4023 - accuracy: 0.8189 - val_loss: 0.3867 - val_accuracy: 0.8311
#
# Epoch 00226: val_loss improved from 0.38810 to 0.38666, saving model to /DockerProjects/walkCAM/tug/0_temporalCNN_wLabel/Results/saveResults_최윤정/DTWact6/LookBack- 8TUG-0226 ----  0.3867.hdf5
# Epoch 227/1000
# 94/94 - 1s - loss: 0.4002 - accuracy: 0.8214 - val_loss: 0.3893 - val_accuracy: 0.8277
#
# Epoch 00227: val_loss did not improve from 0.38666
# Epoch 228/1000
# 94/94 - 1s - loss: 0.4017 - accuracy: 0.8186 - val_loss: 0.3886 - val_accuracy: 0.8305
#
# Epoch 00228: val_loss did not improve from 0.38666
# Epoch 229/1000
# 94/94 - 1s - loss: 0.4011 - accuracy: 0.8178 - val_loss: 0.3877 - val_accuracy: 0.8314
#
# Epoch 00229: val_loss did not improve from 0.38666
# Epoch 230/1000
# 94/94 - 1s - loss: 0.4007 - accuracy: 0.8198 - val_loss: 0.3891 - val_accuracy: 0.8274
#
# Epoch 00230: val_loss did not improve from 0.38666
# Epoch 231/1000
# 94/94 - 1s - loss: 0.4004 - accuracy: 0.8200 - val_loss: 0.3886 - val_accuracy: 0.8287
#
# Epoch 00231: val_loss did not improve from 0.38666
# Epoch 232/1000
# 94/94 - 1s - loss: 0.3998 - accuracy: 0.8216 - val_loss: 0.3886 - val_accuracy: 0.8263
#
# Epoch 00232: val_loss did not improve from 0.38666
# Epoch 233/1000
# 94/94 - 1s - loss: 0.3996 - accuracy: 0.8196 - val_loss: 0.3894 - val_accuracy: 0.8267
#
# Epoch 00233: val_loss did not improve from 0.38666
# Epoch 234/1000
# 94/94 - 1s - loss: 0.4012 - accuracy: 0.8194 - val_loss: 0.3885 - val_accuracy: 0.8251
#
# Epoch 00234: val_loss did not improve from 0.38666
# Epoch 235/1000
# 94/94 - 1s - loss: 0.3987 - accuracy: 0.8203 - val_loss: 0.3888 - val_accuracy: 0.8295
#
# Epoch 00235: val_loss did not improve from 0.38666
# Epoch 236/1000
# 94/94 - 1s - loss: 0.3976 - accuracy: 0.8207 - val_loss: 0.3901 - val_accuracy: 0.8247
#
# Epoch 00236: val_loss did not improve from 0.38666
# 26/26 - 13s - loss: 0.3919 - accuracy: 0.8182
# test_loss: 0.39191925525665283 - test_acc: 0.8182101249694824

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='lower left')

plt.show()

# %%
# y_pred = model.predict(x_test)
y_pred = model.predict(test_x)
print(y_pred.shape)

y_pred_onehot = np.argmax(y_pred, axis=1)
print(y_pred[200] ,"===> onehot: ", y_pred_onehot[200])

y_test_argmax = np.argmax(test_y ,axis=1) 
y_pred_argmax = np.argmax(y_pred ,axis=1)
print(y_test_argmax.shape, y_pred_argmax.shape)

def action_frames(y_pred_argmax, ratio_display = False):
    action_label =  {"sit": 0, "sit-stand": 1,  "walk": 2, "turn": 3, "walkback":4, "stand-sit": 5}
    action_cnt =  {"total_frames": 0,"sit": 0, "sit-stand": 0,  "walk": 0, "turn": 0, "walkback":0, "stand-sit": 0}

    for i in range(len(y_pred_argmax)):
        action_cnt["total_frames"] +=1
        if y_pred_argmax[i] == action_label["sit"]:
            action_cnt["sit"] +=1
            
        elif y_pred_argmax[i] == action_label["sit-stand"]:
            action_cnt["sit-stand"] +=1
            
        elif y_pred_argmax[i] == action_label["walk"]:
            action_cnt["walk"] +=1
            
        elif y_pred_argmax[i] == action_label["turn"]:
            action_cnt["turn"] +=1
            
        elif y_pred_argmax[i] == action_label["walkback"]:
            action_cnt["walkback"] +=1
            
        elif y_pred_argmax[i] == action_label["stand-sit"]:
            action_cnt["stand-sit"] +=1
        
    if ratio_display:     
        print("[ Action Ratio ]")
        print("\t [ 0 - Sit] ratio of sit: ",  action_cnt["sit"]/action_cnt["total_frames"] )
        print("\t [ 1 - sit-stand] ratio of sit-stand: ",  action_cnt["sit-stand"]/action_cnt["total_frames"])
        print("\t [ 2 - walk] ratio of walk: ",  action_cnt["walk"]/action_cnt["total_frames"])
        print("\t [ 3 - turn] ratio of turn: ",  action_cnt["turn"]/action_cnt["total_frames"])
        print("\t [ 4 - walkback] ratio of walkback: ",  action_cnt["walkback"]/action_cnt["total_frames"])
        print("\t [ 5 - stand-sit] ratio of stand-sit: ",  action_cnt["stand-sit"]/action_cnt["total_frames"])
    return action_cnt
    
y_pred_frames = action_frames(y_pred_argmax, ratio_display= True)
y_test_frames = action_frames(y_test_argmax,  ratio_display= True)   

print("--->  # of Each Action Frames  \n\t y_pred: {0}, \n\t y_test: {1}".format(y_pred_frames, y_test_frames))

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import cohen_kappa_score
import seaborn as sns


kappa = cohen_kappa_score(y_test_argmax, y_pred_argmax)
print('Cohens kappa: %f' % kappa)

print(classification_report(y_test_argmax, y_pred_argmax))

conf_matrix = confusion_matrix(y_test_argmax, y_pred_argmax)
print("\n---> Confusion Matrix \n" ,conf_matrix) # sit, sit-stand, walking, turning, stand-sit

plt.figure(figsize = (15,7) )
sns.heatmap(conf_matrix, annot=True)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Cohens kappa: 0.770786
#               precision    recall  f1-score   support
#
#            0       0.49      0.59      0.54      1897
#            1       0.94      0.54      0.68      1252
#            2       0.98      0.84      0.91      4913
#            3       0.91      0.97      0.94      3327
#            4       0.94      0.90      0.92      3498
#            5       0.69      0.79      0.74      5482
#
#     accuracy                           0.82     20369
#    macro avg       0.82      0.77      0.79     20369
# weighted avg       0.84      0.82      0.82     20369
#
#
# ---> Confusion Matrix
#  [[1120    0    0    0    0  777]
#  [ 116  676   21    0   11  428]
#  [   0    6 4140  163   82  522]
#  [   0    0   51 3242   34    0]
#  [   0    0    0  174 3143  181]
#  [1036   40    0    0   85 4321]]

# %% [markdown]
# #### PreProcessing for Saving LPF with oneHot encoded CSV (Fig)

# %%
def preprocess_forSaving(actSplit=False, save = True):
    total_Trials = 0
    for dirpath, foldername, files in sorted(os.walk(datasetDir)):
        clear_output(wait=True)
        actPath = None
        pelvisPath= None
        actFrame = []
        if ".ipynb_checkpoints" in dirpath:
            continue
        else:
            for filename in sorted(files):
                if ".csv" in filename:
                    if "label_" in filename:
                        labelPath = dirpath
                        label_csv = os.path.join(labelPath,filename)
                        actFrame = get_actFrameNumber( label_csv)

                    if "skeleton_" in filename:          
                        pelvisPath = dirpath    
                        subname = dirpath.split("/")[-2] 
                        trial = dirpath.split("/")[-1] 
                        pelvis_csv = os.path.join(dirpath, filename)


                        frameNum, timstamp_ms, pelvis_x, pelvis_y, pelvis_z  = get_rawData(pelvis_csv)  # raw                 
                        pltSkeleton(timstamp_ms, pelvis_x, pelvis_y, pelvis_z, pelvisPath, subname +"_"+str(trial), actFrame, addFolder="raw", actSplit=actSplit, save=save) # ---> plot raw
                        normPelvis_x, normPelvis_y, normPelvis_z = get_normData(pelvis_x, pelvis_y, pelvis_z, normMethod = 'min_max') # norm         
                        pltSkeleton(timstamp_ms, normPelvis_x, normPelvis_y, normPelvis_z, pelvisPath, subname +"_"+str(trial), actFrame, addFolder="norm", actSplit=actSplit, save=save) # ---> plot norm 
                        lpfPelvis_x, lpfPelvis_y, lpfPelvis_z = get_LPFData(normPelvis_x, normPelvis_y, normPelvis_z, cutoff_freq=0.5, order=1)  # lpf 
                        pltSkeleton(timstamp_ms, lpfPelvis_x, lpfPelvis_y, lpfPelvis_z, pelvisPath, subname +"_"+str(trial), actFrame, addFolder= "lpf" + "_norm",actSplit=actSplit, save=save) # plot lpf   
                
                        total_Trials +=1   
                        if labelPath == pelvisPath:
                            print("\t ---->",pelvisPath, " \t act label ====> " +  str(actFrame) + "\n")         
                            oneHot_actionList = convert_act2oneHot(actFrame, frameNum)
                            
                            # --> raw skeleton data is used..
                            unLabel_rawData = np.array([timstamp_ms, pelvis_x, pelvis_y, pelvis_z]).T 
                            unLabel_lpfData = np.array([timstamp_ms, lpfPelvis_x, normPelvis_y, lpfPelvis_z]).T

                            raw_mergeData = np.zeros((len(unLabel_rawData), dataset_columns))
                            lpf_mergeData = np.zeros((len(unLabel_lpfData), dataset_columns))

                            raw_mergeData[:, :-(numActions)] = unLabel_rawData      # time , pelvis  넣음  (317,4) -- raw data  (time, x ,y, z)
                            raw_mergeData[:, -(numActions): ] = oneHot_actionList     #  (onehot encoded action = 6 )

                            lpf_mergeData[:, :-(numActions)] = unLabel_lpfData      # time , pelvis  넣음  (317,4) -- lpf applied
                            lpf_mergeData[:, -(numActions): ] = oneHot_actionList     # (335, 5) one hot encoding 수행한 actionsList          

                            # -- save data 
                            if save:  
                                if  os.path.isfile(pelvisPath + "/" + "raw_labeled_" +  subname +"_"+str(trial) + ".csv"):
                                    os.remove(pelvisPath + "/" + "raw_labeled_" +  subname +"_"+str(trial) + ".csv")
                                    os.remove(pelvisPath + "/" + "lpf_labeled_" +  subname +"_"+str(trial) + ".csv")
                                
                                np.savetxt(pelvisPath + "/" + "raw_labeled_" +  subname +"_"+str(trial) + ".csv", raw_mergeData, fmt='%s', delimiter=',')
                                np.savetxt(pelvisPath + "/" + "lpf_labeled_" +  subname +"_"+str(trial) + ".csv", lpf_mergeData, fmt='%s', delimiter=',')
                            
    return total_Trials
    
    
total_Trials = preprocess_forSaving(actSplit=True, save=True)
print("Total Trials: ", total_Trials)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     509     try:
# --> 510         fh = fp.fileno()
#     511         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-5bbc8308938c> in <module>
#      60
#      61
# ---> 62 total_Trials = preprocess_forSaving(actSplit=True, save=True)
#      63 print("Total Trials: ", total_Trials)
#
# <ipython-input-15-5bbc8308938c> in preprocess_forSaving(actSplit, save)
#      26                         pltSkeleton(timstamp_ms, pelvis_x, pelvis_y, pelvis_z, pelvisPath, subname +"_"+str(trial), actFrame, addFolder="raw", actSplit=actSplit, save=save) # ---> plot raw
#      27                         normPelvis_x, normPelvis_y, normPelvis_z = get_normData(pelvis_x, pelvis_y, pelvis_z, normMethod = 'min_max') # norm
# ---> 28                         pltSkeleton(timstamp_ms, normPelvis_x, normPelvis_y, normPelvis_z, pelvisPath, subname +"_"+str(trial), actFrame, addFolder="norm", actSplit=actSplit, save=save) # ---> plot norm
#      29                         lpfPelvis_x, lpfPelvis_y, lpfPelvis_z = get_LPFData(normPelvis_x, normPelvis_y, normPelvis_z, cutoff_freq=0.5, order=1)  # lpf
#      30                         pltSkeleton(timstamp_ms, lpfPelvis_x, lpfPelvis_y, lpfPelvis_z, pelvisPath, subname +"_"+str(trial), actFrame, addFolder= "lpf" + "_norm",actSplit=actSplit, save=save) # plot lpf
#
# <ipython-input-4-e2445346a7ab> in pltSkeleton(timeSec, pelvis_x, pelvis_y, pelvis_z, saveDir, saveFile, actLabel, addFolder, actSplit, save)
#     145         if  os.path.isfile(saveDir+"/"+title):
#     146             os.remove(saveDir+"/"+title)
# --> 147         fig.savefig(saveDir+"/"+title)
#     148     plt.close()
#     149
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
# --> 512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#     513
#     514     def print_to_buffer(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2162
#    2163         try:
# -> 2164             save_handler(self, fp, filename)
#    2165         finally:
#    2166             # do what we can to clean up
#
# /usr/local/lib/python3.6/dist-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1335         _write_multiple_frames(im, fp, chunk, rawmode)
#    1336     else:
# -> 1337         ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1338
#    1339     if info:
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     522             else:
#     523                 while True:
# --> 524                     l, s, d = e.encode(bufsize)
#     525                     fp.write(d)
#     526                     if s:
#
# KeyboardInterrupt:
